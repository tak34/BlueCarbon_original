# %%
# !pip install shap
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: shap in /usr/local/lib/python3.10/dist-packages (0.41.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from shap) (1.5.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from shap) (1.2.2)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.10/dist-packages (from shap) (23.1)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap) (0.56.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from shap) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from shap) (1.10.1)
# Requirement already satisfied: tqdm>4.25.0 in /usr/local/lib/python3.10/dist-packages (from shap) (4.65.0)
# Requirement already satisfied: slicer==0.0.7 in /usr/local/lib/python3.10/dist-packages (from shap) (0.0.7)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba->shap) (67.7.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap) (0.39.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (1.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->shap) (1.16.0)

# %%
import lightgbm as lgb
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import numpy as np
import pandas as pd
import seaborn as sns
import datetime as dt
from pathlib import Path
import warnings
import os
import random
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
from tqdm.notebook import tqdm

import shap

# %%
# plt.rcParams['font.family'] = "MS Gothic"
warnings.simplefilter('ignore')

# %%
def fix_all_seeds(seed):
    np.random.seed(seed)
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    
fix_all_seeds(0)

# %%
# Config
SUB_FILE_NAME = "val12-0"
SAVE_SUB = False
SAVE_SUB_DIR = Path("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/sub_20230225")
SAVE_DF = False
SAVE_DF_DIR = Path("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/Val_20230429")

# %% [markdown]
# # データ読み込み

# %%
train = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/train.pkl")
test = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/test.pkl")
sub = pd.read_csv("/content/drive/MyDrive/Kaggle/BlueCarbon/raw/submit_example.csv")

# 特徴抽出後のデータ
umap_basic_train = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/FE_20230417/20230417_umap_basic_train.pkl")
umap_basic_test = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/FE_20230417/20230417_umap_basic_test.pkl")
train_sentinel = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/FE_20230417/20230428_train_sentinel_minmaxDiff.pkl")
test_sentinel = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/FE_20230417/20230428_test_sentinel_minmaxDiff.pkl")
train_landsat_2000to2020 = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/FE_20230417/20230429_train_landsat2_2000to2020.pkl")
test_landsat_2000to2020 = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/FE_20230417/20230429_test_landsat2_2000to2020.pkl")
train_landsat_norm = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/FE_20230417/20230430_train_landsat3_normalized.pkl")
test_landsat_norm = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/FE_20230417/20230430_test_landsat3_normalized.pkl")
train_landsat_minmax = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/FE_20230417/20230430_train_landsat4_minmax.pkl")
test_landsat_minmax = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/FE_20230417/20230430_test_landsat4_minmax.pkl")

train.head(2)
# Out:
#          lat         lon  area                 YMD    year  month  cover  \
# 0  24.989140  125.243164  20.0            20110926  2011.0    9.0  0.050
# 1  26.996172  127.912025  40.0  2009.7.6-2009.7.28  2009.0    7.0  0.725
#
#    depth_original  cliff_length  aicial_length  ...  MIN_NormG_2020  \
# 0             NaN           0.0       0.000000  ...        0.507961
# 1             NaN           0.0       0.478772  ...        0.353645
#
#    MIN_NormR_2020  MIN_PPR_2020  MIN_PSNDc2_2020  MIN_RDVI_2020  MIN_IF_2020  \
# 0        0.287288     -0.278071        -0.808075      -2.341663     2.353039
# 1        0.245048     -0.100556        -0.771423      -3.282602     4.672225
#
#    MIN_SLAVI_2020  MIN_SIPI2_2020  MIN_VARIgreen_2020   mesh20
# 0       95.142525        3.728732           -2.405135  3725_10
# 1      174.767501       -0.571513            0.448861  4027_13
#
# [2 rows x 3464 columns]

# %%
sub.head(2)
# Out:
#    0  0.47
# 0  1  0.68
# 1  2  0.25

# %% [markdown]
# # 前処理

# %% [markdown]
# ## 対数変換

# %%
train[f"log_cover"] = np.log1p(train["cover"])

# %% [markdown]
# ## 特徴抽出後のデータを結合

# %%
# いらんデータ消しておく
cols_landsat_2000to2020 = [col for col in train_landsat_2000to2020.columns if not "MINMAX" in col]
train_landsat_2000to2020 = train_landsat_2000to2020[cols_landsat_2000to2020]
test_landsat_2000to2020 = test_landsat_2000to2020[cols_landsat_2000to2020]

# %%
print(train.shape)
print(train_landsat_minmax.shape)
print(test.shape)
print(test_landsat_minmax.shape)
train_landsat_minmax.head(2)
# Out:
# (14140, 3465)
# (14140, 100)
# (4039, 3463)
# (4039, 100)
#    MINMAX_CTVI_mean  MINMAX_CTVI_std  MINMAX_PPR_mean  MINMAX_PPR_std  \
# 0          0.134025         0.111810         0.080669        0.086960
# 1          0.035624         0.047987         0.046483        0.045414
#
#    MINMAX_TIRS2_mean  MINMAX_TIRS2_std  MINMAX_EVI_mean  MINMAX_EVI_std  \
# 0           0.339952          0.359248         0.042444        0.058448
# 1           0.318083          0.318512         0.187296        0.193427
#
#    MINMAX_SIPI2_mean  MINMAX_SIPI2_std  ...  MINMAX_MCARI2_mean  \
# 0           1.817571          2.293036  ...            0.973567
# 1           4.727555          6.033570  ...            0.258074
#
#    MINMAX_MCARI2_std  MINMAX_BWDRVI_mean  MINMAX_BWDRVI_std  \
# 0           0.848198            0.028040           0.035760
# 1           0.266281            0.045798           0.048732
#
#    MINMAX_MCARI1_mean  MINMAX_MCARI1_std  MINMAX_SWIR2_mean  MINMAX_SWIR2_std  \
# 0           11.012710          19.343378           1.181849          1.944656
# 1           21.390165          24.260161           0.475902          0.772107
#
#    MINMAX_Ferric_Oxides_mean  MINMAX_Ferric_Oxides_std
# 0                   0.056972                  0.049894
# 1                   0.048084                  0.053776
#
# [2 rows x 100 columns]

# %%
train = train.join([
    umap_basic_train,
    train_sentinel,
    train_landsat_minmax,
    train_landsat_2000to2020,
    train_landsat_norm,
])
test = test.join([
    umap_basic_test,
    test_sentinel,
    test_landsat_minmax,
    test_landsat_2000to2020,
    train_landsat_norm,
])
train.head(2)
# Out:
#          lat         lon  area                 YMD    year  month  cover  \
# 0  24.989140  125.243164  20.0            20110926  2011.0    9.0  0.050
# 1  26.996172  127.912025  40.0  2009.7.6-2009.7.28  2009.0    7.0  0.725
#
#    depth_original  cliff_length  aicial_length  ...  NLI_norm  NormG_norm  \
# 0             NaN           0.0       0.000000  ... -1.451049    0.475077
# 1             NaN           0.0       0.478772  ...  1.864528   -3.654105
#
#    NormR_norm  PPR_norm  PSNDc2_norm  RDVI_norm    IF_norm  SLAVI_norm  \
# 0    0.296024 -1.109615    -0.750047  -0.052587   0.127271   -0.406854
# 1   -1.126482  2.711313     5.444383   9.581726  12.557637    1.335754
#
#    SIPI2_norm  VARIgreen_norm
# 0    0.116049       -0.049049
# 1   -4.261068        0.143220
#
# [2 rows x 3792 columns]

# %%
umap_basic_train.head()
# Out:
#         dim0      dim1  temp_monthly
# 0   1.788618  6.597842          27.9
# 1 -10.111396  6.170877          29.2
# 2  21.165592  6.679852          25.3
# 3  -6.996612  9.728025          16.7
# 4  -6.822807  9.109682          16.7

# %% [markdown]
# ## 使用する特徴量

# %%
# 被度文献データ、海洋環境要因データ、landsat使用
# YMDは使わない
cols_base = train.columns.to_list()[:25]
# cols_landsat = train.columns.to_list()[25:88]
cols_landsat = ["sunAzimuth", "sunElevation", "Landsat_num"]
cols_landsat_2000to2020 = train_landsat_2000to2020.columns.to_list()
cols_landsat_minmax = train_landsat_minmax.columns.to_list()
cols_landsat_norm = train_landsat_norm.columns.to_list()

cols_sentinel = train.columns.to_list()[88:313]
cols_sentinel = [col for col in cols_sentinel if "MED" in col]
cols_sentinel_minmax = train_sentinel.columns.to_list()

cols_umap = ["temp_monthly"]

cols_use =\
 cols_base +\
 cols_landsat +\
 cols_landsat_2000to2020 +\
 cols_landsat_minmax +\
 cols_landsat_norm +\
 ["log_cover"] # + cols_sentinel

cols_remove = [
    "YMD",
    "month",
    "Date_Acquired",
    "Landsat_StartTime",
    "PRODUCT_ID",
    "mesh20"
]
cols_use = [col for col in cols_use if not col in cols_remove]

# 重複を省く（一応）
cols_use = list(set(cols_use))

cols_use
# Out:
# ['MED_Cigreen_std',
#  'DVIMSS_norm',
#  'EVI_norm',
#  'MINMAX_IF_std',
#  'MED_NIR_median',
#  'MED_H_std',
#  'MED_TIRS1_std',
#  'Cirededge_norm',
#  'MINMAX_TIRS1_mean',
#  'MED_mCRIG_median',
#  'D678_500_norm',
#  'GEMI_norm',
#  'MCARI2_norm',
#  'Chlred_edge_norm',
#  'NIR_norm',
#  'sst_annual',
#  'MED_Cirededge_median',
#  'MED_BWDRVI_std',
#  'MED_Chlred_edge_std',
#  'MINMAX_TSAVI_mean',
#  'MED_GEMI_std',
#  'MINMAX_Cirededge_mean',
#  'MED_MCARI1_std',
#  'MED_Green_median',
#  'MINMAX_Chlgreen_std',
#  'MINMAX_Fe3_std',
#  'MINMAX_Gossan_mean',
#  'MED_GVMI_median',
#  'cliff_length',
#  'MED_NormG_median',
#  'MINMAX_IR550_std',
#  'MINMAX_Red_mean',
#  'MINMAX_Blue_std',
#  'MINMAX_MCARI2_mean',
#  'TSAVI_norm',
#  'Chlgreen_norm',
#  'MINMAX_CVI_std',
#  'GARI_norm',
#  'aicial_length',
#  'MED_CRI550_median',
#  'MED_Ferric_Oxides_median',
#  'MINMAX_Cigreen_std',
#  'MINMAX_IF_mean',
#  'MINMAX_Ferric_Oxides_mean',
#  'MINMAX_NIR_std',
#  'NLI_norm',
#  'mCRIG_norm',
#  'MED_Alteration_std',
#  'GLI_norm',
#  'MINMAX_PPR_std',
#  'MINMAX_DSWI_std',
#  'MED_TSAVI_std',
#  'MINMAX_Chlred_edge_mean',
#  'MINMAX_BWDRVI_std',
#  'MED_DSWI_5_median',
#  'MED_Fe3_median',
#  'MINMAX_PPR_mean',
#  'MINMAX_CVI_mean',
#  'MED_GVMI_std',
#  'MINMAX_Alteration_mean',
#  'MINMAX_Ferric_Oxides_std',
#  'MED_Cigreen_median',
#  'MED_IR550_std',
#  'log_cover',
#  'MINMAX_mCRIRE_std',
#  'BWDRVI_norm',
#  'MINMAX_Chlred_edge_std',
#  'MED_SLAVI_std',
#  'Red_norm',
#  'GVMI_norm',
#  'MED_NLI_median',
#  'MINMAX_mCRIG_mean',
#  'MINMAX_Blue_mean',
#  'depth',
#  'MINMAX_Gossan_std',
#  'MINMAX_Ferrous_Silicates_mean',
#  'MINMAX_NIR_mean',
#  'Ferric_Oxides_norm',
#  'Salinity_annual',
#  'coast_length',
#  'MED_D678_500_median',
#  'MED_NormR_median',
#  'TIRS2_norm',
#  'MVI_norm',
#  'MINMAX_MCARI2_std',
#  'sunAzimuth',
#  'MINMAX_D678_500_std',
#  'MED_Ferrous_Silicates_median',
#  'MINMAX_mCRIRE_mean',
#  'MINMAX_TIRS1_std',
#  'MED_AVI_std',
#  'MED_RDVI_std',
#  'MED_SLAVI_median',
#  'MED_SIPI2_median',
#  'MINMAX_EVI_mean',
#  'MINMAX_MVI_mean',
#  'MED_Ferric_Oxides_std',
#  'MINMAX_TIRS2_std',
#  'MED_GLI_std',
#  'MED_GLI_median',
#  'MINMAX_RDVI_std',
#  'MINMAX_D678_500_mean',
#  'MINMAX_NormR_std',
#  'MED_Alteration_median',
#  'MED_TSAVI_median',
#  'MED_RDVI_median',
#  'MINMAX_GEMI_mean',
#  'MINMAX_GVMI_mean',
#  'H_norm',
#  'MINMAX_SLAVI_std',
#  'MED_IF_std',
#  'IF_norm',
#  'MINMAX_GARI_std',
#  'MINMAX_H_std',
#  'MINMAX_Cigreen_mean',
#  'MED_DSWI_median',
#  'MED_CVI_median',
#  'MINMAX_MCARI1_mean',
#  'fetch',
#  'MED_MVI_median',
#  'MED_Chlgreen_std',
#  'MED_DVIMSS_median',
#  'TIRS1_norm',
#  'MED_SWIR1_std',
#  'MED_PSNDc2_median',
#  'MINMAX_NormR_mean',
#  'MED_Chlgreen_median',
#  'MED_GARI_std',
#  'CI_norm',
#  'beach_length',
#  'MED_Blue_median',
#  'MED_MCARI1_median',
#  'MINMAX_Chlgreen_mean',
#  'Fe3_norm',
#  'SLAVI_norm',
#  'river_dist',
#  'MED_Chlred_edge_median',
#  'MINMAX_GVMI_std',
#  'MINMAX_Red_std',
#  'MINMAX_DSWI_mean',
#  'MINMAX_DSWI_5_std',
#  'MED_MCARI2_median',
#  'MINMAX_MCARI1_std',
#  'CRI550_norm',
#  'MINMAX_BWDRVI_mean',
#  'lon',
#  'area',
#  'MED_IR550_median',
#  'MED_PPR_median',
#  'MINMAX_CTVI_mean',
#  'river_area',
#  'CTVI_norm',
#  'hist_cold_sst',
#  'MINMAX_GLI_std',
#  'depth_original',
#  'NormR_norm',
#  'Green_norm',
#  'MED_BWDRVI_median',
#  'MED_CVI_std',
#  'sst_ymd',
#  'sunElevation',
#  'MINMAX_H_mean',
#  'VARIgreen_norm',
#  'Alteration_norm',
#  'cold_sst',
#  'MED_EVI_std',
#  'MED_SIPI2_std',
#  'MED_EVI_median',
#  'MED_VARIgreen_std',
#  'MINMAX_TIRS2_mean',
#  'DSWI_norm',
#  'MED_TIRS2_std',
#  'hist_warm_sst',
#  'MINMAX_NLI_mean',
#  'MINMAX_SWIR1_std',
#  'MED_GARI_median',
#  'MED_SWIR2_median',
#  'MED_mCRIRE_median',
#  'MED_VARIgreen_median',
#  'AVI_norm',
#  'MINMAX_IR550_mean',
#  'MINMAX_Alteration_std',
#  'MINMAX_AVI_std',
#  'MED_CI_median',
#  'MED_DSWI_5_std',
#  'MINMAX_RDVI_mean',
#  'Blue_norm',
#  'SWIR1_norm',
#  'MED_Ferrous_Silicates_std',
#  'Gossan_norm',
#  'RDVI_norm',
#  'MED_NLI_std',
#  'MINMAX_MVI_std',
#  'MED_GEMI_median',
#  'MINMAX_Cirededge_std',
#  'PSNDc2_norm',
#  'MED_DVIMSS_std',
#  'MINMAX_VARIgreen_std',
#  'PPR_norm',
#  'MINMAX_Green_std',
#  'MED_PSNDc2_std',
#  'MED_NormR_std',
#  'MED_TIRS1_median',
#  'MINMAX_CI_mean',
#  'MINMAX_AVI_mean',
#  'IR550_norm',
#  'MED_Fe3_std',
#  'MED_mCRIG_std',
#  'MED_SWIR1_median',
#  'MINMAX_mCRIG_std',
#  'MINMAX_NormG_std',
#  'MED_SWIR2_std',
#  'MINMAX_GLI_mean',
#  'MINMAX_Green_mean',
#  'MINMAX_GEMI_std',
#  'MINMAX_PSNDc2_mean',
#  'MED_NIR_std',
#  'mCRIRE_norm',
#  'MED_CTVI_median',
#  'MED_CRI550_std',
#  'MINMAX_TSAVI_std',
#  'Ferrous_Silicates_norm',
#  'MED_DSWI_std',
#  'MED_mCRIRE_std',
#  'MED_Cirededge_std',
#  'cover',
#  'MED_TIRS2_median',
#  'MINMAX_SLAVI_mean',
#  'MINMAX_SWIR1_mean',
#  'MINMAX_DSWI_5_mean',
#  'MINMAX_CTVI_std',
#  'MED_Gossan_median',
#  'MED_AVI_median',
#  'MED_D678_500_std',
#  'Cigreen_norm',
#  'MCARI1_norm',
#  'MINMAX_DVIMSS_std',
#  'CVI_norm',
#  'MED_CTVI_std',
#  'MINMAX_NLI_std',
#  'MINMAX_SWIR2_std',
#  'NormG_norm',
#  'MED_H_median',
#  'MED_MVI_std',
#  'MINMAX_EVI_std',
#  'MINMAX_NormG_mean',
#  'MINMAX_SIPI2_std',
#  'MINMAX_GARI_mean',
#  'DSWI_5_norm',
#  'MED_IF_median',
#  'coastal_dist',
#  'MED_PPR_std',
#  'lat',
#  'MINMAX_SIPI2_mean',
#  'MINMAX_VARIgreen_mean',
#  'warm_sst',
#  'MED_NormG_std',
#  'Landsat_num',
#  'MED_CI_std',
#  'MED_Blue_std',
#  'MINMAX_PSNDc2_std',
#  'MINMAX_CRI550_mean',
#  'MINMAX_SWIR2_mean',
#  'MED_MCARI2_std',
#  'MED_Gossan_std',
#  'MINMAX_Fe3_mean',
#  'MINMAX_CI_std',
#  'SIPI2_norm',
#  'MED_Green_std',
#  'sst_diff',
#  'MINMAX_Ferrous_Silicates_std',
#  'MINMAX_DVIMSS_mean',
#  'SWIR2_norm',
#  'year',
#  'MED_Red_std',
#  'MED_Red_median',
#  'MINMAX_CRI550_std']

# %%
train = train[cols_use]
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14140 entries, 0 to 14139
# Columns: 277 entries, MED_Cigreen_std to MINMAX_CRI550_std
# dtypes: float32(27), float64(250)
# memory usage: 28.4 MB

# %%
cols_obj = ["cover", "log_cover"]
features = [col for col in cols_use if col not in cols_obj]
print("特徴量の数：", len(features))
# Out:
# 特徴量の数： 275

# %%
corr = train[features].corr()
threshold = 0.98
drop_numeric_cols=[]
pair=[]
for col in features:
    # if col in cat_features:
    #     continue
    for i in range(len(corr)):
        if abs(corr[col].iloc[i]) >= threshold and col != features[i] :
            print(f"{col} and {features[i]} are highly correlated...") 
            if col not in pair:
                pair.append(col)
                pair.append(features[i])
                drop_numeric_cols.append(col) 
features = list(set(features)-set(drop_numeric_cols))
print(f"Dropping columns : {drop_numeric_cols}")
print("特徴量の数：", len(features))
del drop_numeric_cols
del pair

features
# Out:
# MED_Cigreen_std and MED_CVI_std are highly correlated...
# MINMAX_TIRS1_mean and MINMAX_TIRS2_mean are highly correlated...
# sst_annual and cold_sst are highly correlated...
# sst_annual and lat are highly correlated...
# MED_BWDRVI_std and MED_PSNDc2_std are highly correlated...
# MED_NormG_median and MED_DSWI_5_median are highly correlated...
# MINMAX_Red_mean and MINMAX_Green_mean are highly correlated...
# MED_DSWI_5_median and MED_NormG_median are highly correlated...
# MINMAX_CVI_mean and MINMAX_Cigreen_mean are highly correlated...
# MED_Cigreen_median and MED_CVI_median are highly correlated...
# BWDRVI_norm and PSNDc2_norm are highly correlated...
# BWDRVI_norm and Cigreen_norm are highly correlated...
# BWDRVI_norm and CVI_norm are highly correlated...
# MINMAX_Cigreen_mean and MINMAX_CVI_mean are highly correlated...
# MED_CVI_median and MED_Cigreen_median are highly correlated...
# MED_PSNDc2_median and MED_BWDRVI_median are highly correlated...
# MINMAX_Red_std and MINMAX_Green_std are highly correlated...
# lon and cold_sst are highly correlated...
# MED_BWDRVI_median and MED_PSNDc2_median are highly correlated...
# MED_CVI_std and MED_Cigreen_std are highly correlated...
# cold_sst and sst_annual are highly correlated...
# cold_sst and lon are highly correlated...
# cold_sst and lat are highly correlated...
# MINMAX_TIRS2_mean and MINMAX_TIRS1_mean are highly correlated...
# PSNDc2_norm and BWDRVI_norm are highly correlated...
# MINMAX_Green_std and MINMAX_Red_std are highly correlated...
# MED_PSNDc2_std and MED_BWDRVI_std are highly correlated...
# MINMAX_Green_mean and MINMAX_Red_mean are highly correlated...
# MINMAX_SWIR1_mean and MINMAX_SWIR2_mean are highly correlated...
# Cigreen_norm and BWDRVI_norm are highly correlated...
# Cigreen_norm and CVI_norm are highly correlated...
# CVI_norm and BWDRVI_norm are highly correlated...
# CVI_norm and Cigreen_norm are highly correlated...
# NormG_norm and DSWI_5_norm are highly correlated...
# DSWI_5_norm and NormG_norm are highly correlated...
# lat and sst_annual are highly correlated...
# lat and cold_sst are highly correlated...
# MINMAX_SWIR2_mean and MINMAX_SWIR1_mean are highly correlated...
# Dropping columns : ['MED_Cigreen_std', 'MINMAX_TIRS1_mean', 'sst_annual', 'MED_BWDRVI_std', 'MED_NormG_median', 'MINMAX_Red_mean', 'MINMAX_CVI_mean', 'MED_Cigreen_median', 'BWDRVI_norm', 'MED_PSNDc2_median', 'MINMAX_Red_std', 'lon', 'MINMAX_SWIR1_mean', 'Cigreen_norm', 'CVI_norm', 'NormG_norm', 'lat']
# 特徴量の数： 258
# ['DVIMSS_norm',
#  'EVI_norm',
#  'MINMAX_IF_std',
#  'MED_H_std',
#  'MED_TIRS1_std',
#  'MCARI2_norm',
#  'NIR_norm',
#  'MED_Chlred_edge_std',
#  'MINMAX_TSAVI_mean',
#  'MINMAX_Chlred_edge_std',
#  'MED_GEMI_std',
#  'MINMAX_Cirededge_mean',
#  'Chlred_edge_norm',
#  'MED_MCARI1_std',
#  'MED_Green_median',
#  'MINMAX_Chlgreen_std',
#  'MINMAX_Fe3_std',
#  'MED_GVMI_median',
#  'MINMAX_Blue_std',
#  'MINMAX_IR550_std',
#  'MINMAX_MCARI2_mean',
#  'Chlgreen_norm',
#  'aicial_length',
#  'MED_Ferric_Oxides_median',
#  'MINMAX_IF_mean',
#  'mCRIG_norm',
#  'MINMAX_DSWI_std',
#  'MINMAX_Chlred_edge_mean',
#  'MED_TSAVI_std',
#  'MED_DSWI_5_median',
#  'MED_Fe3_median',
#  'MINMAX_PPR_mean',
#  'MED_GVMI_std',
#  'MINMAX_Ferric_Oxides_std',
#  'GVMI_norm',
#  'MED_NLI_median',
#  'MINMAX_mCRIG_mean',
#  'depth',
#  'MINMAX_Gossan_std',
#  'MINMAX_Ferrous_Silicates_mean',
#  'Ferric_Oxides_norm',
#  'coast_length',
#  'MED_D678_500_median',
#  'TIRS2_norm',
#  'MVI_norm',
#  'MINMAX_MCARI2_std',
#  'sunAzimuth',
#  'MINMAX_mCRIRE_mean',
#  'MINMAX_TIRS1_std',
#  'MED_SIPI2_median',
#  'MINMAX_EVI_mean',
#  'MINMAX_MVI_mean',
#  'MED_Ferric_Oxides_std',
#  'MED_GLI_std',
#  'MED_GLI_median',
#  'MINMAX_RDVI_std',
#  'MINMAX_D678_500_mean',
#  'MED_Alteration_median',
#  'MED_TSAVI_median',
#  'MED_RDVI_median',
#  'MINMAX_GEMI_mean',
#  'MINMAX_GVMI_mean',
#  'H_norm',
#  'IF_norm',
#  'MINMAX_GARI_std',
#  'MED_DSWI_median',
#  'MED_CVI_median',
#  'MED_MVI_median',
#  'MED_DVIMSS_median',
#  'MED_SWIR1_std',
#  'MINMAX_NormR_mean',
#  'MED_Chlgreen_median',
#  'MED_GARI_std',
#  'CI_norm',
#  'Fe3_norm',
#  'MINMAX_Chlgreen_mean',
#  'SLAVI_norm',
#  'MINMAX_DSWI_5_std',
#  'MED_Chlred_edge_median',
#  'MINMAX_MCARI1_std',
#  'MED_MCARI2_median',
#  'MINMAX_BWDRVI_mean',
#  'MED_PPR_median',
#  'MINMAX_CTVI_mean',
#  'river_area',
#  'CTVI_norm',
#  'hist_cold_sst',
#  'MINMAX_GLI_std',
#  'Green_norm',
#  'MED_CVI_std',
#  'sunElevation',
#  'VARIgreen_norm',
#  'Alteration_norm',
#  'cold_sst',
#  'DSWI_norm',
#  'MED_TIRS2_std',
#  'MINMAX_NLI_mean',
#  'MINMAX_SWIR1_std',
#  'MED_SWIR2_median',
#  'MED_mCRIRE_median',
#  'MED_VARIgreen_median',
#  'MINMAX_Alteration_std',
#  'MED_CI_median',
#  'MED_DSWI_5_std',
#  'MINMAX_RDVI_mean',
#  'Blue_norm',
#  'SWIR1_norm',
#  'MED_Ferrous_Silicates_std',
#  'MED_NLI_std',
#  'MINMAX_Cirededge_std',
#  'MED_DVIMSS_std',
#  'MINMAX_VARIgreen_std',
#  'PPR_norm',
#  'MED_PSNDc2_std',
#  'MED_NormR_std',
#  'MINMAX_CI_mean',
#  'MINMAX_AVI_mean',
#  'MED_mCRIG_std',
#  'MED_SWIR1_median',
#  'MINMAX_PSNDc2_mean',
#  'MED_NIR_std',
#  'mCRIRE_norm',
#  'MED_CTVI_median',
#  'MED_CRI550_std',
#  'MINMAX_TSAVI_std',
#  'MED_DSWI_std',
#  'MED_Cirededge_std',
#  'MINMAX_SLAVI_mean',
#  'MINMAX_DSWI_5_mean',
#  'MED_AVI_median',
#  'MED_D678_500_std',
#  'MCARI1_norm',
#  'MED_CTVI_std',
#  'MED_H_median',
#  'MINMAX_NormG_mean',
#  'DSWI_5_norm',
#  'MED_IF_median',
#  'MED_PPR_std',
#  'Landsat_num',
#  'MINMAX_SWIR2_mean',
#  'MED_Blue_std',
#  'MINMAX_CRI550_mean',
#  'MED_MCARI2_std',
#  'MED_Gossan_std',
#  'MINMAX_Fe3_mean',
#  'MINMAX_CI_std',
#  'MED_Green_std',
#  'MINMAX_Ferrous_Silicates_std',
#  'MED_Red_median',
#  'MINMAX_CRI550_std',
#  'MED_NIR_median',
#  'Cirededge_norm',
#  'MED_mCRIG_median',
#  'D678_500_norm',
#  'GEMI_norm',
#  'MED_Cirededge_median',
#  'MINMAX_SWIR2_std',
#  'MINMAX_Gossan_mean',
#  'TSAVI_norm',
#  'cliff_length',
#  'MINMAX_CVI_std',
#  'GARI_norm',
#  'MED_CRI550_median',
#  'MINMAX_Cigreen_std',
#  'MINMAX_Ferric_Oxides_mean',
#  'MINMAX_NIR_std',
#  'NLI_norm',
#  'MED_Alteration_std',
#  'GLI_norm',
#  'MINMAX_PPR_std',
#  'MINMAX_BWDRVI_std',
#  'MINMAX_Alteration_mean',
#  'MED_IR550_std',
#  'MINMAX_mCRIRE_std',
#  'MED_SLAVI_std',
#  'Red_norm',
#  'MINMAX_Blue_mean',
#  'MINMAX_NIR_mean',
#  'Salinity_annual',
#  'MED_NormR_median',
#  'MINMAX_D678_500_std',
#  'MED_Ferrous_Silicates_median',
#  'MED_AVI_std',
#  'MED_RDVI_std',
#  'MED_SLAVI_median',
#  'MINMAX_TIRS2_std',
#  'MINMAX_NormR_std',
#  'MINMAX_SLAVI_std',
#  'MED_IF_std',
#  'MINMAX_Cigreen_mean',
#  'MINMAX_H_std',
#  'MINMAX_MCARI1_mean',
#  'fetch',
#  'MED_Chlgreen_std',
#  'TIRS1_norm',
#  'beach_length',
#  'MED_Blue_median',
#  'MED_MCARI1_median',
#  'river_dist',
#  'MINMAX_GVMI_std',
#  'MINMAX_DSWI_mean',
#  'CRI550_norm',
#  'area',
#  'MED_IR550_median',
#  'depth_original',
#  'NormR_norm',
#  'MED_BWDRVI_median',
#  'sst_ymd',
#  'MINMAX_H_mean',
#  'MED_EVI_std',
#  'MED_SIPI2_std',
#  'MED_EVI_median',
#  'MED_VARIgreen_std',
#  'MINMAX_TIRS2_mean',
#  'hist_warm_sst',
#  'MED_GARI_median',
#  'AVI_norm',
#  'MINMAX_IR550_mean',
#  'MINMAX_AVI_std',
#  'Gossan_norm',
#  'RDVI_norm',
#  'MINMAX_MVI_std',
#  'MED_GEMI_median',
#  'PSNDc2_norm',
#  'MINMAX_Green_std',
#  'MED_TIRS1_median',
#  'IR550_norm',
#  'MED_Fe3_std',
#  'MINMAX_mCRIG_std',
#  'MINMAX_NormG_std',
#  'MED_SWIR2_std',
#  'MINMAX_GLI_mean',
#  'MINMAX_Green_mean',
#  'MINMAX_GEMI_std',
#  'Ferrous_Silicates_norm',
#  'MED_mCRIRE_std',
#  'MED_TIRS2_median',
#  'MINMAX_CTVI_std',
#  'MED_Gossan_median',
#  'MINMAX_DVIMSS_std',
#  'MINMAX_NLI_std',
#  'MED_MVI_std',
#  'MINMAX_EVI_std',
#  'MINMAX_GARI_mean',
#  'MINMAX_SIPI2_std',
#  'coastal_dist',
#  'MINMAX_SIPI2_mean',
#  'MINMAX_VARIgreen_mean',
#  'warm_sst',
#  'MED_NormG_std',
#  'MED_CI_std',
#  'MINMAX_PSNDc2_std',
#  'SIPI2_norm',
#  'sst_diff',
#  'MINMAX_DVIMSS_mean',
#  'SWIR2_norm',
#  'year',
#  'MED_Red_std']

# %% [markdown]
# # CV

# %% [markdown]
# shap:
#
# https://data-analysis-stats.jp/%E6%A9%9F%E6%A2%B0%E5%AD%A6%E7%BF%92/%E6%A9%9F%E6%A2%B0%E5%AD%A6%E7%BF%92%E3%83%A2%E3%83%87%E3%83%AB%E3%82%92%E8%A7%A3%E9%87%88%E3%81%99%E3%82%8Bshap/

# %%
# train_date = train[["year", "month"]].copy()

# def convert_int_into_str(x):
#     x_str = str(int(x))
#     if len(x_str)==1:
#         return "0" + x_str
#     return x_str

# train_date["month_str"] = train_date["month"].apply(convert_int_into_str)
# train_date["year_month"] = (train_date["year"].astype(int).astype(str) + train_date["month_str"]).astype(int)
# train_date.head()

# %%
# year_month = train_date["year_month"]
# cv = []

# val_idx1 = (year_month >= 200901)&(year_month <200907)
# train_idx1 = ~val_idx1
# cv.append([train_idx1, val_idx1])

# val_idx2 = (year_month >= 200910)&(year_month <200912)
# train_idx2 = ~val_idx2
# cv.append([train_idx2, val_idx2])

# val_idx3 = (year_month >= 201006)&(year_month <201009)
# train_idx3 = ~val_idx3
# cv.append([train_idx3, val_idx3])

# val_idx4 = (year_month >= 201010)&(year_month <201101)
# train_idx4 = ~val_idx4
# cv.append([train_idx4, val_idx4])

# val_idx5 = (year_month >= 201909)&(year_month <201910)
# train_idx5 = ~val_idx5
# cv.append([train_idx5, val_idx5])

# %%
def my_cross_val_predict(df, df_test, y_name=None, y_raw_name=None, params=None, features=None, cv=None, split=5, eval_by_shap=True):
    # CVの結果を集約する変数
    results_rmse = []
    dict_learning_rate = {}
    fi_df = pd.DataFrame()
    fi_df['features'] = features

    # kfoldで5分割
    kfold = KFold(n_splits=split, shuffle=True, random_state=42)
    X = df[features].values
    y = df[y_name].values
    y_raw = df[y_raw_name].values

    # 同時にtestデータも予測する
    X_test = df_test[features].values
    y_pred_test_mean = np.zeros(len(X_test))

    y_pred_val_all = np.zeros(len(y))
    y_pred_val_all[:] = np.nan

    for i, (train_idx, val_idx) in enumerate(kfold.split(X)):
        print("###"*10)
        print(f"● CV{i}")
        print("###"*10)
        X_train = X[train_idx, :]
        y_train = y[train_idx]
        X_val = X[val_idx, :]
        y_val = y[val_idx]
        y_val_raw = y_raw[val_idx]

        train_dataset = lgb.Dataset(X_train,
                                    y_train,
                                    feature_name=features,)
        val_dataset = lgb.Dataset(X_val,
                                  y_val,
                                  feature_name=features,)
        
        evals_result = {}
        callbacks = [
            # lgb.log_evaluation(100),
            # lgb.early_stopping(200),
            lgb.record_evaluation(evals_result)
        ]

        # モデル作成
        model = lgb.train(params=params,
                          train_set=train_dataset,
                          valid_sets=[val_dataset],
                          callbacks=callbacks,
                          verbose_eval=500,)
        # valデータ予測
        y_pred_raw = model.predict(X_val)
        y_pred = np.expm1(y_pred_raw)
        y_pred[y_pred<0] = 0
        y_pred[y_pred>1] = 1
        print(np.average(y_pred))
        y_pred_val_all[val_idx] = y_pred
        # testデータ予測
        y_pred_test_raw = model.predict(X_test)
        y_pred_test = np.expm1(y_pred_test_raw)
        # この処理は最後にやる
        # y_pred_test[y_pred_test<0] = 0
        # y_pred_test[y_pred_test>1] = 1
        y_pred_test_mean += (y_pred_test / split)
        
        # RMSE計算
        rmse = np.sqrt(mean_squared_error(y_val_raw, y_pred))
        results_rmse.append(rmse)

        # 予測結果の可視化
        fig, ax = plt.subplots()
        ax.grid(alpha=0.2)
        ax.scatter(y_pred, y_val_raw, s=2)
        ax.set_xlabel("Pred")
        ax.set_ylabel("True")
        ax.set_xlim([0, 1])
        ax.set_ylim([0, 1])
        ax.set_title(f"val_{i}")
        plt.show()

        # 特徴量重要度の抽出
        fi_df[f"importance_cv{i}"] = model.feature_importance(importance_type='gain')
        dict_learning_rate[f"fold_{i}"] = np.array(evals_result['valid_0']['fair'])

        # shapで評価
        if eval_by_shap:
            df_X_val = pd.DataFrame(X_val, columns=features)
            explainer = shap.TreeExplainer(model)
            shap_values = explainer.shap_values(X=df_X_val)
            shap.summary_plot(shap_values, df_X_val)
        
    # 学習曲線の可視化
    print("###"*10)
    print("学習曲線")
    print("###"*10)
    fig, ax = plt.subplots()
    ax.grid(alpha=0.2)
    for key, value in dict_learning_rate.items():
        x = list(range(len(value)))
        ax.plot(x, value, label=key)
    ax.legend(loc="upper left", bbox_to_anchor=(1, 0.5))
    # ax.set_ylim([-0.05, 0.2])
    plt.show()

    # testデータの予測結果整理
    y_pred_test_mean[y_pred_test_mean<0] = 0
    y_pred_test_mean[y_pred_test_mean>1] = 1

    return results_rmse, fi_df, y_pred_test_mean, y_pred_val_all

# %%
def plot_results(results):
    x_list = [f"cv{i}" for i in range(5)]
    fig = plt.figure(figsize=(7, 4))
    ax = fig.add_subplot()
    ax.bar(x=x_list, height=results, label="RMSE", zorder=10)
    ax.set_ylabel("RMSE")
    # ax.set_ylim([0, 0.007])
    ax.grid(zorder=-10)
    ax.legend()
    plt.show()

# from: https://blog.amedama.jp/entry/lightgbm-cv-feature-importance
def plot_importance(fi_df, figsize=(10, 10)):
#     raw_importances = cvbooster.feature_importance(importance_type='gain')
    feature_name = fi_df.features.to_list()
    importance_df = pd.DataFrame(data=fi_df.iloc[:, 1:].values.T,
                             columns=feature_name)
    # 平均値でソートする
    sorted_indices = importance_df.mean(axis=0).sort_values(ascending=False).index
    sorted_importance_df = importance_df.loc[:, sorted_indices]
    print(sorted_importance_df.shape)
    # 上位をプロットする
#     PLOT_TOP_N = 40
    plot_cols = sorted_importance_df.columns[:50]
    _, ax = plt.subplots(figsize=figsize)
    ax.grid()
    ax.set_xscale('log')
    ax.set_ylabel('Feature')
    ax.set_xlabel('Importance')
    sns.boxplot(data=sorted_importance_df[plot_cols],
                orient='h',
                ax=ax)
    plt.show()

# %%
params = {
    'objective': 'fair',
    'metric': 'fair',
    'boosting_type': 'gbdt',
    'max_depth': 5,
    'n_estimators': 2000,
    'learning_rate': 0.01,
    # 'num_leaves': 50,
    # 'colsample_bytree': 0.6,
    # 'subsample': 0.5,
    'verbose': -1,
    'n_jobs': -1,
    'seed': 46,
}

results_rmse, fi_df, y_test_pred, train["y_pred"] = my_cross_val_predict(train, test, y_name="log_cover", y_raw_name="cover", params=params, features=features)
# Out:
# ##############################
# ● CV0
# ##############################
# [500]	valid_0's fair: 0.00398379
# [1000]	valid_0's fair: 0.00360245
# [1500]	valid_0's fair: 0.00340386
# [2000]	valid_0's fair: 0.00328228
# 0.17510624606619868
# ##############################
# ● CV1
# ##############################
# [500]	valid_0's fair: 0.00409792
# [1000]	valid_0's fair: 0.00370351
# [1500]	valid_0's fair: 0.00350685
# [2000]	valid_0's fair: 0.00336506
# 0.17631792548720313
# ##############################
# ● CV2
# ##############################
# [500]	valid_0's fair: 0.0040514
# [1000]	valid_0's fair: 0.0036753
# [1500]	valid_0's fair: 0.00345777
# [2000]	valid_0's fair: 0.00333525
# 0.17843413479514783
# ##############################
# ● CV3
# ##############################
# [500]	valid_0's fair: 0.00383385
# [1000]	valid_0's fair: 0.00339277
# [1500]	valid_0's fair: 0.00316811
# [2000]	valid_0's fair: 0.00304614
# 0.17566539367313708
# ##############################
# ● CV4
# ##############################
# [500]	valid_0's fair: 0.00436163
# [1000]	valid_0's fair: 0.0039445
# [1500]	valid_0's fair: 0.003702
# [2000]	valid_0's fair: 0.00355514
# 0.17553506129717156
# ##############################
# 学習曲線
# ##############################

# %%
for i, rmse in enumerate(results_rmse):
    print(f"CV{i}: {rmse:.3f}")
print(f"Average: {np.average(results_rmse):.3f}")
plot_results(results_rmse)
# Out:
# CV0: 0.118
# CV1: 0.122
# CV2: 0.120
# CV3: 0.115
# CV4: 0.124
# Average: 0.120

# %%
plot_importance(fi_df, figsize=(10, 12))
# Out:
# (5, 258)

# %% [markdown]
# # Sub作成

# %%
test_sub = pd.DataFrame(y_test_pred, columns=["pred"])
test_sub
# Out:
#           pred
# 0     0.144518
# 1     0.064569
# 2     0.545152
# 3     0.054461
# 4     0.121827
# ...        ...
# 4034  0.121681
# 4035  0.041376
# 4036  0.437419
# 4037  0.072165
# 4038  0.684624
#
# [4039 rows x 1 columns]

# %%
test_pred_mean = test_sub["pred"].mean()
test_pred_mean
# Out:
# 0.18219992394218212

# %%
test_sub2 = test_sub.copy()
public_mean = 0.09088
# test_sub["pred"] = test_sub["pred"] * (public_mean / test_pred_mean)
test_sub2["pred"] -= (test_pred_mean - public_mean)
test_sub2["pred"] = np.clip(test_sub2["pred"].values, 0, 1)
test_sub2
# Out:
#           pred
# 0     0.053198
# 1     0.000000
# 2     0.453832
# 3     0.000000
# 4     0.030507
# ...        ...
# 4034  0.030361
# 4035  0.000000
# 4036  0.346099
# 4037  0.000000
# 4038  0.593304
#
# [4039 rows x 1 columns]

# %%
print("pred_最小値:", test_sub["pred"].min())
print("pred_最大値:", test_sub["pred"].max())
print("pred_平均値:", test_sub["pred"].mean())
# Out:
# pred_最小値: 0.0
# pred_最大値: 0.8598299328806733
# pred_平均値: 0.18219992394218212

# %%
print("●後処理後")
print("pred_最小値:", test_sub2["pred"].min())
print("pred_最大値:", test_sub2["pred"].max())
print("pred_平均値:", test_sub2["pred"].mean())
# Out:
# ●後処理後
# pred_最小値: 0.0
# pred_最大値: 0.7685100089384912
# pred_平均値: 0.10681359866935497

# %%
if SAVE_SUB:
    test_sub.to_csv(SAVE_SUB_DIR / f"{SUB_FILE_NAME}.csv", header=False)
    test_sub2.to_csv(SAVE_SUB_DIR / f"{SUB_FILE_NAME}_mod.csv", header=False)

# %% [markdown]
# # 予測結果確認

# %%
def check_by_scatter(check_col):
    tmp1 = df_pred[train[check_col].isnull()]
    tmp2 = df_pred[~train[check_col].isnull()]
    fig, ax = plt.subplots(figsize=(7, 6))
    ax.grid(alpha=0.2, color="gray")
    ax.scatter(tmp2["y_pred"], tmp2["cover"], s=6, label=f"NOT Null", alpha=0.5)
    ax.scatter(tmp1["y_pred"], tmp1["cover"], s=6, label=f"Null", alpha=0.5)
    ax.set_xlabel("Pred")
    ax.set_ylabel("True")
    ax.set_title(check_col)
    ax.legend()
    plt.show()

# %%
df_pred = train[["cover", "y_pred"]]
score = np.sqrt(mean_squared_error(train['cover'].values, train['y_pred'].values))
print(f"全体のRMSE: {score:.04f}")
# Out:
# 全体のRMSE: 0.1197

# %%
check_col = "depth_original"
tmp1 = df_pred[train[check_col].isnull()]
tmp2 = df_pred[~train[check_col].isnull()]
score1 = np.sqrt(mean_squared_error(tmp1['cover'].values, tmp1['y_pred'].values))
score2 = np.sqrt(mean_squared_error(tmp2['cover'].values, tmp2['y_pred'].values))
print(f"●全体のRMSE ({check_col}がnull)")
print(f"　データ数: {len(tmp1)}")
print(f"　スコア: {score1:.04f}\n")
print(f"●全体のRMSE ({check_col}がnull以外)")
print(f"　データ数: {len(tmp2)}")
print(f"　スコア: {score2:.04f}\n")
print(f"テストデータで{check_col}がnullの割合")
print(f"　{(100*test[check_col].isnull().sum()/len(test)):.3f}%")
check_by_scatter(check_col)
# Out:
# ●全体のRMSE (depth_originalがnull)
# 　データ数: 9721
# 　スコア: 0.0916
#
# ●全体のRMSE (depth_originalがnull以外)
# 　データ数: 4419
# 　スコア: 0.1656
#
# テストデータでdepth_originalがnullの割合
# 　50.829%

# %%
check_col = "Blue_norm"
tmp1 = df_pred[train[check_col].isnull()]
tmp2 = df_pred[~train[check_col].isnull()]
score1 = np.sqrt(mean_squared_error(tmp1['cover'].values, tmp1['y_pred'].values))
score2 = np.sqrt(mean_squared_error(tmp2['cover'].values, tmp2['y_pred'].values))
print(f"●全体のRMSE ({check_col}がnull)")
print(f"　データ数: {len(tmp1)}")
print(f"　スコア: {score1:.04f}\n")
print(f"●全体のRMSE ({check_col}がnull以外)")
print(f"　データ数: {len(tmp2)}")
print(f"　スコア: {score2:.04f}\n")
print(f"テストデータで{check_col}がnullの割合")
print(f"　{(100*test[check_col].isnull().sum()/len(test)):.3f}%")
check_by_scatter(check_col)
# Out:
# ●全体のRMSE (Blue_normがnull)
# 　データ数: 3582
# 　スコア: 0.1250
#
# ●全体のRMSE (Blue_normがnull以外)
# 　データ数: 10558
# 　スコア: 0.1179
#
# テストデータでBlue_normがnullの割合
# 　25.576%

# %%
# check_col = "MED_AFRI1600"
# tmp1 = df_pred[train[check_col].isnull()]
# tmp2 = df_pred[~train[check_col].isnull()]
# score1 = np.sqrt(mean_squared_error(tmp1['cover'].values, tmp1['y_pred'].values))
# score2 = np.sqrt(mean_squared_error(tmp2['cover'].values, tmp2['y_pred'].values))
# print(f"●全体のRMSE ({check_col}がnull)")
# print(f"　データ数: {len(tmp1)}")
# print(f"　スコア: {score1:.04f}\n")
# print(f"●全体のRMSE ({check_col}がnull以外)")
# print(f"　データ数: {len(tmp2)}")
# print(f"　スコア: {score2:.04f}\n")
# print(f"テストデータで{check_col}がnullの割合")
# print(f"　{(100*test[check_col].isnull().sum()/len(test)):.3f}%")
# check_by_scatter(check_col)

# %%
# check_col = "MAX_NormG__median"
# tmp1 = df_pred[train[check_col].isnull()]
# tmp2 = df_pred[~train[check_col].isnull()]
# score1 = np.sqrt(mean_squared_error(tmp1['cover'].values, tmp1['y_pred'].values))
# score2 = np.sqrt(mean_squared_error(tmp2['cover'].values, tmp2['y_pred'].values))
# print(f"●全体のRMSE ({check_col}がnull)")
# print(f"　データ数: {len(tmp1)}")
# print(f"　スコア: {score1:.04f}\n")
# print(f"●全体のRMSE ({check_col}がnull以外)")
# print(f"　データ数: {len(tmp2)}")
# print(f"　スコア: {score2:.04f}\n")
# print(f"テストデータで{check_col}がnullの割合")
# print(f"　{(100*test[check_col].isnull().sum()/len(test)):.3f}%")
# check_by_scatter(check_col)

# %%
check_col = "depth"
tmp1 = df_pred[train[check_col].isnull()]
tmp2 = df_pred[~train[check_col].isnull()]
score1 = np.sqrt(mean_squared_error(tmp1['cover'].values, tmp1['y_pred'].values))
score2 = np.sqrt(mean_squared_error(tmp2['cover'].values, tmp2['y_pred'].values))
print(f"●全体のRMSE ({check_col}がnull)")
print(f"　データ数: {len(tmp1)}")
print(f"　スコア: {score1:.04f}\n")
print(f"●全体のRMSE ({check_col}がnull以外)")
print(f"　データ数: {len(tmp2)}")
print(f"　スコア: {score2:.04f}\n")
print(f"テストデータで{check_col}がnullの割合")
print(f"　{(100*test[check_col].isnull().sum()/len(test)):.3f}%")
check_by_scatter(check_col)
# Out:
# ●全体のRMSE (depthがnull)
# 　データ数: 291
# 　スコア: 0.0324
#
# ●全体のRMSE (depthがnull以外)
# 　データ数: 13849
# 　スコア: 0.1209
#
# テストデータでdepthがnullの割合
# 　0.545%

# %%
check_col = "Landsat_num"
tmp1 = df_pred[train[check_col]==7]
tmp2 = df_pred[train[check_col]==8]
score1 = np.sqrt(mean_squared_error(tmp1['cover'].values, tmp1['y_pred'].values))
score2 = np.sqrt(mean_squared_error(tmp2['cover'].values, tmp2['y_pred'].values))
print(f"●全体のRMSE ({check_col}==7)")
print(f"　データ数: {len(tmp1)}")
print(f"　スコア: {score1:.04f}\n")
print(f"●全体のRMSE ({check_col}==8)")
print(f"　データ数: {len(tmp2)}")
print(f"　スコア: {score2:.04f}\n")
print(f"テストデータで{check_col}==7の割合")
print(f"　{(100*(test[check_col]==7).sum()/len(test)):.3f}%")

fig, ax = plt.subplots(figsize=(7, 6))
ax.grid(alpha=0.2, color="gray")
ax.scatter(tmp2["y_pred"], tmp2["cover"], s=6, label=f"Landsat_num==8", alpha=0.5)
ax.scatter(tmp1["y_pred"], tmp1["cover"], s=6, label=f"Landsat_num==7", alpha=0.5)
ax.set_xlabel("Pred")
ax.set_ylabel("True")
ax.set_title(check_col)
ax.legend()
plt.show()
# Out:
# ●全体のRMSE (Landsat_num==7)
# 　データ数: 7343
# 　スコア: 0.0951
#
# ●全体のRMSE (Landsat_num==8)
# 　データ数: 3215
# 　スコア: 0.1581
#
# テストデータでLandsat_num==7の割合
# 　40.753%

# %%
if SAVE_DF:
    train.to_pickle(SAVE_DF_DIR / f"train_predicted_{SUB_FILE_NAME}.pkl")
