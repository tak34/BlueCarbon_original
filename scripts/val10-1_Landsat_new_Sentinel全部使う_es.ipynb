# %%
# !pip install shap
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting shap
#   Downloading shap-0.41.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (572 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.6/572.6 kB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from shap) (1.22.4)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: tqdm>4.25.0 in /usr/local/lib/python3.10/dist-packages (from shap) (4.65.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap) (0.56.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from shap) (1.10.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from shap) (1.5.3)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.10/dist-packages (from shap) (23.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from shap) (1.2.2)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap) (2.2.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba->shap) (67.7.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap) (0.39.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->shap) (1.16.0)
# Installing collected packages: slicer, shap
# Successfully installed shap-0.41.0 slicer-0.0.7

# %%
import lightgbm as lgb
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import numpy as np
import pandas as pd
import seaborn as sns
import datetime as dt
from pathlib import Path
import warnings
import os
import random
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
from tqdm.notebook import tqdm

import shap

# %%
# plt.rcParams['font.family'] = "MS Gothic"
warnings.simplefilter('ignore')

# %%
def fix_all_seeds(seed):
    np.random.seed(seed)
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    
fix_all_seeds(0)

# %%
# Config
SUB_FILE_NAME = "val10-1"
SAVE_SUB = True
SAVE_SUB_DIR = Path("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/sub_20230225")
SAVE_DF = True
SAVE_DF_DIR = Path("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/Val_20230429")

# %% [markdown]
# # データ読み込み

# %%
train = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/train.pkl")
test = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/test.pkl")
sub = pd.read_csv("/content/drive/MyDrive/Kaggle/BlueCarbon/raw/submit_example.csv")

# 特徴抽出後のデータ
umap_basic_train = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/FE_20230417/20230417_umap_basic_train.pkl")
umap_basic_test = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/FE_20230417/20230417_umap_basic_test.pkl")
train_sentinel = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/FE_20230417/20230428_train_sentinel_minmaxDiff.pkl")
test_sentinel = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/FE_20230417/20230428_test_sentinel_minmaxDiff.pkl")
train_landsat_2000to2020 = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/FE_20230417/20230429_train_landsat2_2000to2020.pkl")
test_landsat_2000to2020 = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/FE_20230417/20230429_test_landsat2_2000to2020.pkl")
train_landsat_minmax = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/FE_20230417/20230428_train_landsat_minmax.pkl")
test_landsat_minmax = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/FE_20230417/20230428_test_landsat_minmax.pkl")

train.head(2)
# Out:
#          lat         lon  area                 YMD    year  month  cover  \
# 0  24.989140  125.243164  20.0            20110926  2011.0    9.0  0.050
# 1  26.996172  127.912025  40.0  2009.7.6-2009.7.28  2009.0    7.0  0.725
#
#    depth_original  cliff_length  aicial_length  ...  MIN_NormG_2020  \
# 0             NaN           0.0       0.000000  ...        0.507961
# 1             NaN           0.0       0.478772  ...        0.353645
#
#    MIN_NormR_2020  MIN_PPR_2020  MIN_PSNDc2_2020  MIN_RDVI_2020  MIN_IF_2020  \
# 0        0.287288     -0.278071        -0.808075      -2.341663     2.353039
# 1        0.245048     -0.100556        -0.771423      -3.282602     4.672225
#
#    MIN_SLAVI_2020  MIN_SIPI2_2020  MIN_VARIgreen_2020   mesh20
# 0       95.142525        3.728732           -2.405135  3725_10
# 1      174.767501       -0.571513            0.448861  4027_13
#
# [2 rows x 3464 columns]

# %%
sub.head(2)
# Out:
#    0  0.47
# 0  1  0.68
# 1  2  0.25

# %% [markdown]
# # 前処理

# %% [markdown]
# ## 対数変換

# %%
train[f"log_cover"] = np.log1p(train["cover"])

# %% [markdown]
# ## 特徴抽出後のデータを結合

# %%
print(train.shape)
print(train_landsat_minmax.shape)
print(test.shape)
print(test_landsat_minmax.shape)
train_landsat_minmax.head(2)
# Out:
# (14140, 3465)
# (14140, 50)
# (4039, 3463)
# (4039, 50)
#    MINMAX_MVI  MINMAX_Chlred_edge  MINMAX_NLI  MINMAX_IF  MINMAX_GEMI  \
# 0   -0.498732           -0.031920    1.075848   1.225176     0.018427
# 1    0.698608            1.080161   -0.089137  -1.235533     0.525556
#
#    MINMAX_Chlgreen  MINMAX_CVI  MINMAX_DSWI_5  MINMAX_TSAVI  MINMAX_PSNDc2  \
# 0         0.065996     0.91124       0.839658      1.035656       1.000000
# 1         1.083810    -0.57457      -0.393703     -0.195017      -0.575291
#
#    ...  MINMAX_EVI  MINMAX_GVMI  MINMAX_RDVI  MINMAX_PPR  MINMAX_SIPI2  \
# 0  ...    0.558870     0.176156     0.345818    1.035576      0.350692
# 1  ...    2.011747     0.262679    -0.418989   -0.841783      0.968533
#
#    MINMAX_Cigreen  MINMAX_D678_500  MINMAX_DVIMSS  MINMAX_Green  \
# 0        0.960665        -0.223362       1.000000      1.052035
# 1       -0.482458        -0.112053      -1.535718     -0.357916
#
#    MINMAX_Alteration
# 0            3.30233
# 1           -0.12575
#
# [2 rows x 50 columns]

# %%
train = train.join([
    umap_basic_train,
    train_sentinel,
    train_landsat_minmax,
    train_landsat_2000to2020,
])
test = test.join([
    umap_basic_test,
    test_sentinel,
    test_landsat_minmax,
    test_landsat_2000to2020,
])
train.head(2)
# Out:
#          lat         lon  area                 YMD    year  month  cover  \
# 0  24.989140  125.243164  20.0            20110926  2011.0    9.0  0.050
# 1  26.996172  127.912025  40.0  2009.7.6-2009.7.28  2009.0    7.0  0.725
#
#    depth_original  cliff_length  aicial_length  ...  MINMAX_MCARI2__mean  \
# 0             NaN           0.0       0.000000  ...            -0.006201
# 1             NaN           0.0       0.478772  ...            -0.775479
#
#    MINMAX_MCARI2__std  MED_NormR_median  MED_NormR_std  MINMAX_NormR__mean  \
# 0            1.087738          0.222131       0.699859           -0.086431
# 1            0.251864          0.904064       1.205264           -0.222484
#
#    MINMAX_NormR__std  MED_TIRS2_median  MED_TIRS2_std  MINMAX_TIRS2__mean  \
# 0           1.010979          0.470200       0.632177           -0.219153
# 1           0.889441         -0.002017       0.795383           -0.719698
#
#    MINMAX_TIRS2__std
# 0           0.892955
# 1           0.899809
#
# [2 rows x 3792 columns]

# %%
umap_basic_train.head()
# Out:
#         dim0      dim1  temp_monthly
# 0   1.788618  6.597842          27.9
# 1 -10.111396  6.170877          29.2
# 2  21.165592  6.679852          25.3
# 3  -6.996612  9.728025          16.7
# 4  -6.822807  9.109682          16.7

# %% [markdown]
# ## 使用する特徴量

# %%
# 被度文献データ、海洋環境要因データ、landsat使用
# YMDは使わない
cols_base = train.columns.to_list()[:25]
cols_landsat = train.columns.to_list()[25:88]
cols_landsat_2000to2020 = train_landsat_2000to2020.columns.to_list()
cols_landsat_minmax = train_landsat_minmax.columns.to_list()

cols_sentinel = train.columns.to_list()[88:313]
cols_sentinel = [col for col in cols_sentinel if "MED" in col]
cols_sentinel_minmax = train_sentinel.columns.to_list()

cols_umap = ["temp_monthly"]

cols_use =\
 cols_base +\
 cols_landsat +\
 cols_landsat_2000to2020 +\
 cols_landsat_minmax +\
 cols_sentinel +\
 cols_sentinel_minmax +\
 ["log_cover"] # + cols_sentinel

cols_remove = [
    "YMD",
    "month",
    "Date_Acquired",
    "Landsat_StartTime",
    "PRODUCT_ID",
    "mesh20"
]
cols_use = [col for col in cols_use if not col in cols_remove]

# 重複を省く（一応）
cols_use = list(set(cols_use))

cols_use
# Out:
# ['MINMAX_SWIR1__mean',
#  'MINMAX_BWDRVI__mean',
#  'MINMAXDiff_ExG',
#  'MINMAX_mCRIRE__mean',
#  'MINMAXDiff_BGI',
#  'MED_NIR_median',
#  'RDVI',
#  'MINMAXDiff_B07',
#  'MINMAXDiff_TCI',
#  'MINMAX_D678_500__mean',
#  'MINMAX_NLI__mean',
#  'MED_IR550_std',
#  'MED_SWIR2_median',
#  'MED_MSBI',
#  'MINMAX_Cirededge',
#  'MINMAX_NormG__std',
#  'MINMAX_TIRS1__mean',
#  'MINMAX_Alteration',
#  'MED_NDRE',
#  'NDVI',
#  'MVI',
#  'MINMAXDiff_SB550',
#  'MINMAX_Fe3',
#  'NLI',
#  'MED_RDI',
#  'cliff_length',
#  'MED_MYVI',
#  'MINMAX_Green',
#  'MED_B05',
#  'MINMAX_NIR__std',
#  'MINMAX_CRI550',
#  'MINMAXDiff_Rededge1',
#  'MED_B03',
#  'MED_mCRIRE_std',
#  'SIPI2',
#  'MED_Fe3_median',
#  'MED_PPR_median',
#  'MINMAX_DSWI',
#  'MINMAX_SWIR2',
#  'MED_RGR',
#  'MINMAXDiff_B05',
#  'MED_Green_std',
#  'MINMAX_DVIMSS',
#  'MINMAX_DSWI__mean',
#  'MINMAXDiff_MSR670',
#  'MINMAX_CI__std',
#  'VARIgreen',
#  'MED_RDVI_std',
#  'MED_NormR_std',
#  'MINMAXDiff_NDII',
#  'MED_Ferric_Oxides_median',
#  'MINMAXDiff_GARI',
#  'MINMAX_Red',
#  'MED_MCARI_OSAVI',
#  'MED_mCRIG_median',
#  'MINMAXDiff_CRred',
#  'river_area',
#  'MED_NDFI2',
#  'Fe3',
#  'MINMAX_Ferric_Oxides__std',
#  'MED_Blue_median',
#  'MINMAX_MCARI1__std',
#  'MINMAXDiff_B06',
#  'MED_CIgreen',
#  'Green',
#  'CVI',
#  'MINMAXDiff_Datt1',
#  'MED_mCRIRE_median',
#  'MINMAXDiff_GI',
#  'Red',
#  'MED_TSAVI_std',
#  'MINMAX_NLI__std',
#  'MED_Chlred_edge',
#  'MINMAXDiff_NDRE',
#  'MED_Cigreen_std',
#  'MED_CVI_median',
#  'MINMAXDiff_AFRI1600',
#  'MINMAXDiff_B03',
#  'MED_B04',
#  'IF',
#  'MINMAX_PSNDc2__std',
#  'MINMAX_VARIgreen__mean',
#  'MINMAX_NormR',
#  'MED_MCARI2',
#  'MED_SWIR2_std',
#  'MED_MNSI',
#  'MINMAX_Red__mean',
#  'Alteration',
#  'MED_MVI',
#  'warm_sst',
#  'MED_MSR670',
#  'MINMAX_EVI__mean',
#  'sst_annual',
#  'sst_ymd',
#  'MED_DSWI_std',
#  'MINMAX_RDVI__std',
#  'MINMAX_mCRIG__mean',
#  'NBR2',
#  'MINMAX_IR550__mean',
#  'MINMAXDiff_BRI',
#  'MED_NormG_std',
#  'MED_PSSRc2',
#  'MED_MCARI1_median',
#  'MED_GRNDVI',
#  'MINMAXDiff_NDFI2',
#  'MED_SLAVI_median',
#  'EVI',
#  'MED_NDWI2',
#  'MINMAX_Blue__mean',
#  'MED_TSAVI_median',
#  'MINMAXDiff_MVI',
#  'MED_D678_500_std',
#  'MINMAX_GVMI__mean',
#  'MED_RDVI_median',
#  'MINMAX_IR550__std',
#  'D678_500',
#  'MINMAX_SWIR1',
#  'MINMAXDiff_D678_500',
#  'MED_TIRS2_std',
#  'MINMAX_CVI__mean',
#  'MINMAXDiff_MGVI',
#  'MINMAXDiff_CARI',
#  'MED_VARIgreen_std',
#  'MED_PSNDc2_std',
#  'MINMAX_Blue__std',
#  'SAVI',
#  'MED_NDVIre',
#  'MINMAX_PPR__mean',
#  'MINMAX_Chlgreen__std',
#  'MED_DVIMSS_std',
#  'MINMAXDiff_IPVI',
#  'MED_MIRBI',
#  'MINMAX_Alteration__std',
#  'MINMAXDiff_CLD',
#  'MED_MSI',
#  'CRI550',
#  'MSAVI',
#  'Ferric_Oxides',
#  'MINMAXDiff_GRNDVI',
#  'MED_Red_std',
#  'MED_Ferrous_Silicates_std',
#  'MED_CARI',
#  'MED_NDSI',
#  'MED_Bcc',
#  'MED_CVI',
#  'MINMAX_Ferric_Oxides__mean',
#  'NDWI',
#  'MED_NIR_std',
#  'Blue',
#  'NBR',
#  'MED_GARI',
#  'MINMAX_MCARI2__mean',
#  'river_dist',
#  'MED_GVMI_std',
#  'MINMAX_Red__std',
#  'MED_GVMI',
#  'MINMAX_IF__mean',
#  'MINMAX_Ferrous_Silicates',
#  'MINMAX_AVI',
#  'MINMAX_MVI__std',
#  'DSWI_5',
#  'MED_DSWI_5_median',
#  'MED_Green_median',
#  'MINMAX_DVIMSS__mean',
#  'MINMAXDiff_MSI',
#  'MINMAX_H',
#  'MED_TCI',
#  'MED_SB550',
#  'MED_H_std',
#  'MINMAXDiff_ARVI',
#  'MED_ARVI',
#  'PSNDc2',
#  'Gossan',
#  'MINMAXDiff_MYVI',
#  'MED_Chlred_edge_median',
#  'MINMAX_GARI__mean',
#  'MED_SWIR1_median',
#  'MINMAXDiff_GVMI',
#  'MED_GEMI_std',
#  'Salinity_annual',
#  'MED_D678_500',
#  'MINMAX_TIRS2__std',
#  'MINMAXDiff_NDSI',
#  'MED_B02',
#  'MINMAXDiff_GLI',
#  'MED_mSR',
#  'MINMAXDiff_MCARI2',
#  'MED_NormG_median',
#  'MINMAX_BWDRVI__std',
#  'MED_PPR_std',
#  'MED_B12',
#  'MINMAX_GVMI',
#  'MINMAX_SWIR1__std',
#  'MED_BRI',
#  'MCARI2',
#  'MED_MCARI1_std',
#  'MED_DVIMSS_median',
#  'MED_Chlgreen_std',
#  'MINMAX_Chlred_edge__std',
#  'TIRS2',
#  'MED_DVI',
#  'MED_DSWI_median',
#  'MED_Fe3_std',
#  'MED_IF_median',
#  'MED_Alteration_median',
#  'coast_length',
#  'MINMAXDiff_AVI',
#  'MED_BWDRVI_std',
#  'MED_Alteration_std',
#  'MINMAX_AVI__std',
#  'MINMAXDiff_B11',
#  'Chlgreen',
#  'MINMAX_AVI__mean',
#  'MINMAX_NormR__std',
#  'hist_cold_sst',
#  'MINMAXDiff_CIrededge',
#  'MED_Ferric_Oxides_std',
#  'MED_GARI_median',
#  'MINMAX_CVI',
#  'MED_IF',
#  'MINMAXDiff_Bcc',
#  'MINMAX_Cigreen__mean',
#  'MED_Datt4',
#  'MED_EVI',
#  'DVIMSS',
#  'MINMAX_CI__mean',
#  'MINMAXDiff_RDI',
#  'MED_IF_std',
#  'MED_Chlgreen_median',
#  'MED_Chlred_edge_std',
#  'MED_NLI_std',
#  'MED_Cirededge_std',
#  'CI',
#  'GLI',
#  'CTVI',
#  'MINMAX_Cigreen',
#  'MINMAXDiff_B04',
#  'NIR',
#  'MED_PSNDc2_median',
#  'MED_Datt1',
#  'fetch',
#  'MED_CTVI_median',
#  'SLAVI',
#  'MINMAX_TIRS1',
#  'TIRS1',
#  'MINMAX_TIRS1__std',
#  'MED_ARI',
#  'MINMAXDiff_GDVI',
#  'MINMAXDiff_NDVI2',
#  'MINMAX_DSWI_5__std',
#  'PPR',
#  'MINMAXDiff_BWDRVI',
#  'MED_SIPI2_median',
#  'area',
#  'MED_AVI',
#  'MINMAX_GARI__std',
#  'MED_D678_500_median',
#  'MED_GLI_std',
#  'MINMAX_TSAVI',
#  'MINMAX_Cirededge__mean',
#  'MINMAX_SIPI2__mean',
#  'MINMAX_Gossan',
#  'MINMAX_PSNDc2',
#  'MED_NDBI',
#  'MINMAXDiff_Chlgreen',
#  'MINMAX_Ferrous_Silicates__std',
#  'MINMAX_Blue',
#  'MINMAX_D678_500__std',
#  'SWIR1',
#  'MINMAX_IR550',
#  'MINMAXDiff_BNDVI',
#  'MINMAX_SLAVI__mean',
#  'MED_BOA',
#  'MINMAX_SLAVI__std',
#  'NormG',
#  'cold_sst',
#  'MINMAX_Green__std',
#  'MED_NormR_median',
#  'MINMAX_CTVI__mean',
#  'MINMAX_TSAVI__mean',
#  'DSWI',
#  'MED_AFRI1600',
#  'MINMAX_IF',
#  'MINMAX_CI',
#  'MINMAX_Chlred_edge__mean',
#  'MINMAXDiff_CIgreen',
#  'MED_SLAVI_std',
#  'MED_Blue_std',
#  'MINMAX_VARIgreen__std',
#  'MED_GLI_median',
#  'MINMAXDiff_Datt4',
#  'MINMAX_MVI__mean',
#  'MED_GEMI_median',
#  'MED_EVI_median',
#  'MED_GARI_std',
#  'MINMAX_EVI__std',
#  'sunAzimuth',
#  'MINMAX_NormR__mean',
#  'MED_CRI550_std',
#  'MED_CI_median',
#  'MED_Gossan_median',
#  'mCRIRE',
#  'MED_CRI550_median',
#  'MINMAXDiff_MSBI',
#  'log_cover',
#  'H',
#  'MINMAX_MCARI1',
#  'MINMAXDiff_DVI',
#  'MED_BGI',
#  'MINMAXDiff_Chlred_edge',
#  'MED_CIrededge',
#  'depth_original',
#  'MINMAX_NLI',
#  'MED_GLI',
#  'MINMAXDiff_B8A',
#  'MINMAX_SLAVI',
#  'MINMAX_H__mean',
#  'TSAVI',
#  'MINMAX_Chlgreen',
#  'MED_WVP',
#  'MINMAXDiff_IF',
#  'MINMAX_GLI',
#  'MINMAX_Fe3__mean',
#  'MINMAX_GEMI',
#  'MINMAXDiff_MCARI_OSAVI',
#  'MINMAX_mCRIRE__std',
#  'Landsat_num',
#  'MED_mNDVI',
#  'MINMAXDiff_NDWI2',
#  'MINMAXDiff_SR672_708',
#  'MED_MCARI_MTVI2',
#  'MINMAX_PPR',
#  'MED_GVMI_median',
#  'lon',
#  'MED_TIRS2_median',
#  'MED_B11',
#  'MINMAX_GEMI__std',
#  'coastal_dist',
#  'MED_NDVI2',
#  'GARI',
#  'MINMAX_NIR',
#  'MINMAXDiff_MIRBI',
#  'MINMAX_Ferric_Oxides',
#  'MINMAX_MCARI2__std',
#  'MED_CSI',
#  'MINMAX_Chlgreen__mean',
#  'MED_CLD',
#  'MINMAX_MCARI1__mean',
#  'MINMAX_Green__mean',
#  'MINMAX_EVI',
#  'MINMAXDiff_ARI',
#  'MED_Rededge1',
#  'MINMAX_DVIMSS__std',
#  'MINMAX_CTVI',
#  'MED_IPVI',
#  'MINMAX_NormG',
#  'MINMAX_RDVI__mean',
#  'MINMAX_mCRIG__std',
#  'MINMAX_TIRS2',
#  'MINMAX_H__std',
#  'MED_BB1',
#  'GEMI',
#  'MED_SWIR1_std',
#  'MINMAX_SIPI2__std',
#  'MINMAX_NormG__mean',
#  'Chlred_edge',
#  'MINMAXDiff_B02',
#  'MINMAX_RDVI',
#  'MINMAXDiff_IO',
#  'MED_BNDVI',
#  'MED_CTVI_std',
#  'MED_Red_median',
#  'Ferrous_Silicates',
#  'MINMAXDiff_NBR2',
#  'MINMAX_CRI550__std',
#  'MINMAX_Ferrous_Silicates__mean',
#  'MED_DSWI_5_std',
#  'MINMAX_Gossan__mean',
#  'MED_TIRS1_std',
#  'MINMAX_SWIR2__std',
#  'MINMAX_BWDRVI',
#  'MINMAXDiff_WVP',
#  'MINMAXDiff_NDBI',
#  'MED_Cirededge_median',
#  'MINMAXDiff_EVI',
#  'MED_Gossan_std',
#  'GVMI',
#  'MED_MCARI2_std',
#  'MED_AVI_median',
#  'MINMAX_SIPI2',
#  'MINMAX_Fe3__std',
#  'MED_MVI_median',
#  'MED_B07',
#  'MINMAXDiff_mSR',
#  'MED_GDVI',
#  'MINMAX_Chlred_edge',
#  'MED_BWDRVI_median',
#  'MED_Cigreen_median',
#  'MED_EVI_std',
#  'MINMAXDiff_mNDVI',
#  'MINMAXDiff_PSSRc2',
#  'MINMAX_CTVI__std',
#  'MED_VARIgreen_median',
#  'MINMAXDiff_B12',
#  'MED_NBR2',
#  'MED_NLI_median',
#  'MED_CRred',
#  'sunElevation',
#  'MED_B8A',
#  'MINMAX_SWIR2__mean',
#  'hist_warm_sst',
#  'IR550',
#  'MINMAX_MVI',
#  'SWIR2',
#  'MED_Ferrous_Silicates_median',
#  'MINMAX_GEMI__mean',
#  'MED_GI',
#  'MED_MCARI2_median',
#  'MINMAX_D678_500',
#  'MINMAX_DSWI_5__mean',
#  'MED_IR550_median',
#  'AVI',
#  'MINMAX_mCRIRE',
#  'MED_NDII',
#  'MINMAX_CVI__std',
#  'MINMAX_TSAVI__std',
#  'Cirededge',
#  'MINMAXDiff_AOT',
#  'MED_BWDRVI',
#  'MED_MGVI',
#  'Cigreen',
#  'MINMAX_NIR__mean',
#  'MINMAX_Gossan__std',
#  'MINMAX_CRI550__mean',
#  'MED_H_median',
#  'MINMAX_Cigreen__std',
#  'BWDRVI',
#  'MINMAX_DSWI_5',
#  'mCRIG',
#  'MINMAX_PPR__std',
#  'year',
#  'MINMAXDiff_CSI',
#  'MINMAX_GLI__std',
#  'MINMAX_GARI',
#  'MINMAX_DSWI__std',
#  'sst_diff',
#  'MINMAX_Alteration__mean',
#  'MED_mCRIG_std',
#  'MINMAX_MCARI2',
#  'MINMAXDiff_BB1',
#  'MINMAXDiff_MCARI_MTVI2',
#  'MED_IO',
#  'MED_AOT',
#  'MINMAXDiff_MNSI',
#  'MINMAX_IF__std',
#  'MCARI1',
#  'MINMAX_GLI__mean',
#  'depth',
#  'MINMAX_TIRS2__mean',
#  'beach_length',
#  'MINMAXDiff_NDVIre',
#  'MED_SR672_708',
#  'MINMAXDiff_BOA',
#  'MINMAX_mCRIG',
#  'MED_CI_std',
#  'MINMAX_PSNDc2__mean',
#  'MED_MVI_std',
#  'MED_AVI_std',
#  'MED_SIPI2_std',
#  'MED_ExG',
#  'lat',
#  'NormR',
#  'cover',
#  'NDMI',
#  'MINMAX_GVMI__std',
#  'MED_CVI_std',
#  'aicial_length',
#  'MED_TIRS1_median',
#  'MINMAX_VARIgreen',
#  'MINMAX_Cirededge__std',
#  'MINMAXDiff_RGR',
#  'MED_B06']

# %%
train = train[cols_use]
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14140 entries, 0 to 14139
# Columns: 482 entries, MINMAX_SWIR1__mean to MED_B06
# dtypes: float32(232), float64(250)
# memory usage: 39.5 MB

# %%
cols_obj = ["cover", "log_cover"]
features = [col for col in cols_use if col not in cols_obj]
print("特徴量の数：", len(features))
# Out:
# 特徴量の数： 480

# %%
corr = train[features].corr()
threshold = 0.98
drop_numeric_cols=[]
pair=[]
for col in features:
    # if col in cat_features:
    #     continue
    for i in range(len(corr)):
        if abs(corr[col].iloc[i]) >= threshold and col != features[i] :
            print(f"{col} and {features[i]} are highly correlated...") 
            if col not in pair:
                pair.append(col)
                pair.append(features[i])
                drop_numeric_cols.append(col) 
features = list(set(features)-set(drop_numeric_cols))
print(f"Dropping columns : {drop_numeric_cols}")
print("特徴量の数：", len(features))
del drop_numeric_cols
del pair

features
# Out:
# MINMAX_SWIR1__mean and MINMAX_SWIR2__mean are highly correlated...
# MINMAX_BWDRVI__mean and MINMAX_PSNDc2__mean are highly correlated...
# MINMAXDiff_B07 and MINMAXDiff_B06 are highly correlated...
# MINMAXDiff_B07 and MINMAXDiff_B8A are highly correlated...
# MINMAX_Cirededge and MINMAX_TSAVI are highly correlated...
# NDVI and SAVI are highly correlated...
# NDVI and TSAVI are highly correlated...
# MINMAXDiff_SB550 and MINMAXDiff_B03 are highly correlated...
# MED_RDI and MED_MSI are highly correlated...
# MED_B05 and MED_CARI are highly correlated...
# MED_B03 and MED_SB550 are highly correlated...
# MINMAX_DSWI__mean and MINMAX_DSWI_5__mean are highly correlated...
# MINMAXDiff_NDII and MINMAXDiff_NDVI2 are highly correlated...
# MINMAXDiff_NDII and MINMAXDiff_NDBI are highly correlated...
# MINMAXDiff_B06 and MINMAXDiff_B07 are highly correlated...
# MINMAXDiff_B06 and MINMAXDiff_B8A are highly correlated...
# CVI and Cigreen are highly correlated...
# CVI and BWDRVI are highly correlated...
# MED_Cigreen_std and MED_CVI_std are highly correlated...
# MED_CVI_median and MED_Cigreen_median are highly correlated...
# MINMAXDiff_B03 and MINMAXDiff_SB550 are highly correlated...
# MED_B04 and MED_TCI are highly correlated...
# MED_B04 and MED_BB1 are highly correlated...
# MINMAX_PSNDc2__std and MINMAX_BWDRVI__std are highly correlated...
# sst_annual and cold_sst are highly correlated...
# sst_annual and lat are highly correlated...
# MED_GRNDVI and MED_NDWI2 are highly correlated...
# MED_NDWI2 and MED_GRNDVI are highly correlated...
# MED_NDWI2 and MED_IPVI are highly correlated...
# MED_PSNDc2_std and MED_BWDRVI_std are highly correlated...
# SAVI and NDVI are highly correlated...
# SAVI and TSAVI are highly correlated...
# MINMAXDiff_IPVI and MINMAXDiff_NDWI2 are highly correlated...
# MED_MSI and MED_RDI are highly correlated...
# MSAVI and Chlred_edge are highly correlated...
# Ferric_Oxides and NDMI are highly correlated...
# MED_CARI and MED_B05 are highly correlated...
# NBR and GVMI are highly correlated...
# DSWI_5 and NormG are highly correlated...
# MED_DSWI_5_median and MED_NormG_median are highly correlated...
# MINMAXDiff_MSI and MINMAXDiff_RDI are highly correlated...
# MED_TCI and MED_B04 are highly correlated...
# MED_TCI and MED_BB1 are highly correlated...
# MED_SB550 and MED_B03 are highly correlated...
# PSNDc2 and BWDRVI are highly correlated...
# MED_NormG_median and MED_DSWI_5_median are highly correlated...
# MINMAX_BWDRVI__std and MINMAX_PSNDc2__std are highly correlated...
# MED_BWDRVI_std and MED_PSNDc2_std are highly correlated...
# MINMAXDiff_RDI and MINMAXDiff_MSI are highly correlated...
# MINMAXDiff_B04 and MINMAXDiff_BB1 are highly correlated...
# MED_PSNDc2_median and MED_BWDRVI_median are highly correlated...
# MINMAXDiff_NDVI2 and MINMAXDiff_NDII are highly correlated...
# MINMAXDiff_NDVI2 and MINMAXDiff_NDBI are highly correlated...
# MINMAX_TSAVI and MINMAX_Cirededge are highly correlated...
# MINMAX_Cirededge__mean and MINMAX_TSAVI__mean are highly correlated...
# MINMAX_PSNDc2 and MINMAX_BWDRVI are highly correlated...
# MED_NDBI and MED_NDII are highly correlated...
# MINMAXDiff_BNDVI and MINMAXDiff_NDWI2 are highly correlated...
# NormG and DSWI_5 are highly correlated...
# cold_sst and sst_annual are highly correlated...
# cold_sst and lon are highly correlated...
# cold_sst and lat are highly correlated...
# MINMAX_TSAVI__mean and MINMAX_Cirededge__mean are highly correlated...
# MINMAXDiff_B8A and MINMAXDiff_B07 are highly correlated...
# MINMAXDiff_B8A and MINMAXDiff_B06 are highly correlated...
# TSAVI and NDVI are highly correlated...
# TSAVI and SAVI are highly correlated...
# MINMAXDiff_NDWI2 and MINMAXDiff_IPVI are highly correlated...
# MINMAXDiff_NDWI2 and MINMAXDiff_BNDVI are highly correlated...
# lon and cold_sst are highly correlated...
# MED_IPVI and MED_NDWI2 are highly correlated...
# MED_BB1 and MED_B04 are highly correlated...
# MED_BB1 and MED_TCI are highly correlated...
# Chlred_edge and MSAVI are highly correlated...
# MINMAX_BWDRVI and MINMAX_PSNDc2 are highly correlated...
# MINMAXDiff_NDBI and MINMAXDiff_NDII are highly correlated...
# MINMAXDiff_NDBI and MINMAXDiff_NDVI2 are highly correlated...
# GVMI and NBR are highly correlated...
# MED_B07 and MED_B8A are highly correlated...
# MED_B07 and MED_B06 are highly correlated...
# MED_BWDRVI_median and MED_PSNDc2_median are highly correlated...
# MED_Cigreen_median and MED_CVI_median are highly correlated...
# MED_B8A and MED_B07 are highly correlated...
# MED_B8A and MED_B06 are highly correlated...
# MINMAX_SWIR2__mean and MINMAX_SWIR1__mean are highly correlated...
# MINMAX_DSWI_5__mean and MINMAX_DSWI__mean are highly correlated...
# MED_NDII and MED_NDBI are highly correlated...
# Cigreen and CVI are highly correlated...
# BWDRVI and CVI are highly correlated...
# BWDRVI and PSNDc2 are highly correlated...
# MINMAXDiff_BB1 and MINMAXDiff_B04 are highly correlated...
# MINMAX_PSNDc2__mean and MINMAX_BWDRVI__mean are highly correlated...
# lat and sst_annual are highly correlated...
# lat and cold_sst are highly correlated...
# NDMI and Ferric_Oxides are highly correlated...
# MED_CVI_std and MED_Cigreen_std are highly correlated...
# MED_B06 and MED_B07 are highly correlated...
# MED_B06 and MED_B8A are highly correlated...
# Dropping columns : ['MINMAX_SWIR1__mean', 'MINMAX_BWDRVI__mean', 'MINMAXDiff_B07', 'MINMAX_Cirededge', 'NDVI', 'MINMAXDiff_SB550', 'MED_RDI', 'MED_B05', 'MED_B03', 'MINMAX_DSWI__mean', 'MINMAXDiff_NDII', 'CVI', 'MED_Cigreen_std', 'MED_CVI_median', 'MED_B04', 'MINMAX_PSNDc2__std', 'sst_annual', 'MED_GRNDVI', 'MED_PSNDc2_std', 'MINMAXDiff_IPVI', 'MSAVI', 'Ferric_Oxides', 'NBR', 'DSWI_5', 'MED_DSWI_5_median', 'MINMAXDiff_MSI', 'PSNDc2', 'MINMAXDiff_B04', 'MED_PSNDc2_median', 'MINMAX_Cirededge__mean', 'MINMAX_PSNDc2', 'MED_NDBI', 'MINMAXDiff_BNDVI', 'MINMAXDiff_B8A', 'TSAVI', 'lon', 'MED_IPVI', 'MED_BB1', 'MINMAXDiff_NDBI', 'MED_B07', 'lat', 'MED_B06']
# 特徴量の数： 438
# ['CTVI',
#  'MINMAX_Cigreen',
#  'MINMAXDiff_ExG',
#  'NIR',
#  'MINMAX_mCRIRE__mean',
#  'MED_Datt1',
#  'fetch',
#  'MED_CTVI_median',
#  'SLAVI',
#  'MINMAXDiff_BGI',
#  'MED_NIR_median',
#  'MINMAX_TIRS1',
#  'TIRS1',
#  'RDVI',
#  'MINMAX_TIRS1__std',
#  'MED_ARI',
#  'MINMAXDiff_TCI',
#  'MINMAX_D678_500__mean',
#  'MINMAXDiff_GDVI',
#  'MINMAX_NLI__mean',
#  'MINMAXDiff_NDVI2',
#  'MINMAX_DSWI_5__std',
#  'PPR',
#  'MED_IR550_std',
#  'MINMAXDiff_BWDRVI',
#  'MED_SIPI2_median',
#  'area',
#  'MED_SWIR2_median',
#  'MED_MSBI',
#  'MINMAX_Cirededge__std',
#  'MINMAX_NormG__std',
#  'MED_AVI',
#  'MINMAX_TIRS1__mean',
#  'MINMAX_Alteration',
#  'MINMAX_GARI__std',
#  'MED_NDRE',
#  'MED_D678_500_median',
#  'MED_GLI_std',
#  'MVI',
#  'MINMAX_TSAVI',
#  'MINMAX_Fe3',
#  'MINMAX_SIPI2__mean',
#  'NLI',
#  'MINMAX_Gossan',
#  'cliff_length',
#  'MED_MYVI',
#  'MINMAX_Green',
#  'MINMAXDiff_Chlgreen',
#  'MINMAX_Ferrous_Silicates__std',
#  'MINMAX_NIR__std',
#  'MINMAX_CRI550',
#  'MINMAX_Blue',
#  'MINMAX_D678_500__std',
#  'MINMAXDiff_Rededge1',
#  'SWIR1',
#  'MINMAX_IR550',
#  'MED_mCRIRE_std',
#  'SIPI2',
#  'MED_Fe3_median',
#  'MINMAX_SLAVI__mean',
#  'MED_PPR_median',
#  'MED_BOA',
#  'MINMAX_DSWI',
#  'MINMAX_SWIR2',
#  'MINMAX_SLAVI__std',
#  'NormG',
#  'cold_sst',
#  'MED_RGR',
#  'MINMAX_Green__std',
#  'MED_NormR_median',
#  'MINMAXDiff_B05',
#  'MED_Green_std',
#  'MINMAX_CTVI__mean',
#  'MINMAX_DVIMSS',
#  'MINMAX_TSAVI__mean',
#  'DSWI',
#  'MINMAXDiff_MSR670',
#  'MED_AFRI1600',
#  'MINMAX_IF',
#  'MINMAX_CI__std',
#  'VARIgreen',
#  'MED_RDVI_std',
#  'MINMAX_CI',
#  'MED_NormR_std',
#  'MINMAX_Chlred_edge__mean',
#  'MINMAXDiff_CIgreen',
#  'MED_SLAVI_std',
#  'MED_Ferric_Oxides_median',
#  'MINMAXDiff_GARI',
#  'MED_Blue_std',
#  'MINMAX_Red',
#  'MINMAX_VARIgreen__std',
#  'MINMAX_MCARI2',
#  'MED_GLI_median',
#  'MED_MCARI_OSAVI',
#  'MED_mCRIG_median',
#  'MINMAXDiff_Datt4',
#  'MINMAXDiff_CRred',
#  'MINMAX_MVI__mean',
#  'MED_GEMI_median',
#  'MED_EVI_median',
#  'MED_GARI_std',
#  'river_area',
#  'MED_NDFI2',
#  'MINMAX_EVI__std',
#  'Fe3',
#  'MINMAX_Ferric_Oxides__std',
#  'MED_Blue_median',
#  'MINMAX_MCARI1__std',
#  'MINMAXDiff_B06',
#  'sunAzimuth',
#  'MINMAX_NormR__mean',
#  'MED_CIgreen',
#  'Green',
#  'MED_CRI550_std',
#  'MED_CI_median',
#  'MINMAXDiff_Datt1',
#  'MED_mCRIRE_median',
#  'MED_Gossan_median',
#  'MINMAXDiff_GI',
#  'mCRIRE',
#  'Red',
#  'MED_CRI550_median',
#  'MINMAXDiff_MSBI',
#  'MED_TSAVI_std',
#  'MINMAX_NLI__std',
#  'MED_Chlred_edge',
#  'H',
#  'MINMAX_MCARI1',
#  'MINMAXDiff_DVI',
#  'MED_BGI',
#  'MINMAXDiff_NDRE',
#  'MINMAXDiff_Chlred_edge',
#  'MED_CIrededge',
#  'depth_original',
#  'MINMAX_NLI',
#  'MINMAXDiff_AFRI1600',
#  'MED_GLI',
#  'MINMAXDiff_B03',
#  'MINMAX_SLAVI',
#  'MINMAX_H__mean',
#  'IF',
#  'MINMAX_Chlgreen',
#  'MED_WVP',
#  'MINMAXDiff_IF',
#  'MINMAX_VARIgreen__mean',
#  'MINMAX_GLI',
#  'MINMAX_Fe3__mean',
#  'MINMAX_GEMI',
#  'MINMAXDiff_MCARI_OSAVI',
#  'MINMAX_mCRIRE__std',
#  'Landsat_num',
#  'MED_mNDVI',
#  'MINMAXDiff_NDWI2',
#  'MINMAXDiff_SR672_708',
#  'MINMAX_NormR',
#  'MED_MCARI2',
#  'MED_MCARI_MTVI2',
#  'MED_SWIR2_std',
#  'MINMAX_PPR',
#  'MED_MNSI',
#  'MED_GVMI_median',
#  'MED_TIRS2_median',
#  'MED_B11',
#  'MINMAX_GEMI__std',
#  'MINMAX_Red__mean',
#  'coastal_dist',
#  'Alteration',
#  'MED_NDVI2',
#  'GARI',
#  'MED_MVI',
#  'MINMAX_NIR',
#  'MINMAXDiff_MIRBI',
#  'MINMAX_Ferric_Oxides',
#  'warm_sst',
#  'MINMAX_MCARI2__std',
#  'MED_MSR670',
#  'MED_CSI',
#  'MINMAX_Chlgreen__mean',
#  'MED_CLD',
#  'MINMAX_EVI__mean',
#  'MINMAX_MCARI1__mean',
#  'MINMAX_Green__mean',
#  'MINMAX_EVI',
#  'MINMAXDiff_ARI',
#  'MED_Rededge1',
#  'MINMAX_DVIMSS__std',
#  'MINMAX_CTVI',
#  'MINMAX_NormG',
#  'sst_ymd',
#  'MED_DSWI_std',
#  'MINMAX_RDVI__std',
#  'MINMAX_RDVI__mean',
#  'MINMAX_mCRIG__mean',
#  'NBR2',
#  'MINMAX_IR550__mean',
#  'MINMAXDiff_BRI',
#  'MED_NormG_std',
#  'MINMAX_mCRIG__std',
#  'MINMAX_TIRS2',
#  'MINMAX_H__std',
#  'GEMI',
#  'MED_PSSRc2',
#  'MED_MCARI1_median',
#  'MED_SWIR1_std',
#  'MINMAX_SIPI2__std',
#  'MINMAXDiff_NDFI2',
#  'MINMAX_NormG__mean',
#  'MED_SLAVI_median',
#  'Chlred_edge',
#  'EVI',
#  'MED_NDWI2',
#  'MINMAXDiff_B02',
#  'MINMAX_RDVI',
#  'MINMAX_Blue__mean',
#  'MED_TSAVI_median',
#  'MINMAXDiff_IO',
#  'MED_BNDVI',
#  'MED_CTVI_std',
#  'MED_Red_median',
#  'MINMAXDiff_MVI',
#  'MED_D678_500_std',
#  'Ferrous_Silicates',
#  'MINMAX_GVMI__mean',
#  'MED_RDVI_median',
#  'MINMAXDiff_NBR2',
#  'MINMAX_CRI550__std',
#  'MINMAX_IR550__std',
#  'MINMAX_Ferrous_Silicates__mean',
#  'MED_DSWI_5_std',
#  'MINMAX_Gossan__mean',
#  'MED_TIRS1_std',
#  'MINMAX_SWIR2__std',
#  'MINMAX_BWDRVI',
#  'MINMAXDiff_WVP',
#  'MED_Cirededge_median',
#  'MINMAXDiff_EVI',
#  'D678_500',
#  'MINMAX_SWIR1',
#  'MINMAXDiff_D678_500',
#  'MED_TIRS2_std',
#  'MINMAX_CVI__mean',
#  'MINMAXDiff_MGVI',
#  'MED_Gossan_std',
#  'GVMI',
#  'MINMAXDiff_CARI',
#  'MED_MCARI2_std',
#  'MED_AVI_median',
#  'MED_VARIgreen_std',
#  'MINMAX_SIPI2',
#  'MINMAX_Blue__std',
#  'SAVI',
#  'MINMAX_Fe3__std',
#  'MED_NDVIre',
#  'MINMAX_PPR__mean',
#  'MED_MVI_median',
#  'MINMAX_Chlgreen__std',
#  'MINMAXDiff_mSR',
#  'MED_GDVI',
#  'MED_DVIMSS_std',
#  'MED_MIRBI',
#  'MINMAX_Alteration__std',
#  'MINMAX_Chlred_edge',
#  'MINMAXDiff_CLD',
#  'MED_BWDRVI_median',
#  'MED_MSI',
#  'CRI550',
#  'MED_Cigreen_median',
#  'MED_EVI_std',
#  'MINMAXDiff_GRNDVI',
#  'GLI',
#  'MED_Red_std',
#  'MINMAXDiff_mNDVI',
#  'MED_Ferrous_Silicates_std',
#  'MED_CARI',
#  'MINMAXDiff_PSSRc2',
#  'MED_NDSI',
#  'MED_Bcc',
#  'MINMAX_CTVI__std',
#  'MED_CVI',
#  'MED_VARIgreen_median',
#  'MINMAX_Ferric_Oxides__mean',
#  'NDWI',
#  'MINMAXDiff_B12',
#  'MED_NIR_std',
#  'MED_NBR2',
#  'MED_NLI_median',
#  'MED_CRred',
#  'Blue',
#  'MED_GARI',
#  'sunElevation',
#  'MED_B8A',
#  'MINMAX_SWIR2__mean',
#  'MINMAX_MCARI2__mean',
#  'river_dist',
#  'MED_GVMI_std',
#  'MINMAX_Red__std',
#  'hist_warm_sst',
#  'MED_GVMI',
#  'MINMAX_IF__mean',
#  'MINMAX_Ferrous_Silicates',
#  'MINMAX_AVI',
#  'IR550',
#  'MINMAX_MVI',
#  'SWIR2',
#  'MINMAX_MVI__std',
#  'MED_Green_median',
#  'MED_Ferrous_Silicates_median',
#  'MINMAX_GEMI__mean',
#  'MED_GI',
#  'MED_MCARI2_median',
#  'MINMAX_DVIMSS__mean',
#  'MINMAX_D678_500',
#  'MINMAX_DSWI_5__mean',
#  'MINMAX_H',
#  'MED_TCI',
#  'MED_IR550_median',
#  'MED_SB550',
#  'AVI',
#  'MINMAX_mCRIRE',
#  'MED_NDII',
#  'MED_H_std',
#  'MINMAXDiff_ARVI',
#  'MINMAX_CVI__std',
#  'MED_ARVI',
#  'MINMAX_TSAVI__std',
#  'Cirededge',
#  'MINMAXDiff_AOT',
#  'MED_BWDRVI',
#  'MED_MGVI',
#  'Gossan',
#  'MINMAXDiff_MYVI',
#  'MED_Chlred_edge_median',
#  'Cigreen',
#  'MINMAX_NIR__mean',
#  'MINMAX_GARI__mean',
#  'MED_SWIR1_median',
#  'MINMAXDiff_GVMI',
#  'MINMAX_Gossan__std',
#  'MED_GEMI_std',
#  'Salinity_annual',
#  'MED_D678_500',
#  'MINMAX_CRI550__mean',
#  'MINMAX_TIRS2__std',
#  'MED_H_median',
#  'MINMAX_Cigreen__std',
#  'MINMAXDiff_NDSI',
#  'MED_B02',
#  'BWDRVI',
#  'MINMAX_DSWI_5',
#  'MINMAXDiff_GLI',
#  'mCRIG',
#  'MINMAX_PPR__std',
#  'year',
#  'MINMAXDiff_CSI',
#  'MED_mSR',
#  'MINMAXDiff_MCARI2',
#  'MED_NormG_median',
#  'MINMAX_BWDRVI__std',
#  'MINMAX_GLI__std',
#  'MINMAX_GARI',
#  'MED_PPR_std',
#  'MINMAX_DSWI__std',
#  'sst_diff',
#  'MED_B12',
#  'MINMAX_GVMI',
#  'MINMAX_SWIR1__std',
#  'MED_BRI',
#  'MINMAX_Alteration__mean',
#  'MED_mCRIG_std',
#  'MINMAXDiff_BB1',
#  'MINMAXDiff_MCARI_MTVI2',
#  'MCARI2',
#  'MED_MCARI1_std',
#  'MED_IO',
#  'MED_DVIMSS_median',
#  'MED_Chlgreen_std',
#  'MINMAX_Chlred_edge__std',
#  'TIRS2',
#  'MED_AOT',
#  'MED_DVI',
#  'MED_DSWI_median',
#  'MED_Fe3_std',
#  'MINMAXDiff_MNSI',
#  'MED_IF_median',
#  'MED_Alteration_median',
#  'MINMAX_IF__std',
#  'MCARI1',
#  'coast_length',
#  'MINMAXDiff_AVI',
#  'MINMAX_GLI__mean',
#  'depth',
#  'MINMAX_TIRS2__mean',
#  'MED_BWDRVI_std',
#  'beach_length',
#  'MED_Alteration_std',
#  'MINMAXDiff_NDVIre',
#  'MED_SR672_708',
#  'MINMAX_AVI__std',
#  'MINMAXDiff_B11',
#  'Chlgreen',
#  'MINMAX_AVI__mean',
#  'MINMAXDiff_BOA',
#  'MINMAX_NormR__std',
#  'hist_cold_sst',
#  'MINMAX_mCRIG',
#  'MED_CI_std',
#  'MINMAX_PSNDc2__mean',
#  'MED_MVI_std',
#  'MINMAXDiff_CIrededge',
#  'MED_AVI_std',
#  'MED_Ferric_Oxides_std',
#  'MED_GARI_median',
#  'MINMAX_CVI',
#  'MED_IF',
#  'MINMAXDiff_Bcc',
#  'MED_SIPI2_std',
#  'MINMAX_Cigreen__mean',
#  'MED_Datt4',
#  'MED_EVI',
#  'MED_ExG',
#  'NormR',
#  'DVIMSS',
#  'MINMAX_CI__mean',
#  'NDMI',
#  'MINMAX_GVMI__std',
#  'MINMAXDiff_RDI',
#  'MED_IF_std',
#  'MED_CVI_std',
#  'aicial_length',
#  'MED_Chlgreen_median',
#  'MED_TIRS1_median',
#  'MED_Chlred_edge_std',
#  'MED_NLI_std',
#  'MINMAX_VARIgreen',
#  'MINMAXDiff_RGR',
#  'MED_Cirededge_std',
#  'CI']

# %% [markdown]
# # CV

# %% [markdown]
# shap:
#
# https://data-analysis-stats.jp/%E6%A9%9F%E6%A2%B0%E5%AD%A6%E7%BF%92/%E6%A9%9F%E6%A2%B0%E5%AD%A6%E7%BF%92%E3%83%A2%E3%83%87%E3%83%AB%E3%82%92%E8%A7%A3%E9%87%88%E3%81%99%E3%82%8Bshap/

# %%
# train_date = train[["year", "month"]].copy()

# def convert_int_into_str(x):
#     x_str = str(int(x))
#     if len(x_str)==1:
#         return "0" + x_str
#     return x_str

# train_date["month_str"] = train_date["month"].apply(convert_int_into_str)
# train_date["year_month"] = (train_date["year"].astype(int).astype(str) + train_date["month_str"]).astype(int)
# train_date.head()

# %%
# year_month = train_date["year_month"]
# cv = []

# val_idx1 = (year_month >= 200901)&(year_month <200907)
# train_idx1 = ~val_idx1
# cv.append([train_idx1, val_idx1])

# val_idx2 = (year_month >= 200910)&(year_month <200912)
# train_idx2 = ~val_idx2
# cv.append([train_idx2, val_idx2])

# val_idx3 = (year_month >= 201006)&(year_month <201009)
# train_idx3 = ~val_idx3
# cv.append([train_idx3, val_idx3])

# val_idx4 = (year_month >= 201010)&(year_month <201101)
# train_idx4 = ~val_idx4
# cv.append([train_idx4, val_idx4])

# val_idx5 = (year_month >= 201909)&(year_month <201910)
# train_idx5 = ~val_idx5
# cv.append([train_idx5, val_idx5])

# %%
def my_cross_val_predict(df, df_test, y_name=None, y_raw_name=None, params=None, features=None, cv=None, split=5, eval_by_shap=True):
    # CVの結果を集約する変数
    results_rmse = []
    dict_learning_rate = {}
    fi_df = pd.DataFrame()
    fi_df['features'] = features

    # kfoldで5分割
    kfold = KFold(n_splits=split, shuffle=True, random_state=42)
    X = df[features].values
    y = df[y_name].values
    y_raw = df[y_raw_name].values

    # 同時にtestデータも予測する
    X_test = df_test[features].values
    y_pred_test_mean = np.zeros(len(X_test))

    y_pred_val_all = np.zeros(len(y))
    y_pred_val_all[:] = np.nan

    for i, (train_idx, val_idx) in enumerate(kfold.split(X)):
        print("###"*10)
        print(f"● CV{i}")
        print("###"*10)
        X_train = X[train_idx, :]
        y_train = y[train_idx]
        X_val = X[val_idx, :]
        y_val = y[val_idx]
        y_val_raw = y_raw[val_idx]

        train_dataset = lgb.Dataset(X_train,
                                    y_train,
                                    feature_name=features,)
        val_dataset = lgb.Dataset(X_val,
                                  y_val,
                                  feature_name=features,)
        
        evals_result = {}
        callbacks = [
            # lgb.log_evaluation(100),
            lgb.early_stopping(100),
            lgb.record_evaluation(evals_result)
        ]

        # モデル作成
        model = lgb.train(params=params,
                          train_set=train_dataset,
                          valid_sets=[val_dataset],
                          callbacks=callbacks,
                          verbose_eval=500,)
        # valデータ予測
        y_pred_raw = model.predict(X_val)
        y_pred = np.expm1(y_pred_raw)
        y_pred[y_pred<0] = 0
        y_pred[y_pred>1] = 1
        print(np.average(y_pred))
        y_pred_val_all[val_idx] = y_pred
        # testデータ予測
        y_pred_test_raw = model.predict(X_test)
        y_pred_test = np.expm1(y_pred_test_raw)
        # この処理は最後にやる
        # y_pred_test[y_pred_test<0] = 0
        # y_pred_test[y_pred_test>1] = 1
        y_pred_test_mean += (y_pred_test / split)
        
        # RMSE計算
        rmse = np.sqrt(mean_squared_error(y_val_raw, y_pred))
        results_rmse.append(rmse)

        # 予測結果の可視化
        fig, ax = plt.subplots()
        ax.grid(alpha=0.2)
        ax.scatter(y_pred, y_val_raw, s=2)
        ax.set_xlabel("Pred")
        ax.set_ylabel("True")
        ax.set_xlim([0, 1])
        ax.set_ylim([0, 1])
        ax.set_title(f"val_{i}")
        plt.show()

        # 特徴量重要度の抽出
        fi_df[f"importance_cv{i}"] = model.feature_importance(importance_type='gain')
        dict_learning_rate[f"fold_{i}"] = np.array(evals_result['valid_0']['fair'])

        # shapで評価
        if eval_by_shap:
            df_X_val = pd.DataFrame(X_val, columns=features)
            explainer = shap.TreeExplainer(model)
            shap_values = explainer.shap_values(X=df_X_val)
            shap.summary_plot(shap_values, df_X_val)
        
    # 学習曲線の可視化
    print("###"*10)
    print("学習曲線")
    print("###"*10)
    fig, ax = plt.subplots()
    ax.grid(alpha=0.2)
    for key, value in dict_learning_rate.items():
        x = list(range(len(value)))
        ax.plot(x, value, label=key)
    ax.legend(loc="upper left", bbox_to_anchor=(1, 0.5))
    # ax.set_ylim([-0.05, 0.2])
    plt.show()

    # testデータの予測結果整理
    y_pred_test_mean[y_pred_test_mean<0] = 0
    y_pred_test_mean[y_pred_test_mean>1] = 1

    return results_rmse, fi_df, y_pred_test_mean, y_pred_val_all

# %%
def plot_results(results):
    x_list = [f"cv{i}" for i in range(5)]
    fig = plt.figure(figsize=(7, 4))
    ax = fig.add_subplot()
    ax.bar(x=x_list, height=results, label="RMSE", zorder=10)
    ax.set_ylabel("RMSE")
    # ax.set_ylim([0, 0.007])
    ax.grid(zorder=-10)
    ax.legend()
    plt.show()

# from: https://blog.amedama.jp/entry/lightgbm-cv-feature-importance
def plot_importance(fi_df, figsize=(10, 10)):
#     raw_importances = cvbooster.feature_importance(importance_type='gain')
    feature_name = fi_df.features.to_list()
    importance_df = pd.DataFrame(data=fi_df.iloc[:, 1:].values.T,
                             columns=feature_name)
    # 平均値でソートする
    sorted_indices = importance_df.mean(axis=0).sort_values(ascending=False).index
    sorted_importance_df = importance_df.loc[:, sorted_indices]
    print(sorted_importance_df.shape)
    # 上位をプロットする
#     PLOT_TOP_N = 40
    plot_cols = sorted_importance_df.columns[:50]
    _, ax = plt.subplots(figsize=figsize)
    ax.grid()
    ax.set_xscale('log')
    ax.set_ylabel('Feature')
    ax.set_xlabel('Importance')
    sns.boxplot(data=sorted_importance_df[plot_cols],
                orient='h',
                ax=ax)
    plt.show()

# %%
params = {
    'objective': 'fair',
    'metric': 'fair',
    'boosting_type': 'gbdt',
    'max_depth': 9,
    'n_estimators': 10000,
    'learning_rate': 0.01,
    # 'num_leaves': 50,
    # 'colsample_bytree': 0.6,
    # 'subsample': 0.5,
    'verbose': -1,
    'n_jobs': -1,
    'seed': 46,
}

results_rmse, fi_df, y_test_pred, train["y_pred"] = my_cross_val_predict(train, test, y_name="log_cover", y_raw_name="cover", params=params, features=features)
# Out:
# ##############################
# ● CV0
# ##############################
# Training until validation scores don't improve for 100 rounds
# [500]	valid_0's fair: 0.0035348
# [1000]	valid_0's fair: 0.00320983
# [1500]	valid_0's fair: 0.00308125
# [2000]	valid_0's fair: 0.00302771
# [2500]	valid_0's fair: 0.00298917
# [3000]	valid_0's fair: 0.00296198
# [3500]	valid_0's fair: 0.00294657
# [4000]	valid_0's fair: 0.00293676
# [4500]	valid_0's fair: 0.00292763
# Early stopping, best iteration is:
# [4611]	valid_0's fair: 0.00292627
# 0.17658065396291436
# ##############################
# ● CV1
# ##############################
# Training until validation scores don't improve for 100 rounds
# [500]	valid_0's fair: 0.00362424
# [1000]	valid_0's fair: 0.003297
# [1500]	valid_0's fair: 0.00313064
# [2000]	valid_0's fair: 0.00304548
# [2500]	valid_0's fair: 0.00299061
# [3000]	valid_0's fair: 0.0029469
# [3500]	valid_0's fair: 0.00291468
# [4000]	valid_0's fair: 0.00289083
# [4500]	valid_0's fair: 0.00287254
# [5000]	valid_0's fair: 0.00285865
# [5500]	valid_0's fair: 0.00284566
# [6000]	valid_0's fair: 0.00283495
# [6500]	valid_0's fair: 0.00282753
# [7000]	valid_0's fair: 0.00282226
# [7500]	valid_0's fair: 0.00281562
# [8000]	valid_0's fair: 0.00281078
# [8500]	valid_0's fair: 0.00280553
# [9000]	valid_0's fair: 0.00280161
# [9500]	valid_0's fair: 0.00279904
# [10000]	valid_0's fair: 0.00279588
# Did not meet early stopping. Best iteration is:
# [10000]	valid_0's fair: 0.00279588
# 0.17908165467978154
# ##############################
# ● CV2
# ##############################
# Training until validation scores don't improve for 100 rounds
# [500]	valid_0's fair: 0.0035824
# [1000]	valid_0's fair: 0.00323309
# [1500]	valid_0's fair: 0.00310104
# [2000]	valid_0's fair: 0.00301755
# [2500]	valid_0's fair: 0.00297476
# [3000]	valid_0's fair: 0.00294406
# [3500]	valid_0's fair: 0.00292527
# [4000]	valid_0's fair: 0.0029123
# Early stopping, best iteration is:
# [4225]	valid_0's fair: 0.00290671
# 0.1800326779760818
# ##############################
# ● CV3
# ##############################
# Training until validation scores don't improve for 100 rounds
# [500]	valid_0's fair: 0.00332094
# [1000]	valid_0's fair: 0.00297616
# [1500]	valid_0's fair: 0.00283706
# [2000]	valid_0's fair: 0.00274724
# [2500]	valid_0's fair: 0.00269055
# [3000]	valid_0's fair: 0.0026439
# [3500]	valid_0's fair: 0.00260897
# [4000]	valid_0's fair: 0.00258625
# [4500]	valid_0's fair: 0.00256577
# [5000]	valid_0's fair: 0.00255136
# [5500]	valid_0's fair: 0.00254077
# [6000]	valid_0's fair: 0.00253465
# [6500]	valid_0's fair: 0.00252699
# [7000]	valid_0's fair: 0.00251969
# [7500]	valid_0's fair: 0.00251176
# [8000]	valid_0's fair: 0.00250883
# [8500]	valid_0's fair: 0.00250504
# [9000]	valid_0's fair: 0.00249999
# [9500]	valid_0's fair: 0.00249679
# [10000]	valid_0's fair: 0.00249379
# Did not meet early stopping. Best iteration is:
# [9998]	valid_0's fair: 0.00249378
# 0.17763253065892975
# ##############################
# ● CV4
# ##############################
# Training until validation scores don't improve for 100 rounds
# [500]	valid_0's fair: 0.00384114
# [1000]	valid_0's fair: 0.0034706
# [1500]	valid_0's fair: 0.0033028
# [2000]	valid_0's fair: 0.00320923
# [2500]	valid_0's fair: 0.00315523
# [3000]	valid_0's fair: 0.00311796
# [3500]	valid_0's fair: 0.00309409
# [4000]	valid_0's fair: 0.00307362
# [4500]	valid_0's fair: 0.00305373
# [5000]	valid_0's fair: 0.00304185
# [5500]	valid_0's fair: 0.00303219
# [6000]	valid_0's fair: 0.00302468
# [6500]	valid_0's fair: 0.00301903
# Early stopping, best iteration is:
# [6455]	valid_0's fair: 0.0030187
# 0.17831609512374433
# ##############################
# 学習曲線
# ##############################

# %%
for i, rmse in enumerate(results_rmse):
    print(f"CV{i}: {rmse:.3f}")
print(f"Average: {np.average(results_rmse):.3f}")
plot_results(results_rmse)
# Out:
# CV0: 0.112
# CV1: 0.111
# CV2: 0.112
# CV3: 0.104
# CV4: 0.113
# Average: 0.110

# %%
plot_importance(fi_df, figsize=(10, 12))
# Out:
# (5, 438)

# %% [markdown]
# # Sub作成

# %%
test_sub = pd.DataFrame(y_test_pred, columns=["pred"])
test_sub
# Out:
#           pred
# 0     0.101162
# 1     0.083306
# 2     0.474988
# 3     0.049145
# 4     0.122512
# ...        ...
# 4034  0.135465
# 4035  0.039711
# 4036  0.521066
# 4037  0.059307
# 4038  0.619547
#
# [4039 rows x 1 columns]

# %%
test_pred_mean = test_sub["pred"].mean()
test_pred_mean
# Out:
# 0.18121025441150618

# %%
test_sub2 = test_sub.copy()
public_mean = 0.09088
# test_sub["pred"] = test_sub["pred"] * (public_mean / test_pred_mean)
test_sub2["pred"] -= (test_pred_mean - public_mean)
test_sub2["pred"] = np.clip(test_sub2["pred"].values, 0, 1)
test_sub2
# Out:
#           pred
# 0     0.010832
# 1     0.000000
# 2     0.384658
# 3     0.000000
# 4     0.032181
# ...        ...
# 4034  0.045135
# 4035  0.000000
# 4036  0.430735
# 4037  0.000000
# 4038  0.529216
#
# [4039 rows x 1 columns]

# %%
print("pred_最小値:", test_sub["pred"].min())
print("pred_最大値:", test_sub["pred"].max())
print("pred_平均値:", test_sub["pred"].mean())
# Out:
# pred_最小値: 0.005511983828439557
# pred_最大値: 0.8040092162112694
# pred_平均値: 0.18121025441150618

# %%
print("●後処理後")
print("pred_最小値:", test_sub2["pred"].min())
print("pred_最大値:", test_sub2["pred"].max())
print("pred_平均値:", test_sub2["pred"].mean())
# Out:
# ●後処理後
# pred_最小値: 0.0
# pred_最大値: 0.7136789617997632
# pred_平均値: 0.10662775437829665

# %%
if SAVE_SUB:
    test_sub.to_csv(SAVE_SUB_DIR / f"{SUB_FILE_NAME}.csv", header=False)
    test_sub2.to_csv(SAVE_SUB_DIR / f"{SUB_FILE_NAME}_mod.csv", header=False)

# %% [markdown]
# # 予測結果確認

# %%
def check_by_scatter(check_col):
    tmp1 = df_pred[train[check_col].isnull()]
    tmp2 = df_pred[~train[check_col].isnull()]
    fig, ax = plt.subplots(figsize=(7, 6))
    ax.grid(alpha=0.2, color="gray")
    ax.scatter(tmp2["y_pred"], tmp2["cover"], s=6, label=f"NOT Null", alpha=0.5)
    ax.scatter(tmp1["y_pred"], tmp1["cover"], s=6, label=f"Null", alpha=0.5)
    ax.set_xlabel("Pred")
    ax.set_ylabel("True")
    ax.set_title(check_col)
    ax.legend()
    plt.show()

# %%
df_pred = train[["cover", "y_pred"]]
score = np.sqrt(mean_squared_error(train['cover'].values, train['y_pred'].values))
print(f"全体のRMSE: {score:.04f}")
# Out:
# 全体のRMSE: 0.1104

# %%
check_col = "depth_original"
tmp1 = df_pred[train[check_col].isnull()]
tmp2 = df_pred[~train[check_col].isnull()]
score1 = np.sqrt(mean_squared_error(tmp1['cover'].values, tmp1['y_pred'].values))
score2 = np.sqrt(mean_squared_error(tmp2['cover'].values, tmp2['y_pred'].values))
print(f"●全体のRMSE ({check_col}がnull)")
print(f"　データ数: {len(tmp1)}")
print(f"　スコア: {score1:.04f}\n")
print(f"●全体のRMSE ({check_col}がnull以外)")
print(f"　データ数: {len(tmp2)}")
print(f"　スコア: {score2:.04f}\n")
print(f"テストデータで{check_col}がnullの割合")
print(f"　{(100*test[check_col].isnull().sum()/len(test)):.3f}%")
check_by_scatter(check_col)
# Out:
# ●全体のRMSE (depth_originalがnull)
# 　データ数: 9721
# 　スコア: 0.0855
#
# ●全体のRMSE (depth_originalがnull以外)
# 　データ数: 4419
# 　スコア: 0.1515
#
# テストデータでdepth_originalがnullの割合
# 　50.829%

# %%
check_col = "Blue"
tmp1 = df_pred[train[check_col].isnull()]
tmp2 = df_pred[~train[check_col].isnull()]
score1 = np.sqrt(mean_squared_error(tmp1['cover'].values, tmp1['y_pred'].values))
score2 = np.sqrt(mean_squared_error(tmp2['cover'].values, tmp2['y_pred'].values))
print(f"●全体のRMSE ({check_col}がnull)")
print(f"　データ数: {len(tmp1)}")
print(f"　スコア: {score1:.04f}\n")
print(f"●全体のRMSE ({check_col}がnull以外)")
print(f"　データ数: {len(tmp2)}")
print(f"　スコア: {score2:.04f}\n")
print(f"テストデータで{check_col}がnullの割合")
print(f"　{(100*test[check_col].isnull().sum()/len(test)):.3f}%")
check_by_scatter(check_col)
# Out:
# ●全体のRMSE (Blueがnull)
# 　データ数: 3582
# 　スコア: 0.1196
#
# ●全体のRMSE (Blueがnull以外)
# 　データ数: 10558
# 　スコア: 0.1072
#
# テストデータでBlueがnullの割合
# 　27.804%

# %%
check_col = "MED_AFRI1600"
tmp1 = df_pred[train[check_col].isnull()]
tmp2 = df_pred[~train[check_col].isnull()]
score1 = np.sqrt(mean_squared_error(tmp1['cover'].values, tmp1['y_pred'].values))
score2 = np.sqrt(mean_squared_error(tmp2['cover'].values, tmp2['y_pred'].values))
print(f"●全体のRMSE ({check_col}がnull)")
print(f"　データ数: {len(tmp1)}")
print(f"　スコア: {score1:.04f}\n")
print(f"●全体のRMSE ({check_col}がnull以外)")
print(f"　データ数: {len(tmp2)}")
print(f"　スコア: {score2:.04f}\n")
print(f"テストデータで{check_col}がnullの割合")
print(f"　{(100*test[check_col].isnull().sum()/len(test)):.3f}%")
check_by_scatter(check_col)
# Out:
# ●全体のRMSE (MED_AFRI1600がnull)
# 　データ数: 291
# 　スコア: 0.0295
#
# ●全体のRMSE (MED_AFRI1600がnull以外)
# 　データ数: 13849
# 　スコア: 0.1115
#
# テストデータでMED_AFRI1600がnullの割合
# 　0.545%

# %%
check_col = "MAX_NormG__median"
tmp1 = df_pred[train[check_col].isnull()]
tmp2 = df_pred[~train[check_col].isnull()]
score1 = np.sqrt(mean_squared_error(tmp1['cover'].values, tmp1['y_pred'].values))
score2 = np.sqrt(mean_squared_error(tmp2['cover'].values, tmp2['y_pred'].values))
print(f"●全体のRMSE ({check_col}がnull)")
print(f"　データ数: {len(tmp1)}")
print(f"　スコア: {score1:.04f}\n")
print(f"●全体のRMSE ({check_col}がnull以外)")
print(f"　データ数: {len(tmp2)}")
print(f"　スコア: {score2:.04f}\n")
print(f"テストデータで{check_col}がnullの割合")
print(f"　{(100*test[check_col].isnull().sum()/len(test)):.3f}%")
check_by_scatter(check_col)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MAX_NormG__median'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-dacd3a1b1c62> in <cell line: 2>()
#       1 check_col = "MAX_NormG__median"
# ----> 2 tmp1 = df_pred[train[check_col].isnull()]
#       3 tmp2 = df_pred[~train[check_col].isnull()]
#       4 score1 = np.sqrt(mean_squared_error(tmp1['cover'].values, tmp1['y_pred'].values))
#       5 score2 = np.sqrt(mean_squared_error(tmp2['cover'].values, tmp2['y_pred'].values))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'MAX_NormG__median'

# %%
check_col = "depth"
tmp1 = df_pred[train[check_col].isnull()]
tmp2 = df_pred[~train[check_col].isnull()]
score1 = np.sqrt(mean_squared_error(tmp1['cover'].values, tmp1['y_pred'].values))
score2 = np.sqrt(mean_squared_error(tmp2['cover'].values, tmp2['y_pred'].values))
print(f"●全体のRMSE ({check_col}がnull)")
print(f"　データ数: {len(tmp1)}")
print(f"　スコア: {score1:.04f}\n")
print(f"●全体のRMSE ({check_col}がnull以外)")
print(f"　データ数: {len(tmp2)}")
print(f"　スコア: {score2:.04f}\n")
print(f"テストデータで{check_col}がnullの割合")
print(f"　{(100*test[check_col].isnull().sum()/len(test)):.3f}%")
check_by_scatter(check_col)

# %%
check_col = "Landsat_num"
tmp1 = df_pred[train[check_col]==7]
tmp2 = df_pred[train[check_col]==8]
score1 = np.sqrt(mean_squared_error(tmp1['cover'].values, tmp1['y_pred'].values))
score2 = np.sqrt(mean_squared_error(tmp2['cover'].values, tmp2['y_pred'].values))
print(f"●全体のRMSE ({check_col}==7)")
print(f"　データ数: {len(tmp1)}")
print(f"　スコア: {score1:.04f}\n")
print(f"●全体のRMSE ({check_col}==8)")
print(f"　データ数: {len(tmp2)}")
print(f"　スコア: {score2:.04f}\n")
print(f"テストデータで{check_col}==7の割合")
print(f"　{(100*(test[check_col]==7).sum()/len(test)):.3f}%")

fig, ax = plt.subplots(figsize=(7, 6))
ax.grid(alpha=0.2, color="gray")
ax.scatter(tmp2["y_pred"], tmp2["cover"], s=6, label=f"Landsat_num==8", alpha=0.5)
ax.scatter(tmp1["y_pred"], tmp1["cover"], s=6, label=f"Landsat_num==7", alpha=0.5)
ax.set_xlabel("Pred")
ax.set_ylabel("True")
ax.set_title(check_col)
ax.legend()
plt.show()

# %%
if SAVE_DF:
    train.to_pickle(SAVE_DF_DIR / f"train_predicted_{SUB_FILE_NAME}.pkl")
