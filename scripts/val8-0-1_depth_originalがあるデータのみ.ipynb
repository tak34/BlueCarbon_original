# %%
# !pip install shap
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting shap
#   Downloading shap-0.41.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (572 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.6/572.6 kB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from shap) (1.5.3)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.10/dist-packages (from shap) (23.1)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap) (0.56.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from shap) (1.2.2)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: tqdm>4.25.0 in /usr/local/lib/python3.10/dist-packages (from shap) (4.65.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap) (2.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from shap) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from shap) (1.10.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba->shap) (67.7.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (1.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->shap) (1.16.0)
# Installing collected packages: slicer, shap
# Successfully installed shap-0.41.0 slicer-0.0.7

# %%
import lightgbm as lgb
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import numpy as np
import pandas as pd
import seaborn as sns
import datetime as dt
from pathlib import Path
import warnings
import os
import random
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
from tqdm.notebook import tqdm

import shap

# %%
# plt.rcParams['font.family'] = "MS Gothic"
warnings.simplefilter('ignore')

# %%
def fix_all_seeds(seed):
    np.random.seed(seed)
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    
fix_all_seeds(0)

# %%
# Config
SUB_FILE_NAME = "val8-0"
SAVE_SUB = False
SAVE_SUB_DIR = Path("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/sub_20230225")
SAVE_DF = False
SAVE_DF_DIR = Path("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/Val_20230429")

# %% [markdown]
# # データ読み込み

# %%
train = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/train.pkl")
test = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/test.pkl")
sub = pd.read_csv("/content/drive/MyDrive/Kaggle/BlueCarbon/raw/submit_example.csv")

# 特徴抽出後のデータ
umap_basic_train = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/FE_20230417/20230417_umap_basic_train.pkl")
umap_basic_test = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/FE_20230417/20230417_umap_basic_test.pkl")
train_sentinel = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/FE_20230417/20230428_train_sentinel_minmaxDiff.pkl")
test_sentinel = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/FE_20230417/20230428_test_sentinel_minmaxDiff.pkl")
train_landsat_2000to2020 = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/FE_20230417/20230428_train_landsat_2000to2020.pkl")
test_landsat_2000to2020 = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/FE_20230417/20230428_test_landsat_2000to2020.pkl")
train_landsat_minmax = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/FE_20230417/20230428_train_landsat_minmax.pkl")
test_landsat_minmax = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/FE_20230417/20230428_test_landsat_minmax.pkl")

train.head(2)
# Out:
#          lat         lon  area                 YMD    year  month  cover  \
# 0  24.989140  125.243164  20.0            20110926  2011.0    9.0  0.050
# 1  26.996172  127.912025  40.0  2009.7.6-2009.7.28  2009.0    7.0  0.725
#
#    depth_original  cliff_length  aicial_length  ...  MIN_NormG_2020  \
# 0             NaN           0.0       0.000000  ...        0.507961
# 1             NaN           0.0       0.478772  ...        0.353645
#
#    MIN_NormR_2020  MIN_PPR_2020  MIN_PSNDc2_2020  MIN_RDVI_2020  MIN_IF_2020  \
# 0        0.287288     -0.278071        -0.808075      -2.341663     2.353039
# 1        0.245048     -0.100556        -0.771423      -3.282602     4.672225
#
#    MIN_SLAVI_2020  MIN_SIPI2_2020  MIN_VARIgreen_2020   mesh20
# 0       95.142525        3.728732           -2.405135  3725_10
# 1      174.767501       -0.571513            0.448861  4027_13
#
# [2 rows x 3464 columns]

# %%
sub.head(2)
# Out:
#    0  0.47
# 0  1  0.68
# 1  2  0.25

# %% [markdown]
# # 前処理

# %% [markdown]
# ## 対数変換

# %%
train[f"log_cover"] = np.log1p(train["cover"])

# %% [markdown]
# ## 特徴抽出後のデータを結合

# %%
print(train.shape)
print(train_landsat_minmax.shape)
print(test.shape)
print(test_landsat_minmax.shape)
train_landsat_minmax.head(2)
# Out:
# (14140, 3465)
# (14140, 50)
# (4039, 3463)
# (4039, 50)
#    MINMAX_MVI  MINMAX_Chlred_edge  MINMAX_NLI  MINMAX_IF  MINMAX_GEMI  \
# 0   -0.498732           -0.031920    1.075848   1.225176     0.018427
# 1    0.698608            1.080161   -0.089137  -1.235533     0.525556
#
#    MINMAX_Chlgreen  MINMAX_CVI  MINMAX_DSWI_5  MINMAX_TSAVI  MINMAX_PSNDc2  \
# 0         0.065996     0.91124       0.839658      1.035656       1.000000
# 1         1.083810    -0.57457      -0.393703     -0.195017      -0.575291
#
#    ...  MINMAX_EVI  MINMAX_GVMI  MINMAX_RDVI  MINMAX_PPR  MINMAX_SIPI2  \
# 0  ...    0.558870     0.176156     0.345818    1.035576      0.350692
# 1  ...    2.011747     0.262679    -0.418989   -0.841783      0.968533
#
#    MINMAX_Cigreen  MINMAX_D678_500  MINMAX_DVIMSS  MINMAX_Green  \
# 0        0.960665        -0.223362       1.000000      1.052035
# 1       -0.482458        -0.112053      -1.535718     -0.357916
#
#    MINMAX_Alteration
# 0            3.30233
# 1           -0.12575
#
# [2 rows x 50 columns]

# %%
train = train.join([
    umap_basic_train,
    train_sentinel,
    train_landsat_minmax,
    train_landsat_2000to2020,
])
test = test.join([
    umap_basic_test,
    test_sentinel,
    test_landsat_minmax,
    test_landsat_2000to2020,
])
train.head(2)
# Out:
#          lat         lon  area                 YMD    year  month  cover  \
# 0  24.989140  125.243164  20.0            20110926  2011.0    9.0  0.050
# 1  26.996172  127.912025  40.0  2009.7.6-2009.7.28  2009.0    7.0  0.725
#
#    depth_original  cliff_length  aicial_length  ...  MAX_D678_500__median  \
# 0             NaN           0.0       0.000000  ...            -34.231005
# 1             NaN           0.0       0.478772  ...            -26.482969
#
#    MIN_Fe3__median  MAX_Chlgreen__median  MED_CI__mean  MED_Cigreen__mean  \
# 0         0.464154              5.596622     -2.412849          -0.765163
# 1         0.589454              5.961674     -0.998966          -0.499455
#
#    MED_NormG__mean  MAX_Alteration__median  MAX_CVI__median  MED_GVMI__mean  \
# 0         0.578941                4.325302         0.177657        0.931891
# 1         0.485871                6.066018         0.463270        0.965646
#
#    MED_H__mean
# 0     1.465471
# 1     1.502791
#
# [2 rows x 3742 columns]

# %%
# depth_originalがあるデータのみに絞る
train = train[~train["depth_original"].isnull()].reset_index(drop=True)
train.shape

# %% [markdown]
# ## 使用する特徴量

# %%
# 被度文献データ、海洋環境要因データ、landsat使用
# YMDは使わない
cols_base = train.columns.to_list()[:25]
cols_landsat = train.columns.to_list()[25:88]
cols_landsat_2000to2020 = train_landsat_2000to2020.columns.to_list()
cols_landsat_minmax = train_landsat_minmax.columns.to_list()

cols_sentinel = train.columns.to_list()[88:313]
cols_sentinel = [col for col in cols_sentinel if "MED" in col]
cols_sentinel_minmax = train_sentinel.columns.to_list()

cols_umap = ["temp_monthly"]

cols_use =\
 cols_base +\
 cols_landsat +\
 cols_landsat_2000to2020 +\
 cols_landsat_minmax +\
 cols_sentinel +\
 cols_sentinel_minmax +\
 ["log_cover"] # + cols_sentinel

cols_remove = [
    "YMD",
    "month",
    "Date_Acquired",
    "Landsat_StartTime",
    "PRODUCT_ID",
    "mesh20"
]
cols_use = [col for col in cols_use if not col in cols_remove]

# 重複を省く（一応）
cols_use = list(set(cols_use))

cols_use
# Out:
# ['MINMAXDiff_MCARI_OSAVI',
#  'MINMAXDiff_B8A',
#  'aicial_length',
#  'MINMAX_AVI',
#  'MED_DVIMSS__mean',
#  'sunAzimuth',
#  'MED_B02',
#  'GLI',
#  'MED_NDSI',
#  'MAX_Red__median',
#  'MINMAX_CI',
#  'MINMAX_NLI',
#  'MED_BWDRVI__mean',
#  'MIN_Ferric_Oxides__median',
#  'MED_BWDRVI',
#  'MED_RDVI__mean',
#  'MED_CIrededge',
#  'SLAVI',
#  'MINMAX_NormR',
#  'MINMAXDiff_NDSI',
#  'MINMAX_MCARI1',
#  'MAX_CTVI__median',
#  'MINMAXDiff_EVI',
#  'MIN_Gossan__median',
#  'MED_DVI',
#  'sunElevation',
#  'hist_cold_sst',
#  'MAX_SWIR1__median',
#  'GARI',
#  'Salinity_annual',
#  'MIN_NormG__median',
#  'MED_mSR',
#  'MED_RGR',
#  'MINMAXDiff_Datt1',
#  'MINMAX_TIRS2',
#  'MED_GDVI',
#  'MED_CRI550__mean',
#  'MINMAXDiff_NDVI2',
#  'MED_PPR__mean',
#  'MAX_BWDRVI__median',
#  'NBR',
#  'MED_B11',
#  'mCRIRE',
#  'NBR2',
#  'MINMAX_IR550',
#  'MAX_VARIgreen__median',
#  'MED_ARI',
#  'MED_MSI',
#  'MINMAXDiff_Chlgreen',
#  'MED_Ferrous_Silicates__mean',
#  'MED_GEMI__mean',
#  'MIN_GVMI__median',
#  'MINMAXDiff_BNDVI',
#  'MINMAXDiff_GVMI',
#  'river_area',
#  'MED_Cigreen__mean',
#  'MED_ExG',
#  'MAX_NormG__median',
#  'PSNDc2',
#  'mCRIG',
#  'MED_EVI__mean',
#  'BWDRVI',
#  'MED_BOA',
#  'IF',
#  'MAX_mCRIRE__median',
#  'MAX_SWIR2__median',
#  'MAX_Ferric_Oxides__median',
#  'MED_AOT',
#  'MVI',
#  'MIN_Fe3__median',
#  'MAX_Fe3__median',
#  'MAX_SIPI2__median',
#  'MIN_TIRS2__median',
#  'MIN_CI__median',
#  'MAX_Green__median',
#  'MIN_MVI__median',
#  'MED_B05',
#  'MED_NDVIre',
#  'MED_MIRBI',
#  'MED_Gossan__mean',
#  'MINMAX_GLI',
#  'MINMAX_TIRS1',
#  'MINMAX_BWDRVI',
#  'MINMAXDiff_B05',
#  'MED_CARI',
#  'MINMAXDiff_Rededge1',
#  'MAX_CI__median',
#  'MED_DSWI__mean',
#  'MED_AVI__mean',
#  'MINMAX_SLAVI',
#  'Cigreen',
#  'MINMAX_NIR',
#  'MIN_Cirededge__median',
#  'MED_BB1',
#  'MED_GLI',
#  'MIN_Blue__median',
#  'lat',
#  'MED_Chlgreen__mean',
#  'MED_BGI',
#  'MINMAXDiff_ARI',
#  'MED_NDVI2',
#  'MED_SB550',
#  'MIN_CRI550__median',
#  'MED_MSBI',
#  'MINMAX_VARIgreen',
#  'MINMAXDiff_NDVIre',
#  'MINMAX_Gossan',
#  'coastal_dist',
#  'MED_NDII',
#  'MAX_MCARI1__median',
#  'MIN_EVI__median',
#  'MED_MCARI1__mean',
#  'MED_Ferric_Oxides__mean',
#  'MINMAXDiff_CLD',
#  'MED_SWIR2__mean',
#  'MED_DSWI_5__mean',
#  'MINMAXDiff_GRNDVI',
#  'MED_NormG__mean',
#  'MAX_Cigreen__median',
#  'MED_GARI__mean',
#  'MIN_DSWI_5__median',
#  'MAX_Chlgreen__median',
#  'MED_CI__mean',
#  'GVMI',
#  'MED_Blue__mean',
#  'MED_MCARI2__mean',
#  'MAX_GLI__median',
#  'MINMAXDiff_CIgreen',
#  'NDMI',
#  'MED_NormR__mean',
#  'MINMAXDiff_AOT',
#  'MAX_GARI__median',
#  'MIN_SIPI2__median',
#  'MIN_CTVI__median',
#  'MAX_GVMI__median',
#  'MINMAXDiff_MVI',
#  'MED_EVI',
#  'MIN_AVI__median',
#  'MED_B07',
#  'MIN_TIRS1__median',
#  'MINMAXDiff_MCARI2',
#  'MAX_GEMI__median',
#  'MED_B03',
#  'MED_SLAVI__mean',
#  'MED_MCARI2',
#  'MED_Rededge1',
#  'MED_CIgreen',
#  'MED_Chlred_edge',
#  'MIN_IR550__median',
#  'D678_500',
#  'MED_NDRE',
#  'MIN_PPR__median',
#  'MINMAX_CTVI',
#  'MINMAXDiff_AVI',
#  'Ferrous_Silicates',
#  'SWIR2',
#  'MINMAXDiff_B06',
#  'NormG',
#  'cover',
#  'MINMAXDiff_MSBI',
#  'MINMAXDiff_NDII',
#  'fetch',
#  'MINMAXDiff_NBR2',
#  'MED_NLI__mean',
#  'sst_ymd',
#  'MINMAX_SWIR2',
#  'MINMAXDiff_MGVI',
#  'MED_MCARI_MTVI2',
#  'MAX_MVI__median',
#  'CRI550',
#  'MAX_Alteration__median',
#  'MINMAXDiff_RGR',
#  'beach_length',
#  'river_dist',
#  'MED_MVI',
#  'MINMAXDiff_GI',
#  'MAX_DVIMSS__median',
#  'MED_IO',
#  'VARIgreen',
#  'MAX_mCRIG__median',
#  'MED_SWIR1__mean',
#  'Gossan',
#  'MINMAXDiff_B02',
#  'MINMAX_D678_500',
#  'MAX_EVI__median',
#  'Green',
#  'MED_WVP',
#  'MINMAXDiff_B12',
#  'MINMAX_Red',
#  'coast_length',
#  'MIN_TSAVI__median',
#  'MINMAX_GVMI',
#  'MINMAXDiff_BWDRVI',
#  'MED_NIR__mean',
#  'MED_mNDVI',
#  'MED_Datt4',
#  'Landsat_num',
#  'MED_CVI__mean',
#  'MED_CVI',
#  'MINMAX_Chlred_edge',
#  'MIN_SLAVI__median',
#  'MED_Alteration__mean',
#  'MAX_CVI__median',
#  'MCARI1',
#  'MINMAXDiff_B11',
#  'MIN_DSWI__median',
#  'MED_Red__mean',
#  'MINMAXDiff_BRI',
#  'MED_CLD',
#  'MINMAX_CVI',
#  'MAX_TIRS1__median',
#  'MINMAX_DSWI_5',
#  'MIN_PSNDc2__median',
#  'MINMAX_mCRIRE',
#  'MINMAXDiff_BOA',
#  'MIN_H__median',
#  'CI',
#  'MIN_NIR__median',
#  'MED_MNSI',
#  'MAX_H__median',
#  'MINMAXDiff_CRred',
#  'MIN_Chlred_edge__median',
#  'MIN_RDVI__median',
#  'MED_mCRIG__mean',
#  'MED_Bcc',
#  'MINMAX_Alteration',
#  'CVI',
#  'MED_Cirededge__mean',
#  'MED_MSR670',
#  'MINMAXDiff_RDI',
#  'cold_sst',
#  'MINMAX_SWIR1',
#  'MINMAXDiff_NDRE',
#  'MINMAXDiff_ExG',
#  'MINMAX_CRI550',
#  'MINMAXDiff_TCI',
#  'MIN_GARI__median',
#  'MED_Fe3__mean',
#  'MINMAXDiff_MYVI',
#  'MINMAXDiff_CIrededge',
#  'MIN_Ferrous_Silicates__median',
#  'SWIR1',
#  'area',
#  'AVI',
#  'MINMAX_Ferric_Oxides',
#  'MINMAXDiff_Chlred_edge',
#  'NormR',
#  'TIRS2',
#  'DSWI_5',
#  'MED_CTVI__mean',
#  'MINMAXDiff_B04',
#  'MED_BNDVI',
#  'MINMAXDiff_CARI',
#  'EVI',
#  'H',
#  'MAX_PSNDc2__median',
#  'sst_annual',
#  'MIN_Red__median',
#  'MED_MGVI',
#  'MED_GRNDVI',
#  'TSAVI',
#  'MINMAX_RDVI',
#  'MED_AFRI1600',
#  'MINMAXDiff_GARI',
#  'MINMAX_EVI',
#  'MINMAXDiff_B07',
#  'MINMAX_Chlgreen',
#  'MED_B8A',
#  'MINMAXDiff_GDVI',
#  'RDVI',
#  'warm_sst',
#  'MINMAX_MVI',
#  'MIN_Green__median',
#  'MINMAXDiff_MSR670',
#  'MIN_GLI__median',
#  'MIN_GEMI__median',
#  'MIN_BWDRVI__median',
#  'MED_RDI',
#  'MINMAXDiff_WVP',
#  'Cirededge',
#  'IR550',
#  'MED_Datt1',
#  'MINMAXDiff_BGI',
#  'MED_GVMI__mean',
#  'MAX_Cirededge__median',
#  'MINMAXDiff_SB550',
#  'MINMAXDiff_B03',
#  'MINMAX_SIPI2',
#  'MAX_IR550__median',
#  'MIN_mCRIG__median',
#  'MINMAX_PSNDc2',
#  'Red',
#  'MIN_IF__median',
#  'MED_IF__mean',
#  'MED_TCI',
#  'MCARI2',
#  'NLI',
#  'MINMAXDiff_NDWI2',
#  'MIN_mCRIRE__median',
#  'Fe3',
#  'MIN_VARIgreen__median',
#  'Blue',
#  'MIN_MCARI1__median',
#  'MIN_SWIR1__median',
#  'MINMAXDiff_MSI',
#  'MINMAX_GARI',
#  'MED_AVI',
#  'MED_TIRS2__mean',
#  'MINMAXDiff_D678_500',
#  'Chlred_edge',
#  'MED_B12',
#  'MIN_NormR__median',
#  'MED_GI',
#  'MAX_Blue__median',
#  'MED_GLI__mean',
#  'MED_MYVI',
#  'MINMAXDiff_IF',
#  'MAX_TIRS2__median',
#  'MINMAXDiff_mSR',
#  'MINMAX_GEMI',
#  'MINMAXDiff_CSI',
#  'MAX_D678_500__median',
#  'MINMAXDiff_ARVI',
#  'MED_NDFI2',
#  'cliff_length',
#  'TIRS1',
#  'MED_IR550__mean',
#  'MINMAXDiff_NDBI',
#  'MED_MVI__mean',
#  'MINMAX_MCARI2',
#  'MED_B04',
#  'MED_PSSRc2',
#  'MIN_SWIR2__median',
#  'MINMAXDiff_GLI',
#  'MAX_CRI550__median',
#  'DSWI',
#  'depth_original',
#  'MINMAX_DSWI',
#  'MED_MCARI_OSAVI',
#  'MAX_Gossan__median',
#  'MAX_DSWI__median',
#  'MINMAXDiff_MIRBI',
#  'MINMAX_IF',
#  'MINMAX_Green',
#  'MAX_Chlred_edge__median',
#  'MINMAX_Cirededge',
#  'MED_GARI',
#  'MINMAXDiff_mNDVI',
#  'MED_NBR2',
#  'MAX_RDVI__median',
#  'MED_D678_500',
#  'MINMAX_Ferrous_Silicates',
#  'MINMAX_DVIMSS',
#  'MAX_NormR__median',
#  'MIN_CVI__median',
#  'MINMAX_NormG',
#  'MIN_DVIMSS__median',
#  'DVIMSS',
#  'MED_mCRIRE__mean',
#  'MIN_Cigreen__median',
#  'MINMAXDiff_IPVI',
#  'SAVI',
#  'MED_CSI',
#  'MAX_TSAVI__median',
#  'MED_D678_500__mean',
#  'MINMAXDiff_MNSI',
#  'log_cover',
#  'CTVI',
#  'MED_VARIgreen__mean',
#  'PPR',
#  'MIN_NLI__median',
#  'MED_BRI',
#  'MED_IPVI',
#  'MINMAX_Blue',
#  'MINMAX_TSAVI',
#  'depth',
#  'MED_ARVI',
#  'MED_IF',
#  'NIR',
#  'MED_GVMI',
#  'MAX_PPR__median',
#  'MAX_DSWI_5__median',
#  'MED_B06',
#  'MAX_SLAVI__median',
#  'MED_TIRS1__mean',
#  'MINMAXDiff_DVI',
#  'NDVI',
#  'MED_NDWI2',
#  'MIN_D678_500__median',
#  'MED_SIPI2__mean',
#  'MED_Green__mean',
#  'MINMAX_mCRIG',
#  'MINMAX_PPR',
#  'MINMAXDiff_AFRI1600',
#  'NDWI',
#  'MAX_Ferrous_Silicates__median',
#  'Chlgreen',
#  'MINMAX_Fe3',
#  'MED_NDBI',
#  'MED_Chlred_edge__mean',
#  'MED_SR672_708',
#  'MED_H__mean',
#  'MIN_MCARI2__median',
#  'MSAVI',
#  'MIN_Alteration__median',
#  'hist_warm_sst',
#  'MINMAX_H',
#  'MINMAXDiff_Bcc',
#  'Ferric_Oxides',
#  'MAX_MCARI2__median',
#  'MINMAXDiff_BB1',
#  'MAX_NLI__median',
#  'MINMAXDiff_Datt4',
#  'GEMI',
#  'MINMAXDiff_MCARI_MTVI2',
#  'MAX_AVI__median',
#  'MINMAX_Cigreen',
#  'MINMAXDiff_SR672_708',
#  'lon',
#  'Alteration',
#  'MED_PSNDc2__mean',
#  'MAX_IF__median',
#  'SIPI2',
#  'MINMAXDiff_NDFI2',
#  'MIN_Chlgreen__median',
#  'MINMAXDiff_IO',
#  'year',
#  'sst_diff',
#  'MINMAXDiff_PSSRc2',
#  'MED_CRred',
#  'MAX_NIR__median',
#  'MED_TSAVI__mean']

# %%
train = train[cols_use]
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4419 entries, 0 to 4418
# Columns: 432 entries, MINMAXDiff_MCARI_OSAVI to MED_TSAVI__mean
# dtypes: float32(232), float64(200)
# memory usage: 10.7 MB

# %%
cols_obj = ["cover", "log_cover"]
features = [col for col in cols_use if col not in cols_obj]
print("特徴量の数：", len(features))
# Out:
# 特徴量の数： 430

# %%
corr = train[features].corr()
threshold = 0.98
drop_numeric_cols=[]
pair=[]
for col in features:
    # if col in cat_features:
    #     continue
    for i in range(len(corr)):
        if abs(corr[col].iloc[i]) >= threshold and col != features[i] :
            print(f"{col} and {features[i]} are highly correlated...") 
            if col not in pair:
                pair.append(col)
                pair.append(features[i])
                drop_numeric_cols.append(col) 
features = list(set(features)-set(drop_numeric_cols))
print(f"Dropping columns : {drop_numeric_cols}")
print("特徴量の数：", len(features))
del drop_numeric_cols
del pair

features
# Out:
# MINMAXDiff_B8A and MINMAXDiff_B06 are highly correlated...
# MINMAXDiff_B8A and MINMAXDiff_B07 are highly correlated...
# MED_BWDRVI and MED_PSSRc2 are highly correlated...
# MAX_CTVI__median and MAX_Fe3__median are highly correlated...
# MIN_NormG__median and MAX_DSWI_5__median are highly correlated...
# MED_CRI550__mean and MED_IR550__mean are highly correlated...
# MINMAXDiff_NDVI2 and MINMAXDiff_NDII are highly correlated...
# MINMAXDiff_NDVI2 and MINMAXDiff_NDBI are highly correlated...
# MAX_BWDRVI__median and MAX_PSNDc2__median are highly correlated...
# NBR and GVMI are highly correlated...
# MED_B11 and MED_B12 are highly correlated...
# MED_MSI and MED_RDI are highly correlated...
# MINMAXDiff_BNDVI and MINMAXDiff_NDWI2 are highly correlated...
# MINMAXDiff_BNDVI and MINMAXDiff_IPVI are highly correlated...
# PSNDc2 and BWDRVI are highly correlated...
# BWDRVI and PSNDc2 are highly correlated...
# BWDRVI and CVI are highly correlated...
# MAX_Ferric_Oxides__median and MIN_MVI__median are highly correlated...
# MVI and MINMAX_MVI are highly correlated...
# MAX_Fe3__median and MAX_CTVI__median are highly correlated...
# MIN_MVI__median and MAX_Ferric_Oxides__median are highly correlated...
# MED_B05 and MED_CARI are highly correlated...
# MED_NDVIre and MED_Rededge1 are highly correlated...
# MED_NDVIre and MED_SR672_708 are highly correlated...
# MINMAX_BWDRVI and MINMAX_PSNDc2 are highly correlated...
# MED_CARI and MED_B05 are highly correlated...
# MED_DSWI__mean and MED_Cirededge__mean are highly correlated...
# Cigreen and NDWI are highly correlated...
# MIN_Cirededge__median and MIN_TSAVI__median are highly correlated...
# MED_BB1 and MED_TCI are highly correlated...
# MED_BB1 and MED_B04 are highly correlated...
# lat and cold_sst are highly correlated...
# lat and sst_annual are highly correlated...
# lat and lon are highly correlated...
# MED_SB550 and MED_B03 are highly correlated...
# MED_NDII and MED_NDBI are highly correlated...
# MED_DSWI_5__mean and MED_NormG__mean are highly correlated...
# MINMAXDiff_GRNDVI and MINMAXDiff_NDWI2 are highly correlated...
# MED_NormG__mean and MED_DSWI_5__mean are highly correlated...
# MAX_Cigreen__median and MAX_CVI__median are highly correlated...
# GVMI and NBR are highly correlated...
# NDMI and Ferric_Oxides are highly correlated...
# MED_B07 and MED_B8A are highly correlated...
# MED_B07 and MED_B06 are highly correlated...
# MED_B03 and MED_SB550 are highly correlated...
# MED_Rededge1 and MED_NDVIre are highly correlated...
# MINMAXDiff_AVI and MINMAXDiff_MNSI are highly correlated...
# MINMAXDiff_B06 and MINMAXDiff_B8A are highly correlated...
# MINMAXDiff_B06 and MINMAXDiff_B07 are highly correlated...
# MINMAXDiff_NDII and MINMAXDiff_NDVI2 are highly correlated...
# MINMAXDiff_NDII and MINMAXDiff_NDBI are highly correlated...
# MINMAXDiff_NDII and MINMAXDiff_AFRI1600 are highly correlated...
# MAX_Alteration__median and MIN_Ferrous_Silicates__median are highly correlated...
# MINMAXDiff_B12 and MINMAXDiff_B11 are highly correlated...
# MIN_TSAVI__median and MIN_Cirededge__median are highly correlated...
# MAX_CVI__median and MAX_Cigreen__median are highly correlated...
# MINMAXDiff_B11 and MINMAXDiff_B12 are highly correlated...
# MINMAX_DSWI_5 and MINMAX_NormG are highly correlated...
# MIN_PSNDc2__median and MIN_BWDRVI__median are highly correlated...
# MINMAX_Alteration and Alteration are highly correlated...
# CVI and BWDRVI are highly correlated...
# MED_Cirededge__mean and MED_DSWI__mean are highly correlated...
# cold_sst and lat are highly correlated...
# cold_sst and sst_annual are highly correlated...
# cold_sst and lon are highly correlated...
# MINMAXDiff_TCI and MINMAXDiff_B04 are highly correlated...
# MINMAXDiff_TCI and MINMAXDiff_BB1 are highly correlated...
# MIN_Ferrous_Silicates__median and MAX_Alteration__median are highly correlated...
# NormR and DSWI are highly correlated...
# MINMAXDiff_B04 and MINMAXDiff_TCI are highly correlated...
# MINMAXDiff_B04 and MINMAXDiff_BB1 are highly correlated...
# MAX_PSNDc2__median and MAX_BWDRVI__median are highly correlated...
# sst_annual and lat are highly correlated...
# sst_annual and cold_sst are highly correlated...
# sst_annual and lon are highly correlated...
# MED_GRNDVI and MED_IPVI are highly correlated...
# MED_GRNDVI and MED_NDWI2 are highly correlated...
# TSAVI and SAVI are highly correlated...
# TSAVI and NDVI are highly correlated...
# MINMAXDiff_B07 and MINMAXDiff_B8A are highly correlated...
# MINMAXDiff_B07 and MINMAXDiff_B06 are highly correlated...
# MED_B8A and MED_B07 are highly correlated...
# MED_B8A and MED_B06 are highly correlated...
# MINMAX_MVI and MVI are highly correlated...
# MIN_BWDRVI__median and MIN_PSNDc2__median are highly correlated...
# MED_RDI and MED_MSI are highly correlated...
# Cirededge and SAVI are highly correlated...
# Cirededge and NDVI are highly correlated...
# MAX_Cirededge__median and MAX_TSAVI__median are highly correlated...
# MINMAXDiff_SB550 and MINMAXDiff_B03 are highly correlated...
# MINMAXDiff_B03 and MINMAXDiff_SB550 are highly correlated...
# MINMAX_PSNDc2 and MINMAX_BWDRVI are highly correlated...
# MED_TCI and MED_BB1 are highly correlated...
# MED_TCI and MED_B04 are highly correlated...
# MINMAXDiff_NDWI2 and MINMAXDiff_BNDVI are highly correlated...
# MINMAXDiff_NDWI2 and MINMAXDiff_GRNDVI are highly correlated...
# MINMAXDiff_NDWI2 and MINMAXDiff_IPVI are highly correlated...
# Chlred_edge and MSAVI are highly correlated...
# MED_B12 and MED_B11 are highly correlated...
# MED_IR550__mean and MED_CRI550__mean are highly correlated...
# MINMAXDiff_NDBI and MINMAXDiff_NDVI2 are highly correlated...
# MINMAXDiff_NDBI and MINMAXDiff_NDII are highly correlated...
# MINMAXDiff_NDBI and MINMAXDiff_AFRI1600 are highly correlated...
# MED_B04 and MED_BB1 are highly correlated...
# MED_B04 and MED_TCI are highly correlated...
# MED_PSSRc2 and MED_BWDRVI are highly correlated...
# DSWI and NormR are highly correlated...
# MINMAX_Cirededge and MINMAX_TSAVI are highly correlated...
# MINMAX_NormG and MINMAX_DSWI_5 are highly correlated...
# MINMAXDiff_IPVI and MINMAXDiff_BNDVI are highly correlated...
# MINMAXDiff_IPVI and MINMAXDiff_NDWI2 are highly correlated...
# SAVI and TSAVI are highly correlated...
# SAVI and Cirededge are highly correlated...
# SAVI and NDVI are highly correlated...
# MAX_TSAVI__median and MAX_Cirededge__median are highly correlated...
# MINMAXDiff_MNSI and MINMAXDiff_AVI are highly correlated...
# MED_IPVI and MED_GRNDVI are highly correlated...
# MED_IPVI and MED_NDWI2 are highly correlated...
# MINMAX_TSAVI and MINMAX_Cirededge are highly correlated...
# MAX_DSWI_5__median and MIN_NormG__median are highly correlated...
# MED_B06 and MED_B07 are highly correlated...
# MED_B06 and MED_B8A are highly correlated...
# NDVI and TSAVI are highly correlated...
# NDVI and Cirededge are highly correlated...
# NDVI and SAVI are highly correlated...
# MED_NDWI2 and MED_GRNDVI are highly correlated...
# MED_NDWI2 and MED_IPVI are highly correlated...
# MINMAXDiff_AFRI1600 and MINMAXDiff_NDII are highly correlated...
# MINMAXDiff_AFRI1600 and MINMAXDiff_NDBI are highly correlated...
# NDWI and Cigreen are highly correlated...
# MAX_Ferrous_Silicates__median and MIN_Alteration__median are highly correlated...
# MED_NDBI and MED_NDII are highly correlated...
# MED_SR672_708 and MED_NDVIre are highly correlated...
# MSAVI and Chlred_edge are highly correlated...
# MIN_Alteration__median and MAX_Ferrous_Silicates__median are highly correlated...
# Ferric_Oxides and NDMI are highly correlated...
# MINMAXDiff_BB1 and MINMAXDiff_TCI are highly correlated...
# MINMAXDiff_BB1 and MINMAXDiff_B04 are highly correlated...
# lon and lat are highly correlated...
# lon and cold_sst are highly correlated...
# lon and sst_annual are highly correlated...
# Alteration and MINMAX_Alteration are highly correlated...
# Dropping columns : ['MINMAXDiff_B8A', 'MED_BWDRVI', 'MAX_CTVI__median', 'MIN_NormG__median', 'MED_CRI550__mean', 'MINMAXDiff_NDVI2', 'MAX_BWDRVI__median', 'NBR', 'MED_B11', 'MED_MSI', 'MINMAXDiff_BNDVI', 'PSNDc2', 'MAX_Ferric_Oxides__median', 'MVI', 'MED_B05', 'MED_NDVIre', 'MINMAX_BWDRVI', 'MED_DSWI__mean', 'Cigreen', 'MIN_Cirededge__median', 'MED_BB1', 'lat', 'MED_SB550', 'MED_NDII', 'MED_DSWI_5__mean', 'MINMAXDiff_GRNDVI', 'MAX_Cigreen__median', 'NDMI', 'MED_B07', 'MINMAXDiff_AVI', 'MAX_Alteration__median', 'MINMAXDiff_B12', 'MINMAX_DSWI_5', 'MIN_PSNDc2__median', 'MINMAX_Alteration', 'CVI', 'MINMAXDiff_TCI', 'NormR', 'sst_annual', 'MED_GRNDVI', 'TSAVI', 'MINMAXDiff_B07', 'Cirededge', 'MAX_Cirededge__median', 'MINMAXDiff_SB550', 'Chlred_edge', 'MINMAXDiff_NDBI', 'MED_B04', 'MINMAX_Cirededge', 'MINMAXDiff_IPVI', 'MED_B06', 'NDVI', 'MED_NDWI2', 'MINMAXDiff_AFRI1600', 'MAX_Ferrous_Silicates__median', 'MED_SR672_708', 'MINMAXDiff_BB1', 'lon']
# 特徴量の数： 372
# ['MINMAXDiff_MCARI_OSAVI',
#  'MED_Bcc',
#  'aicial_length',
#  'MINMAX_AVI',
#  'MED_DVIMSS__mean',
#  'MED_Cirededge__mean',
#  'sunAzimuth',
#  'MED_MSR670',
#  'MINMAXDiff_RDI',
#  'MED_B02',
#  'GLI',
#  'cold_sst',
#  'MED_NDSI',
#  'MINMAX_SWIR1',
#  'MINMAXDiff_NDRE',
#  'MAX_Red__median',
#  'MINMAX_CI',
#  'MINMAXDiff_ExG',
#  'MINMAX_CRI550',
#  'MIN_GARI__median',
#  'MINMAX_NLI',
#  'MED_BWDRVI__mean',
#  'MIN_Ferric_Oxides__median',
#  'MED_Fe3__mean',
#  'MINMAXDiff_MYVI',
#  'MED_RDVI__mean',
#  'MINMAXDiff_CIrededge',
#  'MIN_Ferrous_Silicates__median',
#  'SWIR1',
#  'MED_CIrededge',
#  'area',
#  'SLAVI',
#  'AVI',
#  'MINMAX_Ferric_Oxides',
#  'MINMAX_NormR',
#  'MINMAXDiff_NDSI',
#  'MINMAXDiff_Chlred_edge',
#  'MINMAX_MCARI1',
#  'TIRS2',
#  'DSWI_5',
#  'MINMAXDiff_EVI',
#  'MED_CTVI__mean',
#  'MED_DVI',
#  'MIN_Gossan__median',
#  'MINMAXDiff_B04',
#  'MED_BNDVI',
#  'sunElevation',
#  'hist_cold_sst',
#  'GARI',
#  'MAX_SWIR1__median',
#  'MINMAXDiff_CARI',
#  'Salinity_annual',
#  'EVI',
#  'H',
#  'MED_mSR',
#  'MAX_PSNDc2__median',
#  'MED_RGR',
#  'MIN_Red__median',
#  'MINMAXDiff_Datt1',
#  'MINMAX_TIRS2',
#  'MED_MGVI',
#  'MED_GDVI',
#  'MINMAX_RDVI',
#  'MED_AFRI1600',
#  'MED_PPR__mean',
#  'MINMAXDiff_GARI',
#  'MINMAX_EVI',
#  'MINMAX_Chlgreen',
#  'MED_B8A',
#  'MINMAXDiff_GDVI',
#  'RDVI',
#  'mCRIRE',
#  'warm_sst',
#  'NBR2',
#  'MINMAX_MVI',
#  'MIN_Green__median',
#  'MINMAXDiff_MSR670',
#  'MINMAX_IR550',
#  'MIN_GLI__median',
#  'MIN_GEMI__median',
#  'MIN_BWDRVI__median',
#  'MAX_VARIgreen__median',
#  'MED_RDI',
#  'MED_ARI',
#  'MINMAXDiff_Chlgreen',
#  'MED_Ferrous_Silicates__mean',
#  'MINMAXDiff_WVP',
#  'MED_GEMI__mean',
#  'MIN_GVMI__median',
#  'MINMAXDiff_GVMI',
#  'IR550',
#  'river_area',
#  'MED_Cigreen__mean',
#  'MED_Datt1',
#  'MINMAXDiff_BGI',
#  'MED_ExG',
#  'MAX_NormG__median',
#  'MED_GVMI__mean',
#  'mCRIG',
#  'MED_EVI__mean',
#  'MINMAXDiff_B03',
#  'BWDRVI',
#  'MED_BOA',
#  'IF',
#  'MINMAX_SIPI2',
#  'MAX_mCRIRE__median',
#  'MAX_SWIR2__median',
#  'MAX_IR550__median',
#  'MED_AOT',
#  'MIN_mCRIG__median',
#  'MINMAX_PSNDc2',
#  'MIN_Fe3__median',
#  'Red',
#  'MIN_IF__median',
#  'MED_IF__mean',
#  'MED_TCI',
#  'MAX_Fe3__median',
#  'MCARI2',
#  'MAX_SIPI2__median',
#  'NLI',
#  'MINMAXDiff_NDWI2',
#  'MIN_TIRS2__median',
#  'MIN_CI__median',
#  'MAX_Green__median',
#  'MIN_mCRIRE__median',
#  'Fe3',
#  'MIN_MVI__median',
#  'MED_MIRBI',
#  'MIN_VARIgreen__median',
#  'MED_Gossan__mean',
#  'MINMAX_GLI',
#  'Blue',
#  'MIN_MCARI1__median',
#  'MINMAX_TIRS1',
#  'MIN_SWIR1__median',
#  'MINMAXDiff_MSI',
#  'MINMAX_GARI',
#  'MED_AVI',
#  'MINMAXDiff_B05',
#  'MED_CARI',
#  'MED_TIRS2__mean',
#  'MINMAXDiff_D678_500',
#  'MINMAXDiff_Rededge1',
#  'MAX_CI__median',
#  'MED_B12',
#  'MIN_NormR__median',
#  'MED_AVI__mean',
#  'MED_GI',
#  'MINMAX_SLAVI',
#  'MINMAXDiff_PSSRc2',
#  'MINMAX_NIR',
#  'MAX_Blue__median',
#  'MED_GLI__mean',
#  'MED_GLI',
#  'MED_MYVI',
#  'MINMAXDiff_IF',
#  'MIN_Blue__median',
#  'MAX_TIRS2__median',
#  'MINMAXDiff_mSR',
#  'MINMAX_GEMI',
#  'MINMAXDiff_CSI',
#  'MAX_D678_500__median',
#  'MINMAXDiff_ARVI',
#  'MED_NDFI2',
#  'MED_Chlgreen__mean',
#  'MED_BGI',
#  'MINMAXDiff_ARI',
#  'cliff_length',
#  'MED_NDVI2',
#  'TIRS1',
#  'MED_IR550__mean',
#  'MED_MVI__mean',
#  'MIN_CRI550__median',
#  'MINMAX_MCARI2',
#  'MED_MSBI',
#  'MINMAX_VARIgreen',
#  'MINMAXDiff_NDVIre',
#  'MED_PSSRc2',
#  'MINMAX_Gossan',
#  'MIN_SWIR2__median',
#  'MINMAXDiff_GLI',
#  'coastal_dist',
#  'MAX_CRI550__median',
#  'DSWI',
#  'MAX_MCARI1__median',
#  'depth_original',
#  'MIN_EVI__median',
#  'MED_MCARI1__mean',
#  'MED_Ferric_Oxides__mean',
#  'MINMAX_DSWI',
#  'MED_MCARI_OSAVI',
#  'MINMAXDiff_CLD',
#  'MED_SWIR2__mean',
#  'MAX_Gossan__median',
#  'MED_NormG__mean',
#  'MED_GARI__mean',
#  'MIN_DSWI_5__median',
#  'MAX_Chlgreen__median',
#  'MAX_DSWI__median',
#  'MINMAXDiff_MIRBI',
#  'MED_CI__mean',
#  'MINMAX_IF',
#  'GVMI',
#  'MED_Blue__mean',
#  'MINMAX_Green',
#  'MED_MCARI2__mean',
#  'MAX_GLI__median',
#  'MINMAXDiff_CIgreen',
#  'MAX_Chlred_edge__median',
#  'MED_NormR__mean',
#  'MED_GARI',
#  'MINMAXDiff_AOT',
#  'MINMAXDiff_mNDVI',
#  'MAX_GARI__median',
#  'MIN_SIPI2__median',
#  'MED_NBR2',
#  'MAX_RDVI__median',
#  'MIN_CTVI__median',
#  'MED_D678_500',
#  'MINMAX_Ferrous_Silicates',
#  'MINMAX_DVIMSS',
#  'MAX_NormR__median',
#  'MAX_GVMI__median',
#  'MIN_CVI__median',
#  'MINMAX_NormG',
#  'MIN_DVIMSS__median',
#  'MINMAXDiff_MVI',
#  'DVIMSS',
#  'MED_EVI',
#  'MED_mCRIRE__mean',
#  'MIN_AVI__median',
#  'MIN_TIRS1__median',
#  'MIN_Cigreen__median',
#  'MINMAXDiff_MCARI2',
#  'SAVI',
#  'MAX_GEMI__median',
#  'MED_B03',
#  'MED_CSI',
#  'MED_SLAVI__mean',
#  'MED_MCARI2',
#  'MAX_TSAVI__median',
#  'MED_Rededge1',
#  'MED_D678_500__mean',
#  'MINMAXDiff_MNSI',
#  'MED_CIgreen',
#  'MED_Chlred_edge',
#  'MIN_IR550__median',
#  'CTVI',
#  'D678_500',
#  'MED_VARIgreen__mean',
#  'MED_NDRE',
#  'PPR',
#  'MIN_PPR__median',
#  'MINMAX_CTVI',
#  'MIN_NLI__median',
#  'MED_BRI',
#  'Ferrous_Silicates',
#  'MAX_NIR__median',
#  'SWIR2',
#  'MED_IPVI',
#  'MINMAXDiff_B06',
#  'NormG',
#  'MINMAX_Blue',
#  'MINMAX_TSAVI',
#  'depth',
#  'MED_ARVI',
#  'MINMAXDiff_MSBI',
#  'MED_IF',
#  'MINMAXDiff_NDII',
#  'fetch',
#  'MINMAXDiff_NBR2',
#  'NIR',
#  'MED_GVMI',
#  'MAX_PPR__median',
#  'MED_NLI__mean',
#  'MAX_DSWI_5__median',
#  'sst_ymd',
#  'MINMAX_SWIR2',
#  'MINMAXDiff_MGVI',
#  'MED_MCARI_MTVI2',
#  'MAX_MVI__median',
#  'MAX_SLAVI__median',
#  'MED_TIRS1__mean',
#  'CRI550',
#  'MINMAXDiff_DVI',
#  'MINMAXDiff_RGR',
#  'beach_length',
#  'river_dist',
#  'MED_MVI',
#  'MINMAXDiff_GI',
#  'MAX_DVIMSS__median',
#  'MED_IO',
#  'VARIgreen',
#  'MAX_mCRIG__median',
#  'MIN_D678_500__median',
#  'MED_SIPI2__mean',
#  'MED_Green__mean',
#  'MINMAX_mCRIG',
#  'MED_SWIR1__mean',
#  'MINMAX_PPR',
#  'Gossan',
#  'NDWI',
#  'MINMAXDiff_B02',
#  'Chlgreen',
#  'MINMAX_Fe3',
#  'MED_NDBI',
#  'MINMAX_D678_500',
#  'MED_Chlred_edge__mean',
#  'MAX_EVI__median',
#  'Green',
#  'MED_H__mean',
#  'MIN_MCARI2__median',
#  'MED_WVP',
#  'MINMAX_Red',
#  'coast_length',
#  'MIN_TSAVI__median',
#  'MSAVI',
#  'MIN_Alteration__median',
#  'MINMAX_GVMI',
#  'MINMAXDiff_BWDRVI',
#  'hist_warm_sst',
#  'MINMAX_H',
#  'MED_NIR__mean',
#  'MED_mNDVI',
#  'MED_Datt4',
#  'Landsat_num',
#  'MINMAXDiff_Bcc',
#  'Ferric_Oxides',
#  'MAX_MCARI2__median',
#  'MED_CVI__mean',
#  'MAX_NLI__median',
#  'MED_CVI',
#  'MINMAXDiff_Datt4',
#  'MED_CRred',
#  'GEMI',
#  'MINMAX_Chlred_edge',
#  'MINMAXDiff_MCARI_MTVI2',
#  'MAX_AVI__median',
#  'MIN_SLAVI__median',
#  'MED_Alteration__mean',
#  'MINMAX_Cigreen',
#  'MAX_CVI__median',
#  'MINMAXDiff_SR672_708',
#  'MCARI1',
#  'MINMAXDiff_B11',
#  'MIN_DSWI__median',
#  'MED_Red__mean',
#  'MINMAXDiff_BRI',
#  'MED_CLD',
#  'MINMAX_CVI',
#  'MAX_TIRS1__median',
#  'Alteration',
#  'MED_PSNDc2__mean',
#  'MINMAX_mCRIRE',
#  'MINMAXDiff_BOA',
#  'MAX_IF__median',
#  'SIPI2',
#  'MIN_H__median',
#  'MINMAXDiff_NDFI2',
#  'CI',
#  'MIN_Chlgreen__median',
#  'MIN_NIR__median',
#  'MINMAXDiff_IO',
#  'MED_MNSI',
#  'year',
#  'sst_diff',
#  'MAX_H__median',
#  'MINMAXDiff_CRred',
#  'MIN_Chlred_edge__median',
#  'MED_TSAVI__mean',
#  'MIN_RDVI__median',
#  'MED_mCRIG__mean']

# %% [markdown]
# # CV

# %% [markdown]
# shap:
#
# https://data-analysis-stats.jp/%E6%A9%9F%E6%A2%B0%E5%AD%A6%E7%BF%92/%E6%A9%9F%E6%A2%B0%E5%AD%A6%E7%BF%92%E3%83%A2%E3%83%87%E3%83%AB%E3%82%92%E8%A7%A3%E9%87%88%E3%81%99%E3%82%8Bshap/

# %%
# train_date = train[["year", "month"]].copy()

# def convert_int_into_str(x):
#     x_str = str(int(x))
#     if len(x_str)==1:
#         return "0" + x_str
#     return x_str

# train_date["month_str"] = train_date["month"].apply(convert_int_into_str)
# train_date["year_month"] = (train_date["year"].astype(int).astype(str) + train_date["month_str"]).astype(int)
# train_date.head()

# %%
# year_month = train_date["year_month"]
# cv = []

# val_idx1 = (year_month >= 200901)&(year_month <200907)
# train_idx1 = ~val_idx1
# cv.append([train_idx1, val_idx1])

# val_idx2 = (year_month >= 200910)&(year_month <200912)
# train_idx2 = ~val_idx2
# cv.append([train_idx2, val_idx2])

# val_idx3 = (year_month >= 201006)&(year_month <201009)
# train_idx3 = ~val_idx3
# cv.append([train_idx3, val_idx3])

# val_idx4 = (year_month >= 201010)&(year_month <201101)
# train_idx4 = ~val_idx4
# cv.append([train_idx4, val_idx4])

# val_idx5 = (year_month >= 201909)&(year_month <201910)
# train_idx5 = ~val_idx5
# cv.append([train_idx5, val_idx5])

# %%
def my_cross_val_predict(df, df_test, y_name=None, y_raw_name=None, params=None, features=None, cv=None, split=5, eval_by_shap=True):
    # CVの結果を集約する変数
    results_rmse = []
    dict_learning_rate = {}
    fi_df = pd.DataFrame()
    fi_df['features'] = features

    # kfoldで5分割
    kfold = KFold(n_splits=split, shuffle=True, random_state=42)
    X = df[features].values
    y = df[y_name].values
    y_raw = df[y_raw_name].values

    # 同時にtestデータも予測する
    X_test = df_test[features].values
    y_pred_test_mean = np.zeros(len(X_test))

    y_pred_val_all = np.zeros(len(y))
    y_pred_val_all[:] = np.nan

    for i, (train_idx, val_idx) in enumerate(kfold.split(X)):
        print("###"*10)
        print(f"● CV{i}")
        print("###"*10)
        X_train = X[train_idx, :]
        y_train = y[train_idx]
        X_val = X[val_idx, :]
        y_val = y[val_idx]
        y_val_raw = y_raw[val_idx]

        train_dataset = lgb.Dataset(X_train,
                                    y_train,
                                    feature_name=features,)
        val_dataset = lgb.Dataset(X_val,
                                  y_val,
                                  feature_name=features,)
        
        evals_result = {}
        callbacks = [
            # lgb.log_evaluation(100),
            # lgb.early_stopping(200),
            lgb.record_evaluation(evals_result)
        ]

        # モデル作成
        model = lgb.train(params=params,
                          train_set=train_dataset,
                          valid_sets=[val_dataset],
                          callbacks=callbacks,
                          verbose_eval=500,)
        # valデータ予測
        y_pred_raw = model.predict(X_val)
        y_pred = np.expm1(y_pred_raw)
        y_pred[y_pred<0] = 0
        y_pred[y_pred>1] = 1
        print(np.average(y_pred))
        y_pred_val_all[val_idx] = y_pred
        # testデータ予測
        y_pred_test_raw = model.predict(X_test)
        y_pred_test = np.expm1(y_pred_test_raw)
        # この処理は最後にやる
        # y_pred_test[y_pred_test<0] = 0
        # y_pred_test[y_pred_test>1] = 1
        y_pred_test_mean += (y_pred_test / split)
        
        # RMSE計算
        rmse = np.sqrt(mean_squared_error(y_val_raw, y_pred))
        results_rmse.append(rmse)

        # 予測結果の可視化
        fig, ax = plt.subplots()
        ax.grid(alpha=0.2)
        ax.scatter(y_pred, y_val_raw, s=2)
        ax.set_xlabel("Pred")
        ax.set_ylabel("True")
        ax.set_xlim([0, 1])
        ax.set_ylim([0, 1])
        ax.set_title(f"val_{i}")
        plt.show()

        # 特徴量重要度の抽出
        fi_df[f"importance_cv{i}"] = model.feature_importance(importance_type='gain')
        dict_learning_rate[f"fold_{i}"] = np.array(evals_result['valid_0']['fair'])

        # shapで評価
        if eval_by_shap:
            df_X_val = pd.DataFrame(X_val, columns=features)
            explainer = shap.TreeExplainer(model)
            shap_values = explainer.shap_values(X=df_X_val)
            shap.summary_plot(shap_values, df_X_val)
        
    # 学習曲線の可視化
    print("###"*10)
    print("学習曲線")
    print("###"*10)
    fig, ax = plt.subplots()
    ax.grid(alpha=0.2)
    for key, value in dict_learning_rate.items():
        x = list(range(len(value)))
        ax.plot(x, value, label=key)
    ax.legend(loc="upper left", bbox_to_anchor=(1, 0.5))
    # ax.set_ylim([-0.05, 0.2])
    plt.show()

    # testデータの予測結果整理
    y_pred_test_mean[y_pred_test_mean<0] = 0
    y_pred_test_mean[y_pred_test_mean>1] = 1

    return results_rmse, fi_df, y_pred_test_mean, y_pred_val_all

# %%
def plot_results(results):
    x_list = [f"cv{i}" for i in range(5)]
    fig = plt.figure(figsize=(7, 4))
    ax = fig.add_subplot()
    ax.bar(x=x_list, height=results, label="RMSE", zorder=10)
    ax.set_ylabel("RMSE")
    # ax.set_ylim([0, 0.007])
    ax.grid(zorder=-10)
    ax.legend()
    plt.show()

# from: https://blog.amedama.jp/entry/lightgbm-cv-feature-importance
def plot_importance(fi_df, figsize=(10, 10)):
#     raw_importances = cvbooster.feature_importance(importance_type='gain')
    feature_name = fi_df.features.to_list()
    importance_df = pd.DataFrame(data=fi_df.iloc[:, 1:].values.T,
                             columns=feature_name)
    # 平均値でソートする
    sorted_indices = importance_df.mean(axis=0).sort_values(ascending=False).index
    sorted_importance_df = importance_df.loc[:, sorted_indices]
    print(sorted_importance_df.shape)
    # 上位をプロットする
#     PLOT_TOP_N = 40
    plot_cols = sorted_importance_df.columns[:50]
    _, ax = plt.subplots(figsize=figsize)
    ax.grid()
    ax.set_xscale('log')
    ax.set_ylabel('Feature')
    ax.set_xlabel('Importance')
    sns.boxplot(data=sorted_importance_df[plot_cols],
                orient='h',
                ax=ax)
    plt.show()

# %%
params = {
    'objective': 'fair',
    'metric': 'fair',
    'boosting_type': 'gbdt',
    'max_depth': 5,
    'n_estimators': 2000,
    'learning_rate': 0.01,
    # 'num_leaves': 50,
    # 'colsample_bytree': 0.6,
    # 'subsample': 0.5,
    'verbose': -1,
    'n_jobs': -1,
    'seed': 46,
}

results_rmse, fi_df, y_test_pred, train["y_pred"] = my_cross_val_predict(train, test, y_name="log_cover", y_raw_name="cover", params=params, features=features)
# Out:
# ##############################
# ● CV0
# ##############################
# [500]	valid_0's fair: 0.00655795
# [1000]	valid_0's fair: 0.00595342
# [1500]	valid_0's fair: 0.00562214
# [2000]	valid_0's fair: 0.00543124
# 0.22066838588623872
# ##############################
# ● CV1
# ##############################
# [500]	valid_0's fair: 0.00683576
# [1000]	valid_0's fair: 0.0062494
# [1500]	valid_0's fair: 0.00599979
# [2000]	valid_0's fair: 0.00583332
# 0.24207915987992148
# ##############################
# ● CV2
# ##############################
# [500]	valid_0's fair: 0.00650783
# [1000]	valid_0's fair: 0.00592603
# [1500]	valid_0's fair: 0.00565429
# [2000]	valid_0's fair: 0.00544832
# 0.24453934598679158
# ##############################
# ● CV3
# ##############################
# [500]	valid_0's fair: 0.00687062
# [1000]	valid_0's fair: 0.00623368
# [1500]	valid_0's fair: 0.00593486
# [2000]	valid_0's fair: 0.00573492
# 0.24434943067857154
# ##############################
# ● CV4
# ##############################
# [500]	valid_0's fair: 0.00639064
# [1000]	valid_0's fair: 0.00576404
# [1500]	valid_0's fair: 0.00544556
# [2000]	valid_0's fair: 0.00527575
# 0.22720433703292736
# ##############################
# 学習曲線
# ##############################

# %%
for i, rmse in enumerate(results_rmse):
    print(f"CV{i}: {rmse:.3f}")
print(f"Average: {np.average(results_rmse):.3f}")
plot_results(results_rmse)
# Out:
# CV0: 0.153
# CV1: 0.160
# CV2: 0.154
# CV3: 0.158
# CV4: 0.152
# Average: 0.155

# %%
plot_importance(fi_df, figsize=(10, 12))
# Out:
# (5, 372)

# %% [markdown]
# # Sub作成

# %%
test_sub = pd.DataFrame(y_test_pred, columns=["pred"])
test_sub
# Out:
#           pred
# 0     0.256662
# 1     0.057012
# 2     0.247170
# 3     0.072658
# 4     0.121948
# ...        ...
# 4034  0.235989
# 4035  0.395039
# 4036  0.281688
# 4037  0.365041
# 4038  0.737143
#
# [4039 rows x 1 columns]

# %%
test_pred_mean = test_sub["pred"].mean()
test_pred_mean
# Out:
# 0.2824384830839228

# %%
test_sub2 = test_sub.copy()
public_mean = 0.09088
# test_sub["pred"] = test_sub["pred"] * (public_mean / test_pred_mean)
test_sub2["pred"] -= (test_pred_mean - public_mean)
test_sub2["pred"] = np.clip(test_sub2["pred"].values, 0, 1)
test_sub2
# Out:
#           pred
# 0     0.065103
# 1     0.000000
# 2     0.055611
# 3     0.000000
# 4     0.000000
# ...        ...
# 4034  0.044431
# 4035  0.203481
# 4036  0.090129
# 4037  0.173482
# 4038  0.545584
#
# [4039 rows x 1 columns]

# %%
print("pred_最小値:", test_sub["pred"].min())
print("pred_最大値:", test_sub["pred"].max())
print("pred_平均値:", test_sub["pred"].mean())
# Out:
# pred_最小値: 0.0
# pred_最大値: 0.9071035254381282
# pred_平均値: 0.2824384830839228

# %%
print("●後処理後")
print("pred_最小値:", test_sub2["pred"].min())
print("pred_最大値:", test_sub2["pred"].max())
print("pred_平均値:", test_sub2["pred"].mean())
# Out:
# ●後処理後
# pred_最小値: 0.0
# pred_最大値: 0.7155450423542055
# pred_平均値: 0.12080556665764847

# %%
if SAVE_SUB:
    test_sub.to_csv(SAVE_SUB_DIR / f"{SUB_FILE_NAME}.csv", header=False)
    test_sub2.to_csv(SAVE_SUB_DIR / f"{SUB_FILE_NAME}_mod.csv", header=False)

# %% [markdown]
# # 予測結果確認

# %%
def check_by_scatter(check_col):
    tmp1 = df_pred[train[check_col].isnull()]
    tmp2 = df_pred[~train[check_col].isnull()]
    fig, ax = plt.subplots(figsize=(7, 6))
    ax.grid(alpha=0.2, color="gray")
    ax.scatter(tmp2["y_pred"], tmp2["cover"], s=6, label=f"NOT Null", alpha=0.5)
    ax.scatter(tmp1["y_pred"], tmp1["cover"], s=6, label=f"Null", alpha=0.5)
    ax.set_xlabel("Pred")
    ax.set_ylabel("True")
    ax.set_title(check_col)
    ax.legend()
    plt.show()

# %%
df_pred = train[["cover", "y_pred"]]
score = np.sqrt(mean_squared_error(train['cover'].values, train['y_pred'].values))
print(f"全体のRMSE: {score:.04f}")
# Out:
# 全体のRMSE: 0.1554

# %%
check_col = "depth_original"
tmp1 = df_pred[train[check_col].isnull()]
tmp2 = df_pred[~train[check_col].isnull()]
# score1 = np.sqrt(mean_squared_error(tmp1['cover'].values, tmp1['y_pred'].values))
score2 = np.sqrt(mean_squared_error(tmp2['cover'].values, tmp2['y_pred'].values))
# print(f"●全体のRMSE ({check_col}がnull)")
# print(f"　データ数: {len(tmp1)}")
# print(f"　スコア: {score1:.04f}\n")
print(f"●全体のRMSE ({check_col}がnull以外)")
print(f"　データ数: {len(tmp2)}")
print(f"　スコア: {score2:.04f}\n")
print(f"テストデータで{check_col}がnullの割合")
print(f"　{(100*test[check_col].isnull().sum()/len(test)):.3f}%")
check_by_scatter(check_col)
# Out:
# ●全体のRMSE (depth_originalがnull以外)
# 　データ数: 4419
# 　スコア: 0.1554
#
# テストデータでdepth_originalがnullの割合
# 　50.829%

# %%
check_col = "Blue"
tmp1 = df_pred[train[check_col].isnull()]
tmp2 = df_pred[~train[check_col].isnull()]
score1 = np.sqrt(mean_squared_error(tmp1['cover'].values, tmp1['y_pred'].values))
score2 = np.sqrt(mean_squared_error(tmp2['cover'].values, tmp2['y_pred'].values))
print(f"●全体のRMSE ({check_col}がnull)")
print(f"　データ数: {len(tmp1)}")
print(f"　スコア: {score1:.04f}\n")
print(f"●全体のRMSE ({check_col}がnull以外)")
print(f"　データ数: {len(tmp2)}")
print(f"　スコア: {score2:.04f}\n")
print(f"テストデータで{check_col}がnullの割合")
print(f"　{(100*test[check_col].isnull().sum()/len(test)):.3f}%")
check_by_scatter(check_col)
# Out:
# ●全体のRMSE (Blueがnull)
# 　データ数: 595
# 　スコア: 0.1930
#
# ●全体のRMSE (Blueがnull以外)
# 　データ数: 3824
# 　スコア: 0.1487
#
# テストデータでBlueがnullの割合
# 　27.804%

# %%
check_col = "MED_AFRI1600"
tmp1 = df_pred[train[check_col].isnull()]
tmp2 = df_pred[~train[check_col].isnull()]
score1 = np.sqrt(mean_squared_error(tmp1['cover'].values, tmp1['y_pred'].values))
score2 = np.sqrt(mean_squared_error(tmp2['cover'].values, tmp2['y_pred'].values))
print(f"●全体のRMSE ({check_col}がnull)")
print(f"　データ数: {len(tmp1)}")
print(f"　スコア: {score1:.04f}\n")
print(f"●全体のRMSE ({check_col}がnull以外)")
print(f"　データ数: {len(tmp2)}")
print(f"　スコア: {score2:.04f}\n")
print(f"テストデータで{check_col}がnullの割合")
print(f"　{(100*test[check_col].isnull().sum()/len(test)):.3f}%")
check_by_scatter(check_col)
# Out:
# ●全体のRMSE (MED_AFRI1600がnull)
# 　データ数: 3
# 　スコア: 0.0659
#
# ●全体のRMSE (MED_AFRI1600がnull以外)
# 　データ数: 4416
# 　スコア: 0.1555
#
# テストデータでMED_AFRI1600がnullの割合
# 　0.545%

# %%
# check_col = "MAX_NormG__median"
# tmp1 = df_pred[train[check_col].isnull()]
# tmp2 = df_pred[~train[check_col].isnull()]
# score1 = np.sqrt(mean_squared_error(tmp1['cover'].values, tmp1['y_pred'].values))
# score2 = np.sqrt(mean_squared_error(tmp2['cover'].values, tmp2['y_pred'].values))
# print(f"●全体のRMSE ({check_col}がnull)")
# print(f"　データ数: {len(tmp1)}")
# print(f"　スコア: {score1:.04f}\n")
# print(f"●全体のRMSE ({check_col}がnull以外)")
# print(f"　データ数: {len(tmp2)}")
# print(f"　スコア: {score2:.04f}\n")
# print(f"テストデータで{check_col}がnullの割合")
# print(f"　{(100*test[check_col].isnull().sum()/len(test)):.3f}%")
# check_by_scatter(check_col)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-dacd3a1b1c62> in <cell line: 4>()
#       2 tmp1 = df_pred[train[check_col].isnull()]
#       3 tmp2 = df_pred[~train[check_col].isnull()]
# ----> 4 score1 = np.sqrt(mean_squared_error(tmp1['cover'].values, tmp1['y_pred'].values))
#       5 score2 = np.sqrt(mean_squared_error(tmp2['cover'].values, tmp2['y_pred'].values))
#       6 print(f"●全体のRMSE ({check_col}がnull)")
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     440     0.825...
#     441     """
# --> 442     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     443         y_true, y_pred, multioutput
#     444     )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      99     """
#     100     check_consistent_length(y_true, y_pred)
# --> 101     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     102     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#     103
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     929         n_samples = _num_samples(array)
#     930         if n_samples < ensure_min_samples:
# --> 931             raise ValueError(
#     932                 "Found array with %d sample(s) (shape=%s) while a"
#     933                 " minimum of %d is required%s."
#
# ValueError: Found array with 0 sample(s) (shape=(0,)) while a minimum of 1 is required.

# %%
check_col = "depth"
tmp1 = df_pred[train[check_col].isnull()]
tmp2 = df_pred[~train[check_col].isnull()]
score1 = np.sqrt(mean_squared_error(tmp1['cover'].values, tmp1['y_pred'].values))
score2 = np.sqrt(mean_squared_error(tmp2['cover'].values, tmp2['y_pred'].values))
print(f"●全体のRMSE ({check_col}がnull)")
print(f"　データ数: {len(tmp1)}")
print(f"　スコア: {score1:.04f}\n")
print(f"●全体のRMSE ({check_col}がnull以外)")
print(f"　データ数: {len(tmp2)}")
print(f"　スコア: {score2:.04f}\n")
print(f"テストデータで{check_col}がnullの割合")
print(f"　{(100*test[check_col].isnull().sum()/len(test)):.3f}%")
check_by_scatter(check_col)
# Out:
# ●全体のRMSE (depthがnull)
# 　データ数: 3
# 　スコア: 0.0659
#
# ●全体のRMSE (depthがnull以外)
# 　データ数: 4416
# 　スコア: 0.1555
#
# テストデータでdepthがnullの割合
# 　0.545%

# %%
check_col = "Landsat_num"
tmp1 = df_pred[train[check_col]==7]
tmp2 = df_pred[train[check_col]==8]
score1 = np.sqrt(mean_squared_error(tmp1['cover'].values, tmp1['y_pred'].values))
score2 = np.sqrt(mean_squared_error(tmp2['cover'].values, tmp2['y_pred'].values))
print(f"●全体のRMSE ({check_col}==7)")
print(f"　データ数: {len(tmp1)}")
print(f"　スコア: {score1:.04f}\n")
print(f"●全体のRMSE ({check_col}==8)")
print(f"　データ数: {len(tmp2)}")
print(f"　スコア: {score2:.04f}\n")
print(f"テストデータで{check_col}==7の割合")
print(f"　{(100*(test[check_col]==7).sum()/len(test)):.3f}%")

fig, ax = plt.subplots(figsize=(7, 6))
ax.grid(alpha=0.2, color="gray")
ax.scatter(tmp2["y_pred"], tmp2["cover"], s=6, label=f"Landsat_num==8", alpha=0.5)
ax.scatter(tmp1["y_pred"], tmp1["cover"], s=6, label=f"Landsat_num==7", alpha=0.5)
ax.set_xlabel("Pred")
ax.set_ylabel("True")
ax.set_title(check_col)
ax.legend()
plt.show()
# Out:
# ●全体のRMSE (Landsat_num==7)
# 　データ数: 618
# 　スコア: 0.1560
#
# ●全体のRMSE (Landsat_num==8)
# 　データ数: 3206
# 　スコア: 0.1473
#
# テストデータでLandsat_num==7の割合
# 　40.753%

# %%
if SAVE_DF:
    train.to_pickle(SAVE_DF_DIR / f"train_predicted_{SUB_FILE_NAME}.pkl")
