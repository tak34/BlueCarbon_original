# %%
# !pip install shap
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting shap
#   Downloading shap-0.41.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (572 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.6/572.6 kB 27.1 MB/s eta 0:00:00
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from shap) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from shap) (1.10.1)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap) (2.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from shap) (1.22.4)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.10/dist-packages (from shap) (23.1)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap) (0.56.4)
# Requirement already satisfied: tqdm>4.25.0 in /usr/local/lib/python3.10/dist-packages (from shap) (4.65.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from shap) (1.2.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba->shap) (67.7.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap) (0.39.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2022.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (1.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->shap) (1.16.0)
# Installing collected packages: slicer, shap
# Successfully installed shap-0.41.0 slicer-0.0.7

# %%
import lightgbm as lgb
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import numpy as np
import pandas as pd
import seaborn as sns
import datetime as dt
from pathlib import Path
import warnings
import os
import random
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
from tqdm.notebook import tqdm

import shap

# %%
# plt.rcParams['font.family'] = "MS Gothic"
warnings.simplefilter('ignore')

# %%
def fix_all_seeds(seed):
    np.random.seed(seed)
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    
fix_all_seeds(0)

# %%
# Config
SUB_FILE_NAME = "val11-0"
SAVE_SUB = False
SAVE_SUB_DIR = Path("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/sub_20230225")
SAVE_DF = False
SAVE_DF_DIR = Path("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/Val_20230429")

# %% [markdown]
# # データ読み込み

# %%
train = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/train.pkl")
test = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/test.pkl")
sub = pd.read_csv("/content/drive/MyDrive/Kaggle/BlueCarbon/raw/submit_example.csv")

# 特徴抽出後のデータ
umap_basic_train = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/FE_20230417/20230417_umap_basic_train.pkl")
umap_basic_test = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/FE_20230417/20230417_umap_basic_test.pkl")
train_sentinel = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/FE_20230417/20230428_train_sentinel_minmaxDiff.pkl")
test_sentinel = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/FE_20230417/20230428_test_sentinel_minmaxDiff.pkl")
train_landsat_2000to2020 = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/FE_20230417/20230429_train_landsat2_2000to2020.pkl")
test_landsat_2000to2020 = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/FE_20230417/20230429_test_landsat2_2000to2020.pkl")
train_landsat_minmax = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/FE_20230417/20230430_train_landsat3_normalized.pkl")
test_landsat_minmax = pd.read_pickle("/content/drive/MyDrive/Kaggle/BlueCarbon/proc/FE_20230417/20230430_test_landsat3_normalized.pkl")

train.head(2)
# Out:
#          lat         lon  area                 YMD    year  month  cover  \
# 0  24.989140  125.243164  20.0            20110926  2011.0    9.0  0.050
# 1  26.996172  127.912025  40.0  2009.7.6-2009.7.28  2009.0    7.0  0.725
#
#    depth_original  cliff_length  aicial_length  ...  MIN_NormG_2020  \
# 0             NaN           0.0       0.000000  ...        0.507961
# 1             NaN           0.0       0.478772  ...        0.353645
#
#    MIN_NormR_2020  MIN_PPR_2020  MIN_PSNDc2_2020  MIN_RDVI_2020  MIN_IF_2020  \
# 0        0.287288     -0.278071        -0.808075      -2.341663     2.353039
# 1        0.245048     -0.100556        -0.771423      -3.282602     4.672225
#
#    MIN_SLAVI_2020  MIN_SIPI2_2020  MIN_VARIgreen_2020   mesh20
# 0       95.142525        3.728732           -2.405135  3725_10
# 1      174.767501       -0.571513            0.448861  4027_13
#
# [2 rows x 3464 columns]

# %%
sub.head(2)
# Out:
#    0  0.47
# 0  1  0.68
# 1  2  0.25

# %% [markdown]
# # 前処理

# %% [markdown]
# ## 対数変換

# %%
train[f"log_cover"] = np.log1p(train["cover"])

# %% [markdown]
# ## 特徴抽出後のデータを結合

# %%
print(train.shape)
print(train_landsat_minmax.shape)
print(test.shape)
print(test_landsat_minmax.shape)
train_landsat_minmax.head(2)
# Out:
# (14140, 3465)
# (14140, 50)
# (4039, 3463)
# (4039, 50)
#    Blue_norm  Green_norm  Red_norm  NIR_norm  SWIR1_norm  TIRS1_norm  \
# 0  -0.872641   -0.770192 -0.624147 -0.536028   -0.546227   -0.744897
# 1   0.475056    1.254295  1.274292  3.491892    1.998576    0.583671
#
#    TIRS2_norm  SWIR2_norm  EVI_norm  TSAVI_norm  ...  NLI_norm  NormG_norm  \
# 0   -0.828209   -0.532998 -0.085934   -0.914298  ... -1.451049    0.475077
# 1    0.600471    1.090840 -9.960450    5.201679  ...  1.864528   -3.654105
#
#    NormR_norm  PPR_norm  PSNDc2_norm  RDVI_norm    IF_norm  SLAVI_norm  \
# 0    0.296024 -1.109615    -0.750047  -0.052587   0.127271   -0.406854
# 1   -1.126482  2.711313     5.444383   9.581726  12.557637    1.335754
#
#    SIPI2_norm  VARIgreen_norm
# 0    0.116049       -0.049049
# 1   -4.261068        0.143220
#
# [2 rows x 50 columns]

# %%
train = train.join([
    umap_basic_train,
    train_sentinel,
    train_landsat_minmax,
    train_landsat_2000to2020,
])
test = test.join([
    umap_basic_test,
    test_sentinel,
    test_landsat_minmax,
    test_landsat_2000to2020,
])
train.head(2)
# Out:
#          lat         lon  area                 YMD    year  month  cover  \
# 0  24.989140  125.243164  20.0            20110926  2011.0    9.0  0.050
# 1  26.996172  127.912025  40.0  2009.7.6-2009.7.28  2009.0    7.0  0.725
#
#    depth_original  cliff_length  aicial_length  ...  MINMAX_MCARI2__mean  \
# 0             NaN           0.0       0.000000  ...            -0.006201
# 1             NaN           0.0       0.478772  ...            -0.775479
#
#    MINMAX_MCARI2__std  MED_NormR_median  MED_NormR_std  MINMAX_NormR__mean  \
# 0            1.087738          0.222131       0.699859           -0.086431
# 1            0.251864          0.904064       1.205264           -0.222484
#
#    MINMAX_NormR__std  MED_TIRS2_median  MED_TIRS2_std  MINMAX_TIRS2__mean  \
# 0           1.010979          0.470200       0.632177           -0.219153
# 1           0.889441         -0.002017       0.795383           -0.719698
#
#    MINMAX_TIRS2__std
# 0           0.892955
# 1           0.899809
#
# [2 rows x 3792 columns]

# %%
umap_basic_train.head()
# Out:
#         dim0      dim1  temp_monthly
# 0   1.788618  6.597842          27.9
# 1 -10.111396  6.170877          29.2
# 2  21.165592  6.679852          25.3
# 3  -6.996612  9.728025          16.7
# 4  -6.822807  9.109682          16.7

# %% [markdown]
# ## 使用する特徴量

# %%
# 被度文献データ、海洋環境要因データ、landsat使用
# YMDは使わない
cols_base = train.columns.to_list()[:25]
cols_landsat = train.columns.to_list()[25:88]
cols_landsat_2000to2020 = train_landsat_2000to2020.columns.to_list()
cols_landsat_minmax = train_landsat_minmax.columns.to_list()

cols_sentinel = train.columns.to_list()[88:313]
cols_sentinel = [col for col in cols_sentinel if "MED" in col]
cols_sentinel_minmax = train_sentinel.columns.to_list()

cols_umap = ["temp_monthly"]

cols_use =\
 cols_base +\
 cols_landsat_2000to2020 +\
 cols_landsat_minmax +\
 ["log_cover"] # + cols_sentinel

cols_remove = [
    "YMD",
    "month",
    "Date_Acquired",
    "Landsat_StartTime",
    "PRODUCT_ID",
    "mesh20"
]
cols_use = [col for col in cols_use if not col in cols_remove]

# 重複を省く（一応）
cols_use = list(set(cols_use))

cols_use
# Out:
# ['depth',
#  'MINMAX_SIPI2__std',
#  'MED_TIRS1_std',
#  'MINMAX_SLAVI__mean',
#  'MED_SIPI2_median',
#  'MINMAX_SLAVI__std',
#  'MED_Alteration_std',
#  'MINMAX_GLI__std',
#  'MINMAX_CI__std',
#  'TIRS1_norm',
#  'MED_SWIR1_median',
#  'MINMAX_MCARI2__std',
#  'MED_MCARI1_median',
#  'MINMAX_TSAVI__std',
#  'MED_Ferric_Oxides_median',
#  'MINMAX_BWDRVI__mean',
#  'MED_IR550_median',
#  'MINMAX_Ferrous_Silicates__std',
#  'Chlred_edge_norm',
#  'GARI_norm',
#  'MINMAX_VARIgreen__mean',
#  'MCARI1_norm',
#  'MINMAX_MVI__mean',
#  'MINMAX_H__mean',
#  'GVMI_norm',
#  'MINMAX_CI__mean',
#  'area',
#  'MED_PPR_median',
#  'MINMAX_CVI__mean',
#  'MINMAX_PSNDc2__std',
#  'MED_Blue_median',
#  'MED_SWIR1_std',
#  'MED_Chlgreen_std',
#  'D678_500_norm',
#  'Salinity_annual',
#  'MINMAX_PPR__std',
#  'MED_TSAVI_std',
#  'MED_NIR_std',
#  'MED_PSNDc2_std',
#  'MINMAX_GARI__std',
#  'MED_SLAVI_std',
#  'MINMAX_NormR__mean',
#  'depth_original',
#  'hist_warm_sst',
#  'MINMAX_MCARI1__mean',
#  'lon',
#  'MINMAX_TIRS2__mean',
#  'MED_Cirededge_median',
#  'DSWI_norm',
#  'MINMAX_NLI__mean',
#  'MINMAX_Fe3__mean',
#  'mCRIRE_norm',
#  'MINMAX_VARIgreen__std',
#  'MED_D678_500_std',
#  'MINMAX_Blue__mean',
#  'MINMAX_mCRIG__mean',
#  'MED_PSNDc2_median',
#  'MED_CTVI_std',
#  'MINMAX_GVMI__std',
#  'MCARI2_norm',
#  'CTVI_norm',
#  'Blue_norm',
#  'Alteration_norm',
#  'NormR_norm',
#  'MED_DSWI_median',
#  'CVI_norm',
#  'MINMAX_SWIR2__mean',
#  'MINMAX_AVI__std',
#  'MED_SWIR2_std',
#  'aicial_length',
#  'lat',
#  'MINMAX_Cirededge__mean',
#  'MED_Gossan_std',
#  'MINMAX_Fe3__std',
#  'MINMAX_GEMI__mean',
#  'MINMAX_PPR__mean',
#  'MINMAX_IR550__mean',
#  'coast_length',
#  'MINMAX_Red__mean',
#  'EVI_norm',
#  'MINMAX_RDVI__mean',
#  'MED_RDVI_median',
#  'GEMI_norm',
#  'Gossan_norm',
#  'MED_mCRIG_median',
#  'MINMAX_MCARI2__mean',
#  'MED_Fe3_median',
#  'MINMAX_AVI__mean',
#  'MED_DVIMSS_std',
#  'AVI_norm',
#  'MINMAX_Ferric_Oxides__std',
#  'fetch',
#  'MED_RDVI_std',
#  'MED_Green_median',
#  'MINMAX_NIR__std',
#  'MED_MCARI2_median',
#  'MED_Red_median',
#  'BWDRVI_norm',
#  'DVIMSS_norm',
#  'MVI_norm',
#  'MINMAX_SWIR1__std',
#  'MINMAX_DVIMSS__std',
#  'MINMAX_CVI__std',
#  'IF_norm',
#  'MINMAX_Ferrous_Silicates__mean',
#  'MINMAX_NormG__std',
#  'MINMAX_Chlgreen__mean',
#  'MED_Fe3_std',
#  'MED_GEMI_median',
#  'MED_NormG_median',
#  'MED_NormG_std',
#  'MINMAX_D678_500__mean',
#  'MED_SIPI2_std',
#  'MED_GARI_median',
#  'MED_Alteration_median',
#  'MINMAX_TIRS2__std',
#  'MED_DSWI_std',
#  'hist_cold_sst',
#  'MINMAX_Red__std',
#  'MED_Ferrous_Silicates_std',
#  'CRI550_norm',
#  'warm_sst',
#  'MED_NormR_median',
#  'VARIgreen_norm',
#  'MED_SLAVI_median',
#  'MED_TIRS2_std',
#  'MED_NIR_median',
#  'MINMAX_IF__mean',
#  'MINMAX_SWIR2__std',
#  'MED_DSWI_5_std',
#  'river_dist',
#  'MINMAX_BWDRVI__std',
#  'MINMAX_DSWI__std',
#  'MED_NLI_std',
#  'MED_AVI_median',
#  'MED_CVI_std',
#  'MED_GLI_std',
#  'MED_Ferric_Oxides_std',
#  'MED_IF_std',
#  'MINMAX_SIPI2__mean',
#  'MED_MVI_std',
#  'MED_Red_std',
#  'MED_Ferrous_Silicates_median',
#  'Fe3_norm',
#  'MED_MCARI1_std',
#  'MINMAX_H__std',
#  'MINMAX_Gossan__mean',
#  'coastal_dist',
#  'MED_GARI_std',
#  'MINMAX_mCRIG__std',
#  'MINMAX_SWIR1__mean',
#  'MED_CTVI_median',
#  'MED_VARIgreen_std',
#  'MINMAX_NLI__std',
#  'MINMAX_NormR__std',
#  'beach_length',
#  'MINMAX_TIRS1__mean',
#  'MINMAX_Green__mean',
#  'MED_NormR_std',
#  'cover',
#  'DSWI_5_norm',
#  'MINMAX_Gossan__std',
#  'MED_D678_500_median',
#  'MINMAX_DSWI_5__std',
#  'MED_TIRS1_median',
#  'MED_Gossan_median',
#  'MED_GLI_median',
#  'MED_BWDRVI_median',
#  'MINMAX_CRI550__mean',
#  'MINMAX_NormG__mean',
#  'MINMAX_MCARI1__std',
#  'MINMAX_Blue__std',
#  'MED_EVI_std',
#  'MED_mCRIRE_median',
#  'sst_diff',
#  'MINMAX_Cigreen__std',
#  'MINMAX_DSWI__mean',
#  'MINMAX_IF__std',
#  'MED_H_std',
#  'MINMAX_GVMI__mean',
#  'RDVI_norm',
#  'MED_TSAVI_median',
#  'MINMAX_PSNDc2__mean',
#  'MINMAX_CTVI__mean',
#  'MED_MVI_median',
#  'MED_Chlred_edge_std',
#  'MED_GEMI_std',
#  'Cirededge_norm',
#  'MED_DSWI_5_median',
#  'mCRIG_norm',
#  'NormG_norm',
#  'PSNDc2_norm',
#  'MED_H_median',
#  'NLI_norm',
#  'Red_norm',
#  'MED_Cigreen_median',
#  'PPR_norm',
#  'MED_EVI_median',
#  'MED_SWIR2_median',
#  'MED_VARIgreen_median',
#  'MINMAX_CTVI__std',
#  'SLAVI_norm',
#  'MINMAX_GARI__mean',
#  'MED_CI_std',
#  'Ferric_Oxides_norm',
#  'MINMAX_GLI__mean',
#  'cliff_length',
#  'MINMAX_CRI550__std',
#  'MINMAX_DVIMSS__mean',
#  'MINMAX_D678_500__std',
#  'MINMAX_Alteration__mean',
#  'MINMAX_EVI__mean',
#  'MINMAX_GEMI__std',
#  'MED_IF_median',
#  'MINMAX_Ferric_Oxides__mean',
#  'SIPI2_norm',
#  'MED_Chlred_edge_median',
#  'MINMAX_TSAVI__mean',
#  'MINMAX_DSWI_5__mean',
#  'MINMAX_TIRS1__std',
#  'MED_AVI_std',
#  'SWIR2_norm',
#  'MINMAX_IR550__std',
#  'TIRS2_norm',
#  'MINMAX_Cirededge__std',
#  'MINMAX_Chlred_edge__std',
#  'MED_GVMI_median',
#  'MED_CVI_median',
#  'sst_ymd',
#  'Ferrous_Silicates_norm',
#  'MINMAX_Chlgreen__std',
#  'MED_mCRIG_std',
#  'TSAVI_norm',
#  'H_norm',
#  'Green_norm',
#  'MED_Cigreen_std',
#  'Chlgreen_norm',
#  'MED_DVIMSS_median',
#  'cold_sst',
#  'NIR_norm',
#  'log_cover',
#  'MED_BWDRVI_std',
#  'MED_CRI550_std',
#  'MED_MCARI2_std',
#  'GLI_norm',
#  'MED_mCRIRE_std',
#  'MINMAX_EVI__std',
#  'MED_GVMI_std',
#  'MED_NLI_median',
#  'MINMAX_Alteration__std',
#  'SWIR1_norm',
#  'MED_Chlgreen_median',
#  'IR550_norm',
#  'MINMAX_Cigreen__mean',
#  'MED_PPR_std',
#  'year',
#  'MINMAX_mCRIRE__std',
#  'MED_CI_median',
#  'MINMAX_Green__std',
#  'MED_Cirededge_std',
#  'MED_IR550_std',
#  'MED_TIRS2_median',
#  'MINMAX_mCRIRE__mean',
#  'MINMAX_RDVI__std',
#  'MINMAX_Chlred_edge__mean',
#  'MINMAX_NIR__mean',
#  'river_area',
#  'CI_norm',
#  'MINMAX_MVI__std',
#  'MED_Green_std',
#  'MED_Blue_std',
#  'sst_annual',
#  'Cigreen_norm',
#  'MED_CRI550_median']

# %%
train = train[cols_use]
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14140 entries, 0 to 14139
# Columns: 274 entries, depth to MED_CRI550_median
# dtypes: float32(24), float64(250)
# memory usage: 28.3 MB

# %%
cols_obj = ["cover", "log_cover"]
features = [col for col in cols_use if col not in cols_obj]
print("特徴量の数：", len(features))
# Out:
# 特徴量の数： 272

# %%
corr = train[features].corr()
threshold = 0.98
drop_numeric_cols=[]
pair=[]
for col in features:
    # if col in cat_features:
    #     continue
    for i in range(len(corr)):
        if abs(corr[col].iloc[i]) >= threshold and col != features[i] :
            print(f"{col} and {features[i]} are highly correlated...") 
            if col not in pair:
                pair.append(col)
                pair.append(features[i])
                drop_numeric_cols.append(col) 
features = list(set(features)-set(drop_numeric_cols))
print(f"Dropping columns : {drop_numeric_cols}")
print("特徴量の数：", len(features))
del drop_numeric_cols
del pair

features
# Out:
# MINMAX_BWDRVI__mean and MINMAX_PSNDc2__mean are highly correlated...
# MINMAX_PSNDc2__std and MINMAX_BWDRVI__std are highly correlated...
# MED_PSNDc2_std and MED_BWDRVI_std are highly correlated...
# lon and cold_sst are highly correlated...
# MED_PSNDc2_median and MED_BWDRVI_median are highly correlated...
# CVI_norm and BWDRVI_norm are highly correlated...
# CVI_norm and Cigreen_norm are highly correlated...
# MINMAX_SWIR2__mean and MINMAX_SWIR1__mean are highly correlated...
# lat and cold_sst are highly correlated...
# lat and sst_annual are highly correlated...
# MINMAX_Cirededge__mean and MINMAX_TSAVI__mean are highly correlated...
# BWDRVI_norm and CVI_norm are highly correlated...
# BWDRVI_norm and PSNDc2_norm are highly correlated...
# BWDRVI_norm and Cigreen_norm are highly correlated...
# MED_NormG_median and MED_DSWI_5_median are highly correlated...
# MINMAX_BWDRVI__std and MINMAX_PSNDc2__std are highly correlated...
# MED_CVI_std and MED_Cigreen_std are highly correlated...
# MINMAX_SWIR1__mean and MINMAX_SWIR2__mean are highly correlated...
# DSWI_5_norm and NormG_norm are highly correlated...
# MED_BWDRVI_median and MED_PSNDc2_median are highly correlated...
# MINMAX_DSWI__mean and MINMAX_DSWI_5__mean are highly correlated...
# MINMAX_PSNDc2__mean and MINMAX_BWDRVI__mean are highly correlated...
# MED_DSWI_5_median and MED_NormG_median are highly correlated...
# NormG_norm and DSWI_5_norm are highly correlated...
# PSNDc2_norm and BWDRVI_norm are highly correlated...
# MED_Cigreen_median and MED_CVI_median are highly correlated...
# MINMAX_TSAVI__mean and MINMAX_Cirededge__mean are highly correlated...
# MINMAX_DSWI_5__mean and MINMAX_DSWI__mean are highly correlated...
# MED_CVI_median and MED_Cigreen_median are highly correlated...
# MED_Cigreen_std and MED_CVI_std are highly correlated...
# cold_sst and lon are highly correlated...
# cold_sst and lat are highly correlated...
# cold_sst and sst_annual are highly correlated...
# MED_BWDRVI_std and MED_PSNDc2_std are highly correlated...
# sst_annual and lat are highly correlated...
# sst_annual and cold_sst are highly correlated...
# Cigreen_norm and CVI_norm are highly correlated...
# Cigreen_norm and BWDRVI_norm are highly correlated...
# Dropping columns : ['MINMAX_BWDRVI__mean', 'MINMAX_PSNDc2__std', 'MED_PSNDc2_std', 'lon', 'MED_PSNDc2_median', 'CVI_norm', 'MINMAX_SWIR2__mean', 'lat', 'MINMAX_Cirededge__mean', 'MED_NormG_median', 'MED_CVI_std', 'DSWI_5_norm', 'MINMAX_DSWI__mean', 'PSNDc2_norm', 'MED_Cigreen_median', 'sst_annual', 'Cigreen_norm']
# 特徴量の数： 255
# ['depth',
#  'MINMAX_SIPI2__std',
#  'MED_TIRS1_std',
#  'MINMAX_SLAVI__mean',
#  'MED_SIPI2_median',
#  'MINMAX_GLI__std',
#  'TIRS1_norm',
#  'MINMAX_CI__std',
#  'MED_SWIR1_median',
#  'MINMAX_MCARI2__std',
#  'MINMAX_TSAVI__std',
#  'MED_Ferric_Oxides_median',
#  'GARI_norm',
#  'MINMAX_VARIgreen__mean',
#  'MINMAX_MVI__mean',
#  'GVMI_norm',
#  'MINMAX_CVI__mean',
#  'MED_SWIR1_std',
#  'Salinity_annual',
#  'MINMAX_NormR__mean',
#  'depth_original',
#  'MINMAX_MCARI1__mean',
#  'MINMAX_TIRS2__mean',
#  'DSWI_norm',
#  'MINMAX_VARIgreen__std',
#  'MED_CTVI_std',
#  'CTVI_norm',
#  'Alteration_norm',
#  'NormR_norm',
#  'MED_DSWI_median',
#  'MED_SWIR2_std',
#  'MINMAX_Fe3__std',
#  'MED_Gossan_std',
#  'MINMAX_IR550__mean',
#  'coast_length',
#  'MINMAX_Red__mean',
#  'MINMAX_RDVI__mean',
#  'MED_RDVI_median',
#  'MINMAX_MCARI2__mean',
#  'MED_DVIMSS_std',
#  'AVI_norm',
#  'fetch',
#  'MED_RDVI_std',
#  'MED_Green_median',
#  'MED_MCARI2_median',
#  'MED_Red_median',
#  'MVI_norm',
#  'MINMAX_DVIMSS__std',
#  'IF_norm',
#  'MINMAX_Ferrous_Silicates__mean',
#  'MED_NormG_std',
#  'Gossan_norm',
#  'MINMAX_TIRS2__std',
#  'MED_GARI_median',
#  'hist_cold_sst',
#  'MED_Ferrous_Silicates_std',
#  'warm_sst',
#  'MED_SLAVI_median',
#  'MED_NIR_median',
#  'MED_Ferric_Oxides_std',
#  'river_dist',
#  'MINMAX_BWDRVI__std',
#  'MED_IF_std',
#  'MED_MVI_std',
#  'MED_Ferrous_Silicates_median',
#  'Fe3_norm',
#  'MINMAX_H__std',
#  'MINMAX_Gossan__mean',
#  'coastal_dist',
#  'MED_GARI_std',
#  'MINMAX_NormR__std',
#  'MED_VARIgreen_std',
#  'MINMAX_NLI__std',
#  'beach_length',
#  'MINMAX_TIRS1__mean',
#  'MINMAX_DSWI_5__std',
#  'MED_Gossan_median',
#  'MED_BWDRVI_median',
#  'MINMAX_CRI550__mean',
#  'MINMAX_NormG__mean',
#  'MINMAX_Blue__std',
#  'sst_diff',
#  'MINMAX_Cigreen__std',
#  'MINMAX_IF__std',
#  'MED_H_std',
#  'MED_TSAVI_median',
#  'MINMAX_PSNDc2__mean',
#  'MINMAX_CTVI__mean',
#  'MED_MVI_median',
#  'MED_Chlred_edge_std',
#  'Cirededge_norm',
#  'MED_DSWI_5_median',
#  'MED_H_median',
#  'MED_VARIgreen_median',
#  'Ferric_Oxides_norm',
#  'MINMAX_GLI__mean',
#  'cliff_length',
#  'MINMAX_CRI550__std',
#  'MINMAX_DVIMSS__mean',
#  'MINMAX_D678_500__std',
#  'MINMAX_GEMI__std',
#  'MINMAX_Ferric_Oxides__mean',
#  'SIPI2_norm',
#  'MINMAX_TSAVI__mean',
#  'MINMAX_DSWI_5__mean',
#  'MINMAX_TIRS1__std',
#  'MED_GVMI_median',
#  'Ferrous_Silicates_norm',
#  'MINMAX_Chlgreen__std',
#  'Green_norm',
#  'Chlgreen_norm',
#  'MED_BWDRVI_std',
#  'MED_CRI550_std',
#  'GLI_norm',
#  'MINMAX_EVI__std',
#  'MINMAX_Alteration__std',
#  'MED_NLI_median',
#  'SWIR1_norm',
#  'IR550_norm',
#  'MINMAX_Green__std',
#  'MED_TIRS2_median',
#  'MINMAX_Chlred_edge__mean',
#  'MINMAX_NIR__mean',
#  'MED_Green_std',
#  'MED_Blue_std',
#  'MINMAX_SWIR1__mean',
#  'MED_mCRIG_median',
#  'MED_CRI550_median',
#  'MED_Alteration_std',
#  'MINMAX_SLAVI__std',
#  'MED_MCARI1_median',
#  'MED_IR550_median',
#  'MINMAX_Ferrous_Silicates__std',
#  'Chlred_edge_norm',
#  'MCARI1_norm',
#  'MINMAX_H__mean',
#  'MINMAX_CI__mean',
#  'area',
#  'MED_PPR_median',
#  'MED_Blue_median',
#  'MED_Chlgreen_std',
#  'D678_500_norm',
#  'MINMAX_PPR__std',
#  'MED_TSAVI_std',
#  'MED_NIR_std',
#  'MINMAX_GARI__std',
#  'MED_SLAVI_std',
#  'hist_warm_sst',
#  'MED_Cirededge_median',
#  'MINMAX_NLI__mean',
#  'MINMAX_Fe3__mean',
#  'mCRIRE_norm',
#  'MED_D678_500_std',
#  'MINMAX_Blue__mean',
#  'MINMAX_mCRIG__mean',
#  'MINMAX_GVMI__std',
#  'MCARI2_norm',
#  'Blue_norm',
#  'MINMAX_AVI__std',
#  'aicial_length',
#  'MINMAX_GEMI__mean',
#  'MINMAX_PPR__mean',
#  'EVI_norm',
#  'GEMI_norm',
#  'MED_Fe3_median',
#  'MINMAX_AVI__mean',
#  'MINMAX_Ferric_Oxides__std',
#  'MINMAX_NIR__std',
#  'BWDRVI_norm',
#  'DVIMSS_norm',
#  'MINMAX_SWIR1__std',
#  'MINMAX_CVI__std',
#  'MINMAX_NormG__std',
#  'MINMAX_Chlgreen__mean',
#  'MED_Fe3_std',
#  'MED_GEMI_median',
#  'RDVI_norm',
#  'MINMAX_D678_500__mean',
#  'MED_SIPI2_std',
#  'MED_Alteration_median',
#  'MED_DSWI_std',
#  'MINMAX_Red__std',
#  'CRI550_norm',
#  'MED_NormR_median',
#  'VARIgreen_norm',
#  'MED_TIRS2_std',
#  'MINMAX_IF__mean',
#  'MINMAX_SWIR2__std',
#  'MED_DSWI_5_std',
#  'MINMAX_DSWI__std',
#  'MED_NLI_std',
#  'MED_AVI_median',
#  'MED_GLI_std',
#  'MINMAX_SIPI2__mean',
#  'MED_Red_std',
#  'MED_MCARI1_std',
#  'MINMAX_mCRIG__std',
#  'MED_CTVI_median',
#  'MINMAX_Green__mean',
#  'MED_NormR_std',
#  'MINMAX_Gossan__std',
#  'MED_D678_500_median',
#  'MED_TIRS1_median',
#  'MED_GLI_median',
#  'MINMAX_MCARI1__std',
#  'MED_EVI_std',
#  'MED_mCRIRE_median',
#  'MINMAX_GVMI__mean',
#  'MED_GEMI_std',
#  'mCRIG_norm',
#  'NormG_norm',
#  'NLI_norm',
#  'PPR_norm',
#  'Red_norm',
#  'MED_EVI_median',
#  'MED_SWIR2_median',
#  'MINMAX_CTVI__std',
#  'SLAVI_norm',
#  'MINMAX_GARI__mean',
#  'MED_CI_std',
#  'MINMAX_Alteration__mean',
#  'MINMAX_EVI__mean',
#  'MED_IF_median',
#  'MED_Chlred_edge_median',
#  'SWIR2_norm',
#  'MED_AVI_std',
#  'MINMAX_IR550__std',
#  'TIRS2_norm',
#  'MINMAX_Cirededge__std',
#  'MINMAX_Chlred_edge__std',
#  'MED_CVI_median',
#  'sst_ymd',
#  'MED_mCRIG_std',
#  'TSAVI_norm',
#  'H_norm',
#  'MED_Cigreen_std',
#  'MED_DVIMSS_median',
#  'cold_sst',
#  'NIR_norm',
#  'MED_MCARI2_std',
#  'MED_mCRIRE_std',
#  'MED_GVMI_std',
#  'MED_Chlgreen_median',
#  'MINMAX_Cigreen__mean',
#  'MED_PPR_std',
#  'year',
#  'MINMAX_mCRIRE__std',
#  'MED_CI_median',
#  'MED_Cirededge_std',
#  'MED_IR550_std',
#  'MINMAX_mCRIRE__mean',
#  'MINMAX_RDVI__std',
#  'river_area',
#  'CI_norm',
#  'MINMAX_MVI__std']

# %% [markdown]
# # CV

# %% [markdown]
# shap:
#
# https://data-analysis-stats.jp/%E6%A9%9F%E6%A2%B0%E5%AD%A6%E7%BF%92/%E6%A9%9F%E6%A2%B0%E5%AD%A6%E7%BF%92%E3%83%A2%E3%83%87%E3%83%AB%E3%82%92%E8%A7%A3%E9%87%88%E3%81%99%E3%82%8Bshap/

# %%
# train_date = train[["year", "month"]].copy()

# def convert_int_into_str(x):
#     x_str = str(int(x))
#     if len(x_str)==1:
#         return "0" + x_str
#     return x_str

# train_date["month_str"] = train_date["month"].apply(convert_int_into_str)
# train_date["year_month"] = (train_date["year"].astype(int).astype(str) + train_date["month_str"]).astype(int)
# train_date.head()

# %%
# year_month = train_date["year_month"]
# cv = []

# val_idx1 = (year_month >= 200901)&(year_month <200907)
# train_idx1 = ~val_idx1
# cv.append([train_idx1, val_idx1])

# val_idx2 = (year_month >= 200910)&(year_month <200912)
# train_idx2 = ~val_idx2
# cv.append([train_idx2, val_idx2])

# val_idx3 = (year_month >= 201006)&(year_month <201009)
# train_idx3 = ~val_idx3
# cv.append([train_idx3, val_idx3])

# val_idx4 = (year_month >= 201010)&(year_month <201101)
# train_idx4 = ~val_idx4
# cv.append([train_idx4, val_idx4])

# val_idx5 = (year_month >= 201909)&(year_month <201910)
# train_idx5 = ~val_idx5
# cv.append([train_idx5, val_idx5])

# %%
def my_cross_val_predict(df, df_test, y_name=None, y_raw_name=None, params=None, features=None, cv=None, split=5, eval_by_shap=True):
    # CVの結果を集約する変数
    results_rmse = []
    dict_learning_rate = {}
    fi_df = pd.DataFrame()
    fi_df['features'] = features

    # kfoldで5分割
    kfold = KFold(n_splits=split, shuffle=True, random_state=42)
    X = df[features].values
    y = df[y_name].values
    y_raw = df[y_raw_name].values

    # 同時にtestデータも予測する
    X_test = df_test[features].values
    y_pred_test_mean = np.zeros(len(X_test))

    y_pred_val_all = np.zeros(len(y))
    y_pred_val_all[:] = np.nan

    for i, (train_idx, val_idx) in enumerate(kfold.split(X)):
        print("###"*10)
        print(f"● CV{i}")
        print("###"*10)
        X_train = X[train_idx, :]
        y_train = y[train_idx]
        X_val = X[val_idx, :]
        y_val = y[val_idx]
        y_val_raw = y_raw[val_idx]

        train_dataset = lgb.Dataset(X_train,
                                    y_train,
                                    feature_name=features,)
        val_dataset = lgb.Dataset(X_val,
                                  y_val,
                                  feature_name=features,)
        
        evals_result = {}
        callbacks = [
            # lgb.log_evaluation(100),
            # lgb.early_stopping(200),
            lgb.record_evaluation(evals_result)
        ]

        # モデル作成
        model = lgb.train(params=params,
                          train_set=train_dataset,
                          valid_sets=[val_dataset],
                          callbacks=callbacks,
                          verbose_eval=500,)
        # valデータ予測
        y_pred_raw = model.predict(X_val)
        y_pred = np.expm1(y_pred_raw)
        y_pred[y_pred<0] = 0
        y_pred[y_pred>1] = 1
        print(np.average(y_pred))
        y_pred_val_all[val_idx] = y_pred
        # testデータ予測
        y_pred_test_raw = model.predict(X_test)
        y_pred_test = np.expm1(y_pred_test_raw)
        # この処理は最後にやる
        # y_pred_test[y_pred_test<0] = 0
        # y_pred_test[y_pred_test>1] = 1
        y_pred_test_mean += (y_pred_test / split)
        
        # RMSE計算
        rmse = np.sqrt(mean_squared_error(y_val_raw, y_pred))
        results_rmse.append(rmse)

        # 予測結果の可視化
        fig, ax = plt.subplots()
        ax.grid(alpha=0.2)
        ax.scatter(y_pred, y_val_raw, s=2)
        ax.set_xlabel("Pred")
        ax.set_ylabel("True")
        ax.set_xlim([0, 1])
        ax.set_ylim([0, 1])
        ax.set_title(f"val_{i}")
        plt.show()

        # 特徴量重要度の抽出
        fi_df[f"importance_cv{i}"] = model.feature_importance(importance_type='gain')
        dict_learning_rate[f"fold_{i}"] = np.array(evals_result['valid_0']['fair'])

        # shapで評価
        if eval_by_shap:
            df_X_val = pd.DataFrame(X_val, columns=features)
            explainer = shap.TreeExplainer(model)
            shap_values = explainer.shap_values(X=df_X_val)
            shap.summary_plot(shap_values, df_X_val)
        
    # 学習曲線の可視化
    print("###"*10)
    print("学習曲線")
    print("###"*10)
    fig, ax = plt.subplots()
    ax.grid(alpha=0.2)
    for key, value in dict_learning_rate.items():
        x = list(range(len(value)))
        ax.plot(x, value, label=key)
    ax.legend(loc="upper left", bbox_to_anchor=(1, 0.5))
    # ax.set_ylim([-0.05, 0.2])
    plt.show()

    # testデータの予測結果整理
    y_pred_test_mean[y_pred_test_mean<0] = 0
    y_pred_test_mean[y_pred_test_mean>1] = 1

    return results_rmse, fi_df, y_pred_test_mean, y_pred_val_all

# %%
def plot_results(results):
    x_list = [f"cv{i}" for i in range(5)]
    fig = plt.figure(figsize=(7, 4))
    ax = fig.add_subplot()
    ax.bar(x=x_list, height=results, label="RMSE", zorder=10)
    ax.set_ylabel("RMSE")
    # ax.set_ylim([0, 0.007])
    ax.grid(zorder=-10)
    ax.legend()
    plt.show()

# from: https://blog.amedama.jp/entry/lightgbm-cv-feature-importance
def plot_importance(fi_df, figsize=(10, 10)):
#     raw_importances = cvbooster.feature_importance(importance_type='gain')
    feature_name = fi_df.features.to_list()
    importance_df = pd.DataFrame(data=fi_df.iloc[:, 1:].values.T,
                             columns=feature_name)
    # 平均値でソートする
    sorted_indices = importance_df.mean(axis=0).sort_values(ascending=False).index
    sorted_importance_df = importance_df.loc[:, sorted_indices]
    print(sorted_importance_df.shape)
    # 上位をプロットする
#     PLOT_TOP_N = 40
    plot_cols = sorted_importance_df.columns[:50]
    _, ax = plt.subplots(figsize=figsize)
    ax.grid()
    ax.set_xscale('log')
    ax.set_ylabel('Feature')
    ax.set_xlabel('Importance')
    sns.boxplot(data=sorted_importance_df[plot_cols],
                orient='h',
                ax=ax)
    plt.show()

# %%
params = {
    'objective': 'fair',
    'metric': 'fair',
    'boosting_type': 'gbdt',
    'max_depth': 5,
    'n_estimators': 2000,
    'learning_rate': 0.01,
    # 'num_leaves': 50,
    # 'colsample_bytree': 0.6,
    # 'subsample': 0.5,
    'verbose': -1,
    'n_jobs': -1,
    'seed': 46,
}

results_rmse, fi_df, y_test_pred, train["y_pred"] = my_cross_val_predict(train, test, y_name="log_cover", y_raw_name="cover", params=params, features=features)
# Out:
# ##############################
# ● CV0
# ##############################
# [500]	valid_0's fair: 0.00401033
# [1000]	valid_0's fair: 0.00365836
# [1500]	valid_0's fair: 0.0034602
# [2000]	valid_0's fair: 0.0033363
# 0.1746680879226175
# ##############################
# ● CV1
# ##############################
# [500]	valid_0's fair: 0.00408079
# [1000]	valid_0's fair: 0.00369002
# [1500]	valid_0's fair: 0.00347275
# [2000]	valid_0's fair: 0.00334609
# 0.17729876379692455
# ##############################
# ● CV2
# ##############################
# [500]	valid_0's fair: 0.00405516
# [1000]	valid_0's fair: 0.00362302
# [1500]	valid_0's fair: 0.00339752
# [2000]	valid_0's fair: 0.00326464
# 0.1785165486187991
# ##############################
# ● CV3
# ##############################
# [500]	valid_0's fair: 0.0038154
# [1000]	valid_0's fair: 0.00339714
# [1500]	valid_0's fair: 0.00319011
# [2000]	valid_0's fair: 0.00305431
# 0.17669207013834815
# ##############################
# ● CV4
# ##############################
# [500]	valid_0's fair: 0.0043917
# [1000]	valid_0's fair: 0.00395983
# [1500]	valid_0's fair: 0.00372324
# [2000]	valid_0's fair: 0.00358395
# 0.17557166224964618
# ##############################
# 学習曲線
# ##############################

# %%
for i, rmse in enumerate(results_rmse):
    print(f"CV{i}: {rmse:.3f}")
print(f"Average: {np.average(results_rmse):.3f}")
plot_results(results_rmse)
# Out:
# CV0: 0.119
# CV1: 0.121
# CV2: 0.119
# CV3: 0.114
# CV4: 0.124
# Average: 0.120

# %%
plot_importance(fi_df, figsize=(10, 12))
# Out:
# (5, 255)

# %% [markdown]
# # Sub作成

# %%
test_sub = pd.DataFrame(y_test_pred, columns=["pred"])
test_sub
# Out:
#           pred
# 0     0.125993
# 1     0.064126
# 2     0.484471
# 3     0.044140
# 4     0.147799
# ...        ...
# 4034  0.093993
# 4035  0.039352
# 4036  0.438805
# 4037  0.068629
# 4038  0.555375
#
# [4039 rows x 1 columns]

# %%
test_pred_mean = test_sub["pred"].mean()
test_pred_mean
# Out:
# 0.1830774516297825

# %%
test_sub2 = test_sub.copy()
public_mean = 0.09088
# test_sub["pred"] = test_sub["pred"] * (public_mean / test_pred_mean)
test_sub2["pred"] -= (test_pred_mean - public_mean)
test_sub2["pred"] = np.clip(test_sub2["pred"].values, 0, 1)
test_sub2
# Out:
#           pred
# 0     0.033796
# 1     0.000000
# 2     0.392273
# 3     0.000000
# 4     0.055601
# ...        ...
# 4034  0.001796
# 4035  0.000000
# 4036  0.346607
# 4037  0.000000
# 4038  0.463178
#
# [4039 rows x 1 columns]

# %%
print("pred_最小値:", test_sub["pred"].min())
print("pred_最大値:", test_sub["pred"].max())
print("pred_平均値:", test_sub["pred"].mean())
# Out:
# pred_最小値: 0.0
# pred_最大値: 0.7176100475182816
# pred_平均値: 0.1830774516297825

# %%
print("●後処理後")
print("pred_最小値:", test_sub2["pred"].min())
print("pred_最大値:", test_sub2["pred"].max())
print("pred_平均値:", test_sub2["pred"].mean())
# Out:
# ●後処理後
# pred_最小値: 0.0
# pred_最大値: 0.6254125958884991
# pred_平均値: 0.10910088532513866

# %%
if SAVE_SUB:
    test_sub.to_csv(SAVE_SUB_DIR / f"{SUB_FILE_NAME}.csv", header=False)
    test_sub2.to_csv(SAVE_SUB_DIR / f"{SUB_FILE_NAME}_mod.csv", header=False)

# %% [markdown]
# # 予測結果確認

# %%
def check_by_scatter(check_col):
    tmp1 = df_pred[train[check_col].isnull()]
    tmp2 = df_pred[~train[check_col].isnull()]
    fig, ax = plt.subplots(figsize=(7, 6))
    ax.grid(alpha=0.2, color="gray")
    ax.scatter(tmp2["y_pred"], tmp2["cover"], s=6, label=f"NOT Null", alpha=0.5)
    ax.scatter(tmp1["y_pred"], tmp1["cover"], s=6, label=f"Null", alpha=0.5)
    ax.set_xlabel("Pred")
    ax.set_ylabel("True")
    ax.set_title(check_col)
    ax.legend()
    plt.show()

# %%
df_pred = train[["cover", "y_pred"]]
score = np.sqrt(mean_squared_error(train['cover'].values, train['y_pred'].values))
print(f"全体のRMSE: {score:.04f}")
# Out:
# 全体のRMSE: 0.1197

# %%
check_col = "depth_original"
tmp1 = df_pred[train[check_col].isnull()]
tmp2 = df_pred[~train[check_col].isnull()]
score1 = np.sqrt(mean_squared_error(tmp1['cover'].values, tmp1['y_pred'].values))
score2 = np.sqrt(mean_squared_error(tmp2['cover'].values, tmp2['y_pred'].values))
print(f"●全体のRMSE ({check_col}がnull)")
print(f"　データ数: {len(tmp1)}")
print(f"　スコア: {score1:.04f}\n")
print(f"●全体のRMSE ({check_col}がnull以外)")
print(f"　データ数: {len(tmp2)}")
print(f"　スコア: {score2:.04f}\n")
print(f"テストデータで{check_col}がnullの割合")
print(f"　{(100*test[check_col].isnull().sum()/len(test)):.3f}%")
check_by_scatter(check_col)
# Out:
# ●全体のRMSE (depth_originalがnull)
# 　データ数: 9721
# 　スコア: 0.0914
#
# ●全体のRMSE (depth_originalがnull以外)
# 　データ数: 4419
# 　スコア: 0.1658
#
# テストデータでdepth_originalがnullの割合
# 　50.829%

# %%
check_col = "Blue"
tmp1 = df_pred[train[check_col].isnull()]
tmp2 = df_pred[~train[check_col].isnull()]
score1 = np.sqrt(mean_squared_error(tmp1['cover'].values, tmp1['y_pred'].values))
score2 = np.sqrt(mean_squared_error(tmp2['cover'].values, tmp2['y_pred'].values))
print(f"●全体のRMSE ({check_col}がnull)")
print(f"　データ数: {len(tmp1)}")
print(f"　スコア: {score1:.04f}\n")
print(f"●全体のRMSE ({check_col}がnull以外)")
print(f"　データ数: {len(tmp2)}")
print(f"　スコア: {score2:.04f}\n")
print(f"テストデータで{check_col}がnullの割合")
print(f"　{(100*test[check_col].isnull().sum()/len(test)):.3f}%")
check_by_scatter(check_col)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Blue'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-8a8d30179106> in <cell line: 2>()
#       1 check_col = "Blue"
# ----> 2 tmp1 = df_pred[train[check_col].isnull()]
#       3 tmp2 = df_pred[~train[check_col].isnull()]
#       4 score1 = np.sqrt(mean_squared_error(tmp1['cover'].values, tmp1['y_pred'].values))
#       5 score2 = np.sqrt(mean_squared_error(tmp2['cover'].values, tmp2['y_pred'].values))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Blue'

# %%
check_col = "MED_AFRI1600"
tmp1 = df_pred[train[check_col].isnull()]
tmp2 = df_pred[~train[check_col].isnull()]
score1 = np.sqrt(mean_squared_error(tmp1['cover'].values, tmp1['y_pred'].values))
score2 = np.sqrt(mean_squared_error(tmp2['cover'].values, tmp2['y_pred'].values))
print(f"●全体のRMSE ({check_col}がnull)")
print(f"　データ数: {len(tmp1)}")
print(f"　スコア: {score1:.04f}\n")
print(f"●全体のRMSE ({check_col}がnull以外)")
print(f"　データ数: {len(tmp2)}")
print(f"　スコア: {score2:.04f}\n")
print(f"テストデータで{check_col}がnullの割合")
print(f"　{(100*test[check_col].isnull().sum()/len(test)):.3f}%")
check_by_scatter(check_col)

# %%
check_col = "MAX_NormG__median"
tmp1 = df_pred[train[check_col].isnull()]
tmp2 = df_pred[~train[check_col].isnull()]
score1 = np.sqrt(mean_squared_error(tmp1['cover'].values, tmp1['y_pred'].values))
score2 = np.sqrt(mean_squared_error(tmp2['cover'].values, tmp2['y_pred'].values))
print(f"●全体のRMSE ({check_col}がnull)")
print(f"　データ数: {len(tmp1)}")
print(f"　スコア: {score1:.04f}\n")
print(f"●全体のRMSE ({check_col}がnull以外)")
print(f"　データ数: {len(tmp2)}")
print(f"　スコア: {score2:.04f}\n")
print(f"テストデータで{check_col}がnullの割合")
print(f"　{(100*test[check_col].isnull().sum()/len(test)):.3f}%")
check_by_scatter(check_col)

# %%
check_col = "depth"
tmp1 = df_pred[train[check_col].isnull()]
tmp2 = df_pred[~train[check_col].isnull()]
score1 = np.sqrt(mean_squared_error(tmp1['cover'].values, tmp1['y_pred'].values))
score2 = np.sqrt(mean_squared_error(tmp2['cover'].values, tmp2['y_pred'].values))
print(f"●全体のRMSE ({check_col}がnull)")
print(f"　データ数: {len(tmp1)}")
print(f"　スコア: {score1:.04f}\n")
print(f"●全体のRMSE ({check_col}がnull以外)")
print(f"　データ数: {len(tmp2)}")
print(f"　スコア: {score2:.04f}\n")
print(f"テストデータで{check_col}がnullの割合")
print(f"　{(100*test[check_col].isnull().sum()/len(test)):.3f}%")
check_by_scatter(check_col)

# %%
check_col = "Landsat_num"
tmp1 = df_pred[train[check_col]==7]
tmp2 = df_pred[train[check_col]==8]
score1 = np.sqrt(mean_squared_error(tmp1['cover'].values, tmp1['y_pred'].values))
score2 = np.sqrt(mean_squared_error(tmp2['cover'].values, tmp2['y_pred'].values))
print(f"●全体のRMSE ({check_col}==7)")
print(f"　データ数: {len(tmp1)}")
print(f"　スコア: {score1:.04f}\n")
print(f"●全体のRMSE ({check_col}==8)")
print(f"　データ数: {len(tmp2)}")
print(f"　スコア: {score2:.04f}\n")
print(f"テストデータで{check_col}==7の割合")
print(f"　{(100*(test[check_col]==7).sum()/len(test)):.3f}%")

fig, ax = plt.subplots(figsize=(7, 6))
ax.grid(alpha=0.2, color="gray")
ax.scatter(tmp2["y_pred"], tmp2["cover"], s=6, label=f"Landsat_num==8", alpha=0.5)
ax.scatter(tmp1["y_pred"], tmp1["cover"], s=6, label=f"Landsat_num==7", alpha=0.5)
ax.set_xlabel("Pred")
ax.set_ylabel("True")
ax.set_title(check_col)
ax.legend()
plt.show()

# %%
if SAVE_DF:
    train.to_pickle(SAVE_DF_DIR / f"train_predicted_{SUB_FILE_NAME}.pkl")
